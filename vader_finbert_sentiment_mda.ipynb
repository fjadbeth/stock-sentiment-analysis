# %% [markdown]
# # Financial Sentiment Analysis with VADER and FinBERT
#
# ## Overview
#
# This Python script enhances financial sentiment analysis by adding VADER (Valence Aware Dictionary and sEntiment Reasoner) and FinBERT (Financial BERT) sentiment scores to existing financial text analysis results. It's designed to work with Management Discussion and Analysis (MDA) sections from financial filings and complements existing sentiment analysis (presumably from the Gemini API).
#
# ## Key Features
#
# - Dual sentiment analysis approach using:
#   - VADER: Lexicon and rule-based sentiment analysis
#   - FinBERT: Financial domain-specific BERT model
# - Parallel processing with ThreadPoolExecutor
# - Robust text matching between datasets
# - Automatic handling of long texts through chunking
# - Progress tracking and intermediate result saving
# - Comprehensive error handling and logging
#
# ## Installation Requirements
#
# - Python 3.6+
# - Required packages:
#   ```bash
#   pip install pandas numpy torch tqdm nltk transformers
#   ```
# - NLTK VADER lexicon (automatically downloaded if missing)
# - ProsusAI/finbert model (automatically downloaded during first run)
#
# ## Configuration
#
# Key parameters at the top of the script:
#
# ```python
# MAX_TEXT_LENGTH = 60000  # Maximum text length to process
# BATCH_SIZE = 5           # Rows to process per batch
# SAVE_FREQUENCY = 20      # Save after processing this many batches
# MAX_WORKERS = 4          # Number of parallel processing threads
# ```
#
# ## Usage
#
# ### Basic Operation
#
# 1. Run the script:
#    ```bash
#    python sentiment_enhancement.py
#    ```
#
# 2. Follow the interactive prompts:
#    - Enter years to process (comma-separated or "all")
#    - Confirm file paths or provide alternatives
#    - Review progress in the terminal
#
# ### Expected File Structure
#
# The script expects:
# ```
# project/
# ├── data/
# │   └── mda_data/
# │       └── mda_sections_YEAR.csv    # Original MDA text data
# ├── sentiment_results/
# │   └── mda/
# │       ├── mda_sentiment_YEAR_results_v2.csv  # Input with existing scores
# │       └── mda_sentiment_YEAR_results_v3.csv  # Output with enhanced scores
# └── sentiment_enhancement.py
# ```
#
# ## Sentiment Analysis Details
#
# ### VADER Analysis
# VADER provides:
# - `vader_compound`: Overall sentiment score (-1 to 1)
# - `vader_pos`: Positive sentiment score (0 to 1)
# - `vader_neg`: Negative sentiment score (0 to 1)
# - `vader_neu`: Neutral sentiment score (0 to 1)
#
# ### FinBERT Analysis
# FinBERT provides:
# - `finbert_positive`: Probability of positive sentiment (0 to 1)
# - `finbert_negative`: Probability of negative sentiment (0 to 1)
# - `finbert_neutral`: Probability of neutral sentiment (0 to 1)
# - `finbert_sentiment`: Overall sentiment score (positive - negative)
#
# ## Advanced Features
#
# ### Chunking for Long Texts
# For longer documents, FinBERT analysis splits text into 512-token chunks and averages sentiment scores across all chunks.
#
# ### Parallel Processing
# The script uses ThreadPoolExecutor to process multiple batches simultaneously, significantly improving performance.
#
# ### Multiple Matching Strategies
# Three matching strategies are attempted when finding MDA text:
# 1. Match on all fields (Ticker, CIK, FormType, FiledAt)
# 2. Match on Ticker, CIK, and FormType
# 3. Match on just Ticker and CIK
#
# ## Troubleshooting
#
# - **Missing files**: The script attempts to find alternative paths or prompts for the correct location
# - **Model initialization errors**: Check CUDA compatibility and available memory
# - **Text matching failures**: Ensure consistent date formats and identifiers between datasets
# - **Memory issues**: Reduce MAX_WORKERS or BATCH_SIZE for large datasets
#
# ## Error Handling
#
# The script implements robust error handling:
# - Detailed logging to both console and file
# - Graceful handling of missing data
# - Thread-safe parallel processing
# - Automatic NLTK resource downloading
# - GPU/CPU detection with fallback options
#
# ## Output
#
# The script generates a CSV file with all original columns plus:
# - VADER sentiment scores (vader_compound, vader_pos, vader_neg, vader_neu)
# - FinBERT sentiment scores (finbert_positive, finbert_negative, finbert_neutral, finbert_sentiment)

# %%
import pandas as pd
import numpy as np
import os
import glob
import time
import logging
import re
import torch
from datetime import datetime
from tqdm import tqdm
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from transformers import BertTokenizer, BertForSequenceClassification
from concurrent.futures import ThreadPoolExecutor

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'sentiment_enhancement_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Constants
MAX_TEXT_LENGTH = 60000  # Match the same limit as in the Gemini code
BATCH_SIZE = 5  # Number of rows to process at once for efficiency
SAVE_FREQUENCY = 20  # Save after processing this many rows
MAX_WORKERS = 4  # Thread pool size for parallel processing

# Initialize VADER and FinBERT only once
def initialize_models():
    logger.info("Initializing sentiment models...")
    try:
        # Initialize VADER
        vader_analyzer = SentimentIntensityAnalyzer()
        
        # Initialize FinBERT (with device management)
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        logger.info(f"Using device: {device}")
        
        finbert_tokenizer = BertTokenizer.from_pretrained('ProsusAI/finbert')
        finbert_model = BertForSequenceClassification.from_pretrained('ProsusAI/finbert').to(device)
        finbert_model.eval()  # Set to evaluation mode
        
        logger.info("Models initialized successfully!")
        return vader_analyzer, finbert_tokenizer, finbert_model, device
    except Exception as e:
        logger.error(f"Error initializing models: {e}")
        raise

# Helper function to standardize date format
def standardize_date_format(date_str):
    """
    Standardize date string to YYYY-MM-DD format for consistent matching
    """
    if pd.isna(date_str) or date_str is None or date_str == '':
        return None
    
    try:
        # Try to parse using pandas (handles many formats)
        dt = pd.to_datetime(date_str)
        return dt.strftime('%Y-%m-%d')
    except:
        logger.warning(f"Could not standardize date: {date_str}")
        return date_str

# VADER sentiment analysis function
def analyze_with_vader(text, vader_analyzer):
    """
    Analyze sentiment using VADER
    """
    try:
        # Truncate text if too long (VADER can handle long texts, but we'll be consistent)
        if text and len(text) > MAX_TEXT_LENGTH:
            logger.warning(f"Text truncated for VADER from {len(text)} to {MAX_TEXT_LENGTH} chars")
            text = text[:MAX_TEXT_LENGTH]
        
        if not text or not isinstance(text, str):
            logger.warning("Empty or invalid text for VADER analysis")
            return {
                'vader_compound': np.nan,
                'vader_pos': np.nan,
                'vader_neg': np.nan,
                'vader_neu': np.nan
            }
        
        # Get sentiment scores
        scores = vader_analyzer.polarity_scores(text)
        
        return {
            'vader_compound': scores['compound'],
            'vader_pos': scores['pos'],
            'vader_neg': scores['neg'],
            'vader_neu': scores['neu']
        }
    except Exception as e:
        logger.error(f"Error in VADER analysis: {e}")
        return {
            'vader_compound': np.nan,
            'vader_pos': np.nan,
            'vader_neg': np.nan,
            'vader_neu': np.nan
        }

# FinBERT chunking and sentiment analysis function
def analyze_with_finbert(text, tokenizer, model, device):
    """
    Analyze sentiment using FinBERT with chunking for long texts
    """
    try:
        if not text or not isinstance(text, str):
            logger.warning("Empty or invalid text for FinBERT analysis")
            return {
                'finbert_positive': np.nan,
                'finbert_negative': np.nan,
                'finbert_neutral': np.nan,
                'finbert_sentiment': np.nan  # Overall sentiment score (pos - neg)
            }
        
        # Truncate text if too long (for memory considerations)
        if len(text) > MAX_TEXT_LENGTH:
            logger.warning(f"Text truncated for FinBERT from {len(text)} to {MAX_TEXT_LENGTH} chars")
            text = text[:MAX_TEXT_LENGTH]
        
        # Tokenize and split into chunks of 512 tokens
        encoded_input = tokenizer(text, 
                                  return_tensors='pt', 
                                  max_length=512, 
                                  truncation=True, 
                                  padding=True, 
                                  return_overflowing_tokens=True)
        
        # Get number of chunks
        num_chunks = encoded_input['input_ids'].size(0)
        logger.info(f"Processing {num_chunks} chunks for FinBERT")
        
        if num_chunks == 0:
            logger.warning("No chunks were created by the tokenizer")
            return {
                'finbert_positive': np.nan,
                'finbert_negative': np.nan,
                'finbert_neutral': np.nan,
                'finbert_sentiment': np.nan
            }
        
        # Process all chunks in one batch (or in smaller batches if there are too many)
        all_probs = []
        batch_size = 8  # Process chunks in batches of 8 if there are many
        
        for i in range(0, num_chunks, batch_size):
            batch_input_ids = encoded_input['input_ids'][i:i+batch_size].to(device)
            batch_attention_mask = encoded_input['attention_mask'][i:i+batch_size].to(device)
            
            with torch.no_grad():
                outputs = model(batch_input_ids, attention_mask=batch_attention_mask)
                logits = outputs.logits
                probs = torch.softmax(logits, dim=1)
                all_probs.append(probs)
        
        # Combine all batches
        combined_probs = torch.cat(all_probs, dim=0)
        
        # Average probabilities across all chunks
        avg_probs = combined_probs.mean(dim=0).cpu().numpy()
        
        # Map to sentiment categories (FinBERT order: positive, negative, neutral)
        return {
            'finbert_positive': float(avg_probs[0]),
            'finbert_negative': float(avg_probs[1]),
            'finbert_neutral': float(avg_probs[2]),
            'finbert_sentiment': float(avg_probs[0] - avg_probs[1])  # pos - neg as overall score
        }
    except Exception as e:
        logger.error(f"Error in FinBERT analysis: {e}")
        import traceback
        logger.error(f"Traceback: {traceback.format_exc()}")
        return {
            'finbert_positive': np.nan,
            'finbert_negative': np.nan,
            'finbert_neutral': np.nan,
            'finbert_sentiment': np.nan
        }

# Find matching MDA text for a row
def find_matching_mda_text(row, mda_df):
    """
    Find matching MDA text for a row using multiple matching strategies
    Similar to the approach in the reference code
    """
    # Extract row data for matching
    ticker = row.get('Ticker', None)
    cik = row.get('CIK', None)
    form_type = row.get('FormType', None)
    filed_at = row.get('FiledAt', None)
    
    # Log what we're trying to match
    logger.info(f"Looking for match: Ticker={ticker}, CIK={cik}, FormType={form_type}, FiledAt={filed_at}")
    
    # Try different matching strategies
    matching_rows = None
    
    # Strategy 1: Try matching on all fields
    if matching_rows is None or len(matching_rows) == 0:
        mask = pd.Series([True] * len(mda_df), index=mda_df.index)
        
        if ticker is not None and 'Ticker' in mda_df.columns:
            mask = mask & (mda_df['Ticker'] == ticker)
        
        if cik is not None and 'CIK' in mda_df.columns:
            mask = mask & (mda_df['CIK'] == cik)
        
        if form_type is not None and 'FormType' in mda_df.columns:
            mask = mask & (mda_df['FormType'] == form_type)
        
        if filed_at is not None and 'FiledAt' in mda_df.columns:
            mask = mask & (mda_df['FiledAt'] == filed_at)
        
        matching_rows = mda_df[mask]
        logger.info(f"Strategy 1 (all fields): Found {len(matching_rows)} matches")
    
    # Strategy 2: Match on Ticker, CIK, and FormType but not date
    if matching_rows is None or len(matching_rows) == 0:
        mask = pd.Series([True] * len(mda_df), index=mda_df.index)
        
        if ticker is not None and 'Ticker' in mda_df.columns:
            mask = mask & (mda_df['Ticker'] == ticker)
        
        if cik is not None and 'CIK' in mda_df.columns:
            mask = mask & (mda_df['CIK'] == cik)
        
        if form_type is not None and 'FormType' in mda_df.columns:
            mask = mask & (mda_df['FormType'] == form_type)
        
        matching_rows = mda_df[mask]
        logger.info(f"Strategy 2 (no date): Found {len(matching_rows)} matches")
    
    # Strategy 3: Match on just Ticker and CIK
    if matching_rows is None or len(matching_rows) == 0:
        mask = pd.Series([True] * len(mda_df), index=mda_df.index)
        
        if ticker is not None and 'Ticker' in mda_df.columns:
            mask = mask & (mda_df['Ticker'] == ticker)
        
        if cik is not None and 'CIK' in mda_df.columns:
            mask = mask & (mda_df['CIK'] == cik)
        
        matching_rows = mda_df[mask]
        logger.info(f"Strategy 3 (Ticker+CIK): Found {len(matching_rows)} matches")
    
    # If we still have no matches, return None
    if matching_rows is None or len(matching_rows) == 0:
        logger.warning(f"Could not find matching row in MDA file")
        return None
    
    if len(matching_rows) > 1:
        logger.warning(f"Found multiple matching rows ({len(matching_rows)}), using the first one")
    
    # Get the MDA text from the first matching row
    try:
        mda_text = matching_rows.iloc[0]['MDA_Text']
        
        if not isinstance(mda_text, str) or not mda_text.strip():
            logger.warning(f"Empty or invalid MDA_Text in matched row")
            return None
        
        logger.info(f"Found matching MDA text (length: {len(mda_text)} chars)")
        
        # Truncate text if too long
        if len(mda_text) > MAX_TEXT_LENGTH:
            logger.warning(f"Text too long ({len(mda_text)} chars), truncating to {MAX_TEXT_LENGTH} chars")
            mda_text = mda_text[:MAX_TEXT_LENGTH]
        
        return mda_text
    
    except Exception as e:
        logger.error(f"Error getting MDA text: {e}")
        return None

# Process a batch of rows
def process_batch(batch_df, mda_df, vader_analyzer, finbert_tokenizer, finbert_model, device):
    """
    Process a batch of rows with both sentiment models
    """
    results = []
    
    for idx, row in batch_df.iterrows():
        try:
            # Find matching MDA text
            mda_text = find_matching_mda_text(row, mda_df)
            
            # Skip if no text
            if not mda_text:
                logger.warning(f"No matching MDA text found for row {idx}, skipping")
                results.append((idx, None, None))
                continue
            
            # Process with VADER
            vader_results = analyze_with_vader(mda_text, vader_analyzer)
            
            # Process with FinBERT
            finbert_results = analyze_with_finbert(mda_text, finbert_tokenizer, finbert_model, device)
            
            # Store results
            results.append((idx, vader_results, finbert_results))
            logger.info(f"Successfully analyzed sentiment for row {idx}")
            
        except Exception as e:
            logger.error(f"Error processing row {idx}: {e}")
            results.append((idx, None, None))
    
    return results

# Find MDA file path
def find_mda_file_path(year):
    """
    Attempt to find the correct MDA file path
    """
    # Default path
    default_path = f"data/mda_data/mda_sections_{year}.csv"
    
    # Check if default path exists
    if os.path.exists(default_path):
        return default_path
    
    # Try alternative paths
    alternatives = [
        f"mda_data/mda_sections_{year}.csv",
        f"data/mda_sections_{year}.csv",
        f"mda_sections_{year}.csv"
    ]
    
    # Check parent directories
    current_dir = os.getcwd()
    parent_dir = os.path.dirname(current_dir)
    
    for alt_path in alternatives:
        # Check in current directory
        if os.path.exists(alt_path):
            return alt_path
        
        # Check in parent directory
        parent_path = os.path.join(parent_dir, alt_path)
        if os.path.exists(parent_path):
            return parent_path
    
    # If we've made it here, try to find any file that might match
    possible_paths = []
    
    # Search patterns
    patterns = [
        f"**/mda_*{year}*.csv",
        f"**/mda*{year}*.csv",
        f"**/*mda*{year}*.csv"
    ]
    
    for pattern in patterns:
        matches = glob.glob(pattern, recursive=True)
        possible_paths.extend(matches)
    
    if possible_paths:
        logger.info(f"Found possible MDA files: {possible_paths}")
        return possible_paths[0]  # Return the first match
    
    return None

# Main function to process the CSV files
def enhance_sentiment_analysis(input_file, output_file, year):
    """
    Add VADER and FinBERT sentiment scores to the input file
    """
    try:
        logger.info(f"Loading input file: {input_file}")
        results_df = pd.read_csv(input_file)
        logger.info(f"Loaded {len(results_df)} rows from {input_file}")
        
        # Find and load MDA file with original text
        mda_file_path = find_mda_file_path(year)
        if not mda_file_path:
            logger.error(f"Could not find MDA file for year {year}")
            return None
        
        logger.info(f"Loading MDA file: {mda_file_path}")
        mda_df = pd.read_csv(mda_file_path)
        logger.info(f"Loaded {len(mda_df)} rows from MDA file")
        
        # Check if MDA_Text column exists in the MDA file
        if 'MDA_Text' not in mda_df.columns:
            logger.error(f"MDA_Text column not found in {mda_file_path}")
            # Try to find an alternative column
            text_columns = [col for col in mda_df.columns if 'text' in col.lower() or 'mda' in col.lower()]
            if not text_columns:
                raise ValueError(f"Could not find text column in {mda_file_path}")
            logger.info(f"Using {text_columns[0]} as the text column")
            mda_df['MDA_Text'] = mda_df[text_columns[0]]
        
        # Standardize date formats in both dataframes for accurate matching
        if 'FiledAt' in results_df.columns:
            logger.info("Standardizing FiledAt dates in results dataframe")
            results_df['FiledAt'] = results_df['FiledAt'].apply(standardize_date_format)
        
        if 'FiledAt' in mda_df.columns:
            logger.info("Standardizing FiledAt dates in MDA dataframe")
            mda_df['FiledAt'] = mda_df['FiledAt'].apply(standardize_date_format)
        
        # Check if VADER and FinBERT columns already exist
        vader_cols = [col for col in results_df.columns if 'vader' in col.lower()]
        finbert_cols = [col for col in results_df.columns if 'finbert' in col.lower()]
        
        if vader_cols and finbert_cols:
            logger.warning(f"VADER and FinBERT columns already exist in {input_file}")
            logger.info(f"VADER columns: {vader_cols}")
            logger.info(f"FinBERT columns: {finbert_cols}")
            overwrite = input("Overwrite existing sentiment columns? (y/n): ").lower() == 'y'
            if not overwrite:
                logger.info("Skipping file")
                return
        
        # Initialize models
        vader_analyzer, finbert_tokenizer, finbert_model, device = initialize_models()
        
        # Process in batches
        batch_indices = [results_df.index[i:i+BATCH_SIZE] for i in range(0, len(results_df), BATCH_SIZE)]
        all_results = []
        
        logger.info(f"Processing {len(batch_indices)} batches")
        
        # Use ThreadPoolExecutor for parallel processing
        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            futures = []
            
            for i, batch_idx in enumerate(batch_indices):
                batch_df = results_df.loc[batch_idx].copy()
                futures.append(executor.submit(
                    process_batch, batch_df, mda_df, vader_analyzer, finbert_tokenizer, finbert_model, device
                ))
                
                # Wait for futures to complete and save intermediate results periodically
                if (i + 1) % SAVE_FREQUENCY == 0 or i == len(batch_indices) - 1:
                    logger.info(f"Waiting for batch {i+1}/{len(batch_indices)} to complete")
                    
                    # Collect completed results
                    completed_futures = [f for f in futures if f.done()]
                    for future in completed_futures:
                        try:
                            batch_results = future.result()
                            all_results.extend(batch_results)
                        except Exception as e:
                            logger.error(f"Error getting future result: {e}")
                    
                    # Clear completed futures
                    futures = [f for f in futures if not f.done()]
                    
                    # Save intermediate results
                    if all_results:
                        temp_df = results_df.copy()
                        for idx, vader_result, finbert_result in all_results:
                            if vader_result:
                                for key, value in vader_result.items():
                                    temp_df.at[idx, key] = value
                            if finbert_result:
                                for key, value in finbert_result.items():
                                    temp_df.at[idx, key] = value
                        
                        temp_output = output_file.replace('.csv', f'_temp_{i+1}.csv')
                        temp_df.to_csv(temp_output, index=False)
                        logger.info(f"Saved intermediate results to {temp_output}")
            
            # Collect remaining results
            for future in futures:
                try:
                    batch_results = future.result()
                    all_results.extend(batch_results)
                except Exception as e:
                    logger.error(f"Error getting future result: {e}")
        
        # Update dataframe with all results (excluding MDA_Text)
        output_df = results_df.copy()
        
        # Remove any existing VADER or FinBERT columns
        for col in vader_cols + finbert_cols:
            if col in output_df.columns:
                output_df = output_df.drop(col, axis=1)
                
        # Add new sentiment scores
        for idx, vader_result, finbert_result in all_results:
            if vader_result:
                for key, value in vader_result.items():
                    output_df.at[idx, key] = value
            if finbert_result:
                for key, value in finbert_result.items():
                    output_df.at[idx, key] = value
        
        # Save final results
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        output_df.to_csv(output_file, index=False)
        logger.info(f"Saved final results to {output_file}")
        
        # Clean up temporary files
        temp_files = [f for f in os.listdir(os.path.dirname(output_file)) 
                     if os.path.basename(f).startswith(os.path.basename(output_file).split('.')[0] + '_temp_')]
        if temp_files and input("Remove temporary files? (y/n): ").lower() == 'y':
            for temp_file in temp_files:
                temp_path = os.path.join(os.path.dirname(output_file), temp_file)
                try:
                    os.remove(temp_path)
                    logger.info(f"Removed {temp_file}")
                except Exception as e:
                    logger.error(f"Could not remove {temp_file}: {e}")
        
        return output_df
        
    except Exception as e:
        logger.error(f"Error processing file {input_file}: {e}")
        import traceback
        logger.error(f"Traceback: {traceback.format_exc()}")
        return None

def main():
    print("\n=== ENHANCING MDA SENTIMENT ANALYSIS WITH VADER AND FINBERT ===")
    
    # Ask user for years to process
    years_input = input("Which years would you like to process? (Enter comma-separated values, e.g., '2023,2024' or 'all' for all years): ")
    
    if years_input.lower() == 'all':
        years = ['2023', '2024']  # Default years
    else:
        years = [year.strip() for year in years_input.split(',')]
    
    # Process each year
    for year in years:
        # Define file paths
        input_file = f"sentiment_results/mda/mda_sentiment_{year}_results_v2.csv"
        output_file = f"sentiment_results/mda/mda_sentiment_{year}_results_v3.csv"
        
        print(f"\n=== PROCESSING YEAR: {year} ===")
        print(f"Input file: {input_file}")
        print(f"Output file: {output_file}")
        
        # Check if input file exists
        if not os.path.exists(input_file):
            print(f"Error: Input file not found: {input_file}")
            # Try alternative paths
            alternatives = [
                f"mda_sentiment_{year}_results_v2.csv",
                f"*sentiment*{year}*v2*.csv"
            ]
            
            found = False
            for alt_pattern in alternatives:
                matches = glob.glob(alt_pattern)
                if matches:
                    input_file = matches[0]
                    print(f"Found alternative input file: {input_file}")
                    found = True
                    break
            
            if not found:
                print("Could not find input file. Skipping year.")
                continue
        
        # Check if MDA file can be found
        mda_file_path = find_mda_file_path(year)
        if not mda_file_path:
            print(f"Error: Could not find MDA data file for year {year}")
            user_path = input(f"Please provide the path to the MDA file for {year} (or press Enter to skip): ")
            if user_path.strip():
                if os.path.exists(user_path):
                    print(f"Using provided MDA file: {user_path}")
                else:
                    print(f"Provided path does not exist: {user_path}")
                    if input("Continue anyway? (y/n): ").lower() != 'y':
                        print(f"Skipping year {year}")
                        continue
            else:
                print(f"Skipping year {year}")
                continue
        else:
            print(f"Found MDA file: {mda_file_path}")
        
        # Ask user to confirm
        confirm = input(f"Process {year}? (y/n): ")
        if confirm.lower() != 'y':
            print(f"Skipping year {year}")
            continue
        
        # Enhance sentiment analysis
        enhance_sentiment_analysis(input_file, output_file, year)
        
        print(f"Completed enhancement for year {year}")

if __name__ == "__main__":
    # Check if required libraries are installed
    try:
        import nltk
        nltk.data.find('vader_lexicon')
    except (ImportError, LookupError):
        print("NLTK VADER lexicon not found. Installing...")
        import nltk
        nltk.download('vader_lexicon')
    
    try:
        import transformers
    except ImportError:
        print("Transformers library not found. Please install it with:")
        print("pip install transformers")
        if input("Continue anyway? (y/n): ").lower() != 'y':
            import sys
            sys.exit(1)
    
    try:
        import torch
    except ImportError:
        print("PyTorch not found. Please install it with:")
        print("pip install torch")
        if input("Continue anyway? (y/n): ").lower() != 'y':
            import sys
            sys.exit(1)
    
    # Run main function
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/nawa/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# NLTK VADER lexicon not found. Installing...
#
# === ENHANCING MDA SENTIMENT ANALYSIS WITH VADER AND FINBERT ===
# Which years would you like to process? (Enter comma-separated values, e.g., '2023,2024' or 'all' for all years):  2024
# === PROCESSING YEAR: 2024 ===
# Input file: sentiment_results/mda/mda_sentiment_2024_results_v2.csv
# Output file: sentiment_results/mda/mda_sentiment_2024_results_v3.csv
# Found MDA file: data/mda_data/mda_sections_2024.csv
# Process 2024? (y/n):  y
# 2025-04-13 16:50:02,668 - INFO - Loading input file: sentiment_results/mda/mda_sentiment_2024_results_v2.csv
# 2025-04-13 16:50:02,688 - INFO - Loaded 1959 rows from sentiment_results/mda/mda_sentiment_2024_results_v2.csv
# 2025-04-13 16:50:02,688 - INFO - Loading MDA file: data/mda_data/mda_sections_2024.csv
# 2025-04-13 16:50:03,534 - INFO - Loaded 1959 rows from MDA file
# 2025-04-13 16:50:03,535 - INFO - Standardizing FiledAt dates in results dataframe
# 2025-04-13 16:50:03,839 - INFO - Standardizing FiledAt dates in MDA dataframe
# 2025-04-13 16:50:04,289 - INFO - Initializing sentiment models...
# 2025-04-13 16:50:04,293 - INFO - Using device: cuda
# 2025-04-13 16:50:04,763 - INFO - Models initialized successfully!
# 2025-04-13 16:50:04,764 - INFO - Processing 392 batches
# 2025-04-13 16:50:04,766 - INFO - Looking for match: Ticker=MMM, CIK=66740, FormType=10-Q, FiledAt=2024-10-22
# 2025-04-13 16:50:04,769 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:04,769 - INFO - Looking for match: Ticker=AOS, CIK=91142, FormType=10-Q, FiledAt=2024-07-24
# 2025-04-13 16:50:04,771 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-Q, FiledAt=2024-05-02
# 2025-04-13 16:50:04,771 - INFO - Looking for match: Ticker=ABBV, CIK=1551152, FormType=10-K, FiledAt=2024-02-20
# 2025-04-13 16:50:04,776 - INFO - Waiting for batch 20/392 to complete
# 2025-04-13 16:50:04,776 - INFO - Found matching MDA text (length: 71554 chars)
# 2025-04-13 16:50:04,778 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:04,780 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:04,782 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:04,788 - INFO - Waiting for batch 40/392 to complete
# 2025-04-13 16:50:04,789 - WARNING - Text too long (71554 chars), truncating to 60000 chars
# 2025-04-13 16:50:04,790 - INFO - Found matching MDA text (length: 29621 chars)
# 2025-04-13 16:50:04,791 - INFO - Found matching MDA text (length: 20943 chars)
# 2025-04-13 16:50:04,792 - INFO - Found matching MDA text (length: 62585 chars)
# 2025-04-13 16:50:04,797 - INFO - Waiting for batch 60/392 to complete
# 2025-04-13 16:50:05,047 - WARNING - Text too long (62585 chars), truncating to 60000 chars
# 2025-04-13 16:50:05,159 - INFO - Waiting for batch 80/392 to complete
# 2025-04-13 16:50:05,285 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:05,455 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:05,477 - INFO - Waiting for batch 100/392 to complete
# 2025-04-13 16:50:05,514 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:05,561 - INFO - Waiting for batch 120/392 to complete
# 2025-04-13 16:50:05,605 - INFO - Waiting for batch 140/392 to complete
# 2025-04-13 16:50:05,659 - INFO - Waiting for batch 160/392 to complete
# 2025-04-13 16:50:05,735 - INFO - Waiting for batch 180/392 to complete
# 2025-04-13 16:50:05,806 - INFO - Waiting for batch 200/392 to complete
# 2025-04-13 16:50:05,820 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:05,832 - INFO - Waiting for batch 220/392 to complete
# 2025-04-13 16:50:05,846 - INFO - Waiting for batch 240/392 to complete
# 2025-04-13 16:50:05,858 - INFO - Waiting for batch 260/392 to complete
# 2025-04-13 16:50:05,870 - INFO - Waiting for batch 280/392 to complete
# 2025-04-13 16:50:05,882 - INFO - Waiting for batch 300/392 to complete
# 2025-04-13 16:50:05,892 - INFO - Waiting for batch 320/392 to complete
# 2025-04-13 16:50:05,902 - INFO - Waiting for batch 340/392 to complete
# 2025-04-13 16:50:05,912 - INFO - Waiting for batch 360/392 to complete
# 2025-04-13 16:50:05,921 - INFO - Waiting for batch 380/392 to complete
# 2025-04-13 16:50:05,926 - INFO - Waiting for batch 392/392 to complete
# 2025-04-13 16:50:05,944 - INFO - Successfully analyzed sentiment for row 15
# 2025-04-13 16:50:05,945 - INFO - Looking for match: Ticker=ACN, CIK=1467373, FormType=10-Q, FiledAt=2024-12-19
# 2025-04-13 16:50:05,947 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:05,948 - INFO - Found matching MDA text (length: 38930 chars)
# 2025-04-13 16:50:05,975 - INFO - Successfully analyzed sentiment for row 0
# 2025-04-13 16:50:06,029 - INFO - Looking for match: Ticker=MMM, CIK=66740, FormType=10-Q, FiledAt=2024-07-26
# 2025-04-13 16:50:06,082 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:06,083 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:06,084 - INFO - Successfully analyzed sentiment for row 10
# 2025-04-13 16:50:06,086 - INFO - Found matching MDA text (length: 71830 chars)
# 2025-04-13 16:50:06,087 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-K, FiledAt=2024-02-16
# 2025-04-13 16:50:06,087 - WARNING - Text too long (71830 chars), truncating to 60000 chars
# 2025-04-13 16:50:06,088 - INFO - Successfully analyzed sentiment for row 5
# 2025-04-13 16:50:06,090 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:06,154 - INFO - Looking for match: Ticker=AOS, CIK=91142, FormType=10-Q, FiledAt=2024-04-26
# 2025-04-13 16:50:06,228 - INFO - Found matching MDA text (length: 78127 chars)
# 2025-04-13 16:50:06,305 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:06,306 - WARNING - Text too long (78127 chars), truncating to 60000 chars
# 2025-04-13 16:50:06,350 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:06,352 - INFO - Found matching MDA text (length: 23572 chars)
# 2025-04-13 16:50:06,733 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:06,905 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:06,931 - INFO - Successfully analyzed sentiment for row 16
# 2025-04-13 16:50:06,932 - INFO - Looking for match: Ticker=ACN, CIK=1467373, FormType=10-K, FiledAt=2024-10-10
# 2025-04-13 16:50:06,936 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:06,938 - INFO - Found matching MDA text (length: 47475 chars)
# 2025-04-13 16:50:06,939 - INFO - Successfully analyzed sentiment for row 11
# 2025-04-13 16:50:06,955 - INFO - Looking for match: Ticker=ABBV, CIK=1551152, FormType=10-Q, FiledAt=2024-11-04
# 2025-04-13 16:50:06,984 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:06,995 - INFO - Found matching MDA text (length: 42750 chars)
# 2025-04-13 16:50:07,347 - INFO - Successfully analyzed sentiment for row 1
# 2025-04-13 16:50:07,369 - INFO - Looking for match: Ticker=MMM, CIK=66740, FormType=10-Q, FiledAt=2024-04-30
# 2025-04-13 16:50:07,415 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:07,447 - INFO - Found matching MDA text (length: 59663 chars)
# 2025-04-13 16:50:07,549 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:07,780 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:07,791 - INFO - Successfully analyzed sentiment for row 6
# 2025-04-13 16:50:07,846 - INFO - Looking for match: Ticker=AOS, CIK=91142, FormType=10-K, FiledAt=2024-02-13
# 2025-04-13 16:50:07,897 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:07,914 - INFO - Found matching MDA text (length: 34435 chars)
# 2025-04-13 16:50:07,977 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:08,129 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:08,156 - INFO - Successfully analyzed sentiment for row 7
# 2025-04-13 16:50:08,157 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-Q, FiledAt=2024-10-31
# 2025-04-13 16:50:08,160 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:08,161 - INFO - Found matching MDA text (length: 27679 chars)
# 2025-04-13 16:50:08,248 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:08,249 - INFO - Successfully analyzed sentiment for row 12
# 2025-04-13 16:50:08,251 - INFO - Looking for match: Ticker=ABBV, CIK=1551152, FormType=10-Q, FiledAt=2024-08-07
# 2025-04-13 16:50:08,254 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:08,255 - INFO - Found matching MDA text (length: 37967 chars)
# 2025-04-13 16:50:08,341 - INFO - Successfully analyzed sentiment for row 17
# 2025-04-13 16:50:08,390 - INFO - Looking for match: Ticker=ACN, CIK=1467373, FormType=10-Q, FiledAt=2024-06-20
# 2025-04-13 16:50:08,434 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:08,439 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:08,441 - INFO - Successfully analyzed sentiment for row 2
# 2025-04-13 16:50:08,442 - INFO - Found matching MDA text (length: 48297 chars)
# 2025-04-13 16:50:08,443 - INFO - Looking for match: Ticker=MMM, CIK=66740, FormType=10-K, FiledAt=2024-02-07
# 2025-04-13 16:50:08,478 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:08,511 - INFO - Found matching MDA text (length: 89577 chars)
# 2025-04-13 16:50:08,559 - WARNING - Text too long (89577 chars), truncating to 60000 chars
# 2025-04-13 16:50:08,687 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:08,906 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:08,924 - INFO - Successfully analyzed sentiment for row 8
# 2025-04-13 16:50:08,926 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-Q, FiledAt=2024-07-31
# 2025-04-13 16:50:08,929 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:08,931 - INFO - Found matching MDA text (length: 26386 chars)
# 2025-04-13 16:50:08,957 - INFO - Successfully analyzed sentiment for row 18
# 2025-04-13 16:50:09,010 - INFO - Looking for match: Ticker=ACN, CIK=1467373, FormType=10-Q, FiledAt=2024-03-21
# 2025-04-13 16:50:09,041 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:09,044 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,046 - INFO - Successfully analyzed sentiment for row 3
# 2025-04-13 16:50:09,047 - INFO - Found matching MDA text (length: 47882 chars)
# 2025-04-13 16:50:09,048 - INFO - Looking for match: Ticker=AOS, CIK=91142, FormType=10-Q, FiledAt=2024-10-23
# 2025-04-13 16:50:09,076 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,103 - INFO - Found matching MDA text (length: 31566 chars)
# 2025-04-13 16:50:09,337 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:09,421 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:09,424 - INFO - Successfully analyzed sentiment for row 13
# 2025-04-13 16:50:09,425 - INFO - Looking for match: Ticker=ABBV, CIK=1551152, FormType=10-Q, FiledAt=2024-05-03
# 2025-04-13 16:50:09,429 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,431 - INFO - Found matching MDA text (length: 30700 chars)
# 2025-04-13 16:50:09,571 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:09,589 - INFO - Successfully analyzed sentiment for row 4
# 2025-04-13 16:50:09,591 - INFO - Looking for match: Ticker=ADBE, CIK=796343, FormType=10-Q, FiledAt=2024-09-25
# 2025-04-13 16:50:09,592 - INFO - Successfully analyzed sentiment for row 19
# 2025-04-13 16:50:09,593 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,594 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-Q, FiledAt=2024-07-31
# 2025-04-13 16:50:09,595 - INFO - Found matching MDA text (length: 49592 chars)
# 2025-04-13 16:50:09,596 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,634 - INFO - Found matching MDA text (length: 26203 chars)
# 2025-04-13 16:50:09,772 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:09,810 - INFO - Successfully analyzed sentiment for row 9
# 2025-04-13 16:50:09,823 - INFO - Looking for match: Ticker=AES, CIK=874761, FormType=10-Q, FiledAt=2024-05-02
# 2025-04-13 16:50:09,881 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:09,882 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,884 - INFO - Found matching MDA text (length: 115327 chars)
# 2025-04-13 16:50:09,885 - WARNING - Text too long (115327 chars), truncating to 60000 chars
# 2025-04-13 16:50:09,890 - INFO - Successfully analyzed sentiment for row 14
# 2025-04-13 16:50:09,907 - INFO - Looking for match: Ticker=AFL, CIK=4977, FormType=10-K, FiledAt=2024-02-22
# 2025-04-13 16:50:09,935 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:09,995 - INFO - Found matching MDA text (length: 160136 chars)
# 2025-04-13 16:50:10,042 - WARNING - Text too long (160136 chars), truncating to 60000 chars
# 2025-04-13 16:50:10,279 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:10,390 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:10,413 - INFO - Successfully analyzed sentiment for row 25
# 2025-04-13 16:50:10,415 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-Q, FiledAt=2024-05-01
# 2025-04-13 16:50:10,417 - INFO - Successfully analyzed sentiment for row 35
# 2025-04-13 16:50:10,419 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:10,419 - INFO - Looking for match: Ticker=A, CIK=1090872, FormType=10-K, FiledAt=2024-12-19
# 2025-04-13 16:50:10,421 - INFO - Found matching MDA text (length: 22653 chars)
# 2025-04-13 16:50:10,423 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:10,441 - INFO - Found matching MDA text (length: 109212 chars)
# 2025-04-13 16:50:10,447 - WARNING - Text too long (109212 chars), truncating to 60000 chars
# 2025-04-13 16:50:10,624 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:10,642 - INFO - Successfully analyzed sentiment for row 20
# 2025-04-13 16:50:10,691 - INFO - Looking for match: Ticker=ADBE, CIK=796343, FormType=10-Q, FiledAt=2024-06-26
# 2025-04-13 16:50:10,709 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:10,742 - INFO - Found matching MDA text (length: 48385 chars)
# 2025-04-13 16:50:10,858 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:11,059 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:11,060 - INFO - Successfully analyzed sentiment for row 30
# 2025-04-13 16:50:11,063 - INFO - Looking for match: Ticker=AES, CIK=874761, FormType=10-K, FiledAt=2024-02-26
# 2025-04-13 16:50:11,066 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:11,067 - INFO - Found matching MDA text (length: 134484 chars)
# 2025-04-13 16:50:11,068 - WARNING - Text too long (134484 chars), truncating to 60000 chars
# 2025-04-13 16:50:11,332 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:11,359 - INFO - Successfully analyzed sentiment for row 31
# 2025-04-13 16:50:11,360 - INFO - Successfully analyzed sentiment for row 26
# 2025-04-13 16:50:11,361 - INFO - Looking for match: Ticker=AFL, CIK=4977, FormType=10-Q, FiledAt=2024-11-01
# 2025-04-13 16:50:11,362 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-K, FiledAt=2024-01-31
# 2025-04-13 16:50:11,363 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:11,364 - INFO - Successfully analyzed sentiment for row 36
# 2025-04-13 16:50:11,366 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:11,367 - INFO - Found matching MDA text (length: 126692 chars)
# 2025-04-13 16:50:11,369 - INFO - Looking for match: Ticker=A, CIK=1090872, FormType=10-Q, FiledAt=2024-08-29
# 2025-04-13 16:50:11,370 - INFO - Found matching MDA text (length: 35280 chars)
# 2025-04-13 16:50:11,371 - WARNING - Text too long (126692 chars), truncating to 60000 chars
# 2025-04-13 16:50:11,371 - INFO - Successfully analyzed sentiment for row 21
# 2025-04-13 16:50:11,395 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:11,504 - INFO - Looking for match: Ticker=ADBE, CIK=796343, FormType=10-Q, FiledAt=2024-03-27
# 2025-04-13 16:50:11,571 - INFO - Found matching MDA text (length: 75262 chars)
# 2025-04-13 16:50:11,631 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:11,720 - WARNING - Text too long (75262 chars), truncating to 60000 chars
# 2025-04-13 16:50:11,758 - INFO - Found matching MDA text (length: 45755 chars)
# 2025-04-13 16:50:11,786 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:12,017 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:12,727 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:12,751 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:12,783 - INFO - Successfully analyzed sentiment for row 32
# 2025-04-13 16:50:12,785 - INFO - Looking for match: Ticker=AFL, CIK=4977, FormType=10-Q, FiledAt=2024-08-01
# 2025-04-13 16:50:12,789 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:12,791 - INFO - Found matching MDA text (length: 124489 chars)
# 2025-04-13 16:50:12,792 - INFO - Successfully analyzed sentiment for row 27
# 2025-04-13 16:50:12,792 - WARNING - Text too long (124489 chars), truncating to 60000 chars
# 2025-04-13 16:50:12,794 - INFO - Looking for match: Ticker=AES, CIK=874761, FormType=10-Q, FiledAt=2024-10-31
# 2025-04-13 16:50:12,794 - INFO - Successfully analyzed sentiment for row 37
# 2025-04-13 16:50:12,831 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:12,853 - INFO - Looking for match: Ticker=A, CIK=1090872, FormType=10-Q, FiledAt=2024-05-31
# 2025-04-13 16:50:12,909 - INFO - Found matching MDA text (length: 142371 chars)
# 2025-04-13 16:50:12,955 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:12,967 - WARNING - Text too long (142371 chars), truncating to 60000 chars
# 2025-04-13 16:50:13,004 - INFO - Successfully analyzed sentiment for row 22
# 2025-04-13 16:50:13,054 - INFO - Found matching MDA text (length: 69840 chars)
# 2025-04-13 16:50:13,071 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:13,145 - INFO - Looking for match: Ticker=ADBE, CIK=796343, FormType=10-K, FiledAt=2024-01-16
# 2025-04-13 16:50:13,248 - WARNING - Text too long (69840 chars), truncating to 60000 chars
# 2025-04-13 16:50:13,322 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:13,327 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:13,415 - INFO - Found matching MDA text (length: 49916 chars)
# 2025-04-13 16:50:13,736 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:13,866 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:13,889 - INFO - Successfully analyzed sentiment for row 23
# 2025-04-13 16:50:13,891 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-Q, FiledAt=2024-10-30
# 2025-04-13 16:50:13,893 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:13,894 - INFO - Found matching MDA text (length: 28941 chars)
# 2025-04-13 16:50:13,982 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:13,990 - INFO - Successfully analyzed sentiment for row 28
# 2025-04-13 16:50:13,991 - INFO - Looking for match: Ticker=AES, CIK=874761, FormType=10-Q, FiledAt=2024-08-01
# 2025-04-13 16:50:13,994 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:13,997 - INFO - Found matching MDA text (length: 134643 chars)
# 2025-04-13 16:50:13,997 - WARNING - Text too long (134643 chars), truncating to 60000 chars
# 2025-04-13 16:50:13,997 - INFO - Successfully analyzed sentiment for row 38
# 2025-04-13 16:50:13,998 - INFO - Successfully analyzed sentiment for row 33
# 2025-04-13 16:50:14,019 - INFO - Looking for match: Ticker=A, CIK=1090872, FormType=10-Q, FiledAt=2024-03-04
# 2025-04-13 16:50:14,031 - INFO - Looking for match: Ticker=AFL, CIK=4977, FormType=10-Q, FiledAt=2024-05-02
# 2025-04-13 16:50:14,112 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:14,150 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:14,245 - INFO - Found matching MDA text (length: 56579 chars)
# 2025-04-13 16:50:14,266 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:14,267 - INFO - Found matching MDA text (length: 113245 chars)
# 2025-04-13 16:50:14,322 - WARNING - Text too long (113245 chars), truncating to 60000 chars
# 2025-04-13 16:50:14,961 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:15,048 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:15,062 - INFO - Successfully analyzed sentiment for row 24
# 2025-04-13 16:50:15,064 - INFO - Looking for match: Ticker=APD, CIK=2969, FormType=10-K, FiledAt=2024-11-21
# 2025-04-13 16:50:15,069 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:15,070 - INFO - Found matching MDA text (length: 93725 chars)
# 2025-04-13 16:50:15,071 - WARNING - Text too long (93725 chars), truncating to 60000 chars
# 2025-04-13 16:50:15,330 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:15,339 - INFO - Successfully analyzed sentiment for row 29
# 2025-04-13 16:50:15,340 - INFO - Looking for match: Ticker=ABNB, CIK=1559720, FormType=10-Q, FiledAt=2024-08-06
# 2025-04-13 16:50:15,344 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:15,345 - INFO - Successfully analyzed sentiment for row 34
# 2025-04-13 16:50:15,345 - INFO - Found matching MDA text (length: 36653 chars)
# 2025-04-13 16:50:15,347 - INFO - Looking for match: Ticker=AKAM, CIK=1086222, FormType=10-Q, FiledAt=2024-05-09
# 2025-04-13 16:50:15,407 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:15,461 - INFO - Found matching MDA text (length: 55199 chars)
# 2025-04-13 16:50:15,538 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:15,740 - INFO - Successfully analyzed sentiment for row 39
# 2025-04-13 16:50:15,754 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:15,757 - INFO - Looking for match: Ticker=ALB, CIK=915913, FormType=10-K, FiledAt=2024-02-14
# 2025-04-13 16:50:15,762 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:15,763 - INFO - Found matching MDA text (length: 138089 chars)
# 2025-04-13 16:50:15,764 - WARNING - Text too long (138089 chars), truncating to 60000 chars
# 2025-04-13 16:50:16,028 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:16,036 - INFO - Successfully analyzed sentiment for row 40
# 2025-04-13 16:50:16,038 - INFO - Looking for match: Ticker=APD, CIK=2969, FormType=10-Q, FiledAt=2024-08-01
# 2025-04-13 16:50:16,041 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:16,042 - INFO - Found matching MDA text (length: 71344 chars)
# 2025-04-13 16:50:16,044 - WARNING - Text too long (71344 chars), truncating to 60000 chars
# 2025-04-13 16:50:16,296 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:16,304 - INFO - Successfully analyzed sentiment for row 50
# 2025-04-13 16:50:16,306 - INFO - Looking for match: Ticker=AKAM, CIK=1086222, FormType=10-K, FiledAt=2024-02-28
# 2025-04-13 16:50:16,309 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:16,310 - INFO - Found matching MDA text (length: 85545 chars)
# 2025-04-13 16:50:16,312 - WARNING - Text too long (85545 chars), truncating to 60000 chars
# 2025-04-13 16:50:16,318 - INFO - Successfully analyzed sentiment for row 45
# 2025-04-13 16:50:16,372 - INFO - Looking for match: Ticker=ABNB, CIK=1559720, FormType=10-Q, FiledAt=2024-05-08
# 2025-04-13 16:50:16,439 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:16,532 - INFO - Found matching MDA text (length: 31236 chars)
# 2025-04-13 16:50:16,583 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:16,727 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:16,728 - INFO - Successfully analyzed sentiment for row 55
# 2025-04-13 16:50:16,730 - INFO - Looking for match: Ticker=ARE, CIK=1035443, FormType=10-Q, FiledAt=2024-10-21
# 2025-04-13 16:50:16,734 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:16,735 - INFO - Found matching MDA text (length: 229744 chars)
# 2025-04-13 16:50:16,736 - WARNING - Text too long (229744 chars), truncating to 60000 chars
# 2025-04-13 16:50:17,018 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:17,031 - INFO - Successfully analyzed sentiment for row 41
# 2025-04-13 16:50:17,033 - INFO - Looking for match: Ticker=APD, CIK=2969, FormType=10-Q, FiledAt=2024-04-30
# 2025-04-13 16:50:17,037 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:17,039 - INFO - Found matching MDA text (length: 67737 chars)
# 2025-04-13 16:50:17,041 - WARNING - Text too long (67737 chars), truncating to 60000 chars
# 2025-04-13 16:50:17,303 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:17,306 - INFO - Successfully analyzed sentiment for row 56
# 2025-04-13 16:50:17,307 - INFO - Looking for match: Ticker=ARE, CIK=1035443, FormType=10-Q, FiledAt=2024-07-22
# 2025-04-13 16:50:17,309 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:17,310 - INFO - Found matching MDA text (length: 215093 chars)
# 2025-04-13 16:50:17,311 - WARNING - Text too long (215093 chars), truncating to 60000 chars
# 2025-04-13 16:50:17,373 - INFO - Successfully analyzed sentiment for row 46
# 2025-04-13 16:50:17,401 - INFO - Looking for match: Ticker=ABNB, CIK=1559720, FormType=10-K, FiledAt=2024-02-16
# 2025-04-13 16:50:17,451 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:17,488 - INFO - Found matching MDA text (length: 49128 chars)
# 2025-04-13 16:50:17,689 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:17,800 - INFO - Successfully analyzed sentiment for row 51
# 2025-04-13 16:50:17,833 - INFO - Looking for match: Ticker=ALB, CIK=915913, FormType=10-Q, FiledAt=2024-11-06
# 2025-04-13 16:50:17,848 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:17,852 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:17,855 - INFO - Found matching MDA text (length: 97858 chars)
# 2025-04-13 16:50:17,857 - WARNING - Text too long (97858 chars), truncating to 60000 chars
# 2025-04-13 16:50:18,123 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:18,144 - INFO - Successfully analyzed sentiment for row 42
# 2025-04-13 16:50:18,146 - INFO - Looking for match: Ticker=APD, CIK=2969, FormType=10-Q, FiledAt=2024-02-05
# 2025-04-13 16:50:18,149 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:18,151 - INFO - Found matching MDA text (length: 45904 chars)
# 2025-04-13 16:50:18,251 - INFO - Successfully analyzed sentiment for row 52
# 2025-04-13 16:50:18,283 - INFO - Looking for match: Ticker=ALB, CIK=915913, FormType=10-Q, FiledAt=2024-07-31
# 2025-04-13 16:50:18,329 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:18,354 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:18,355 - INFO - Found matching MDA text (length: 98260 chars)
# 2025-04-13 16:50:18,357 - WARNING - Text too long (98260 chars), truncating to 60000 chars
# 2025-04-13 16:50:18,554 - INFO - Successfully analyzed sentiment for row 57
# 2025-04-13 16:50:18,592 - INFO - Looking for match: Ticker=ARE, CIK=1035443, FormType=10-Q, FiledAt=2024-04-22
# 2025-04-13 16:50:18,622 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:18,623 - INFO - Successfully analyzed sentiment for row 47
# 2025-04-13 16:50:18,625 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:18,627 - INFO - Looking for match: Ticker=AKAM, CIK=1086222, FormType=10-Q, FiledAt=2024-11-08
# 2025-04-13 16:50:18,629 - INFO - Found matching MDA text (length: 188130 chars)
# 2025-04-13 16:50:18,633 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:18,634 - WARNING - Text too long (188130 chars), truncating to 60000 chars
# 2025-04-13 16:50:18,635 - INFO - Found matching MDA text (length: 62821 chars)
# 2025-04-13 16:50:18,671 - WARNING - Text too long (62821 chars), truncating to 60000 chars
# 2025-04-13 16:50:19,156 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:19,283 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:19,306 - INFO - Successfully analyzed sentiment for row 43
# 2025-04-13 16:50:19,308 - INFO - Looking for match: Ticker=ABNB, CIK=1559720, FormType=10-Q, FiledAt=2024-11-07
# 2025-04-13 16:50:19,311 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:19,313 - INFO - Successfully analyzed sentiment for row 53
# 2025-04-13 16:50:19,313 - INFO - Found matching MDA text (length: 38646 chars)
# 2025-04-13 16:50:19,315 - INFO - Looking for match: Ticker=ALB, CIK=915913, FormType=10-Q, FiledAt=2024-05-01
# 2025-04-13 16:50:19,315 - INFO - Successfully analyzed sentiment for row 58
# 2025-04-13 16:50:19,336 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:19,373 - INFO - Looking for match: Ticker=ARE, CIK=1035443, FormType=10-K, FiledAt=2024-01-29
# 2025-04-13 16:50:19,423 - INFO - Found matching MDA text (length: 81154 chars)
# 2025-04-13 16:50:19,473 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:19,488 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:19,489 - WARNING - Text too long (81154 chars), truncating to 60000 chars
# 2025-04-13 16:50:19,491 - INFO - Found matching MDA text (length: 195949 chars)
# 2025-04-13 16:50:19,548 - WARNING - Text too long (195949 chars), truncating to 60000 chars
# 2025-04-13 16:50:19,864 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:20,077 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:20,078 - INFO - Successfully analyzed sentiment for row 48
# 2025-04-13 16:50:20,080 - INFO - Looking for match: Ticker=AKAM, CIK=1086222, FormType=10-Q, FiledAt=2024-08-08
# 2025-04-13 16:50:20,083 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:20,084 - INFO - Found matching MDA text (length: 59700 chars)
# 2025-04-13 16:50:20,345 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:20,359 - INFO - Successfully analyzed sentiment for row 59
# 2025-04-13 16:50:20,360 - INFO - Looking for match: Ticker=ALGN, CIK=1097149, FormType=10-Q, FiledAt=2024-11-05
# 2025-04-13 16:50:20,362 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:20,363 - INFO - Found matching MDA text (length: 44098 chars)
# 2025-04-13 16:50:20,513 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:20,517 - INFO - Successfully analyzed sentiment for row 44
# 2025-04-13 16:50:20,519 - INFO - Looking for match: Ticker=ALLE, CIK=1579241, FormType=10-Q, FiledAt=2024-07-24
# 2025-04-13 16:50:20,523 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:20,523 - INFO - Successfully analyzed sentiment for row 49
# 2025-04-13 16:50:20,524 - INFO - Found matching MDA text (length: 43992 chars)
# 2025-04-13 16:50:20,525 - INFO - Looking for match: Ticker=LNT, CIK=352541, FormType=10-Q, FiledAt=2024-05-03
# 2025-04-13 16:50:20,560 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:20,609 - INFO - Found matching MDA text (length: 21706 chars)
# 2025-04-13 16:50:20,795 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:20,859 - INFO - Successfully analyzed sentiment for row 54
# 2025-04-13 16:50:20,860 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:20,861 - INFO - Looking for match: Ticker=ALL, CIK=899051, FormType=10-K, FiledAt=2024-02-21
# 2025-04-13 16:50:20,865 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:20,866 - INFO - Found matching MDA text (length: 241283 chars)
# 2025-04-13 16:50:20,868 - WARNING - Text too long (241283 chars), truncating to 60000 chars
# 2025-04-13 16:50:21,134 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:21,152 - INFO - Successfully analyzed sentiment for row 60
# 2025-04-13 16:50:21,154 - INFO - Looking for match: Ticker=ALGN, CIK=1097149, FormType=10-Q, FiledAt=2024-08-02
# 2025-04-13 16:50:21,157 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:21,157 - INFO - Successfully analyzed sentiment for row 75
# 2025-04-13 16:50:21,159 - INFO - Found matching MDA text (length: 43371 chars)
# 2025-04-13 16:50:21,159 - INFO - Looking for match: Ticker=GOOGL, CIK=1652044, FormType=10-Q, FiledAt=2024-10-29
# 2025-04-13 16:50:21,178 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:21,204 - INFO - Found matching MDA text (length: 53554 chars)
# 2025-04-13 16:50:21,348 - INFO - Successfully analyzed sentiment for row 70
# 2025-04-13 16:50:21,414 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:21,419 - INFO - Looking for match: Ticker=LNT, CIK=352541, FormType=10-K, FiledAt=2024-02-16
# 2025-04-13 16:50:21,473 - INFO - Successfully analyzed sentiment for row 65
# 2025-04-13 16:50:21,507 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:21,540 - INFO - Looking for match: Ticker=ALLE, CIK=1579241, FormType=10-Q, FiledAt=2024-04-25
# 2025-04-13 16:50:21,572 - INFO - Found matching MDA text (length: 87879 chars)
# 2025-04-13 16:50:21,615 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:21,618 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:21,619 - WARNING - Text too long (87879 chars), truncating to 60000 chars
# 2025-04-13 16:50:21,621 - INFO - Found matching MDA text (length: 36532 chars)
# 2025-04-13 16:50:22,006 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:22,104 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:22,129 - INFO - Successfully analyzed sentiment for row 66
# 2025-04-13 16:50:22,130 - INFO - Looking for match: Ticker=ALLE, CIK=1579241, FormType=10-K, FiledAt=2024-02-20
# 2025-04-13 16:50:22,132 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:22,132 - INFO - Found matching MDA text (length: 55904 chars)
# 2025-04-13 16:50:22,222 - INFO - Successfully analyzed sentiment for row 61
# 2025-04-13 16:50:22,239 - INFO - Looking for match: Ticker=ALGN, CIK=1097149, FormType=10-Q, FiledAt=2024-05-03
# 2025-04-13 16:50:22,306 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:22,334 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:22,335 - INFO - Found matching MDA text (length: 36738 chars)
# 2025-04-13 16:50:22,391 - INFO - Successfully analyzed sentiment for row 76
# 2025-04-13 16:50:22,428 - INFO - Looking for match: Ticker=GOOGL, CIK=1652044, FormType=10-Q, FiledAt=2024-07-23
# 2025-04-13 16:50:22,500 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:22,505 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:22,506 - INFO - Found matching MDA text (length: 51726 chars)
# 2025-04-13 16:50:22,731 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:22,735 - INFO - Successfully analyzed sentiment for row 71
# 2025-04-13 16:50:22,737 - INFO - Looking for match: Ticker=ALL, CIK=899051, FormType=10-Q, FiledAt=2024-10-30
# 2025-04-13 16:50:22,740 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:22,742 - INFO - Found matching MDA text (length: 92910 chars)
# 2025-04-13 16:50:22,743 - WARNING - Text too long (92910 chars), truncating to 60000 chars
# 2025-04-13 16:50:23,011 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:23,030 - INFO - Successfully analyzed sentiment for row 67
# 2025-04-13 16:50:23,031 - INFO - Looking for match: Ticker=LNT, CIK=352541, FormType=10-Q, FiledAt=2024-11-01
# 2025-04-13 16:50:23,031 - INFO - Successfully analyzed sentiment for row 62
# 2025-04-13 16:50:23,035 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:23,035 - INFO - Looking for match: Ticker=ALGN, CIK=1097149, FormType=10-K, FiledAt=2024-02-28
# 2025-04-13 16:50:23,036 - INFO - Found matching MDA text (length: 46281 chars)
# 2025-04-13 16:50:23,039 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:23,051 - INFO - Successfully analyzed sentiment for row 77
# 2025-04-13 16:50:23,088 - INFO - Found matching MDA text (length: 47256 chars)
# 2025-04-13 16:50:23,120 - INFO - Looking for match: Ticker=GOOGL, CIK=1652044, FormType=10-Q, FiledAt=2024-04-25
# 2025-04-13 16:50:23,192 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:23,276 - INFO - Found matching MDA text (length: 46149 chars)
# 2025-04-13 16:50:23,297 - INFO - Successfully analyzed sentiment for row 72
# 2025-04-13 16:50:23,350 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:23,461 - INFO - Looking for match: Ticker=ALL, CIK=899051, FormType=10-Q, FiledAt=2024-07-31
# 2025-04-13 16:50:23,538 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:23,591 - INFO - Found matching MDA text (length: 90057 chars)
# 2025-04-13 16:50:23,665 - WARNING - Text too long (90057 chars), truncating to 60000 chars
# 2025-04-13 16:50:23,940 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:24,265 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:24,384 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:24,410 - INFO - Successfully analyzed sentiment for row 73
# 2025-04-13 16:50:24,411 - INFO - Looking for match: Ticker=ALL, CIK=899051, FormType=10-Q, FiledAt=2024-05-01
# 2025-04-13 16:50:24,413 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:24,414 - INFO - Found matching MDA text (length: 80350 chars)
# 2025-04-13 16:50:24,414 - WARNING - Text too long (80350 chars), truncating to 60000 chars
# 2025-04-13 16:50:24,495 - INFO - Successfully analyzed sentiment for row 68
# 2025-04-13 16:50:24,533 - INFO - Looking for match: Ticker=LNT, CIK=352541, FormType=10-Q, FiledAt=2024-08-02
# 2025-04-13 16:50:24,548 - INFO - Successfully analyzed sentiment for row 63
# 2025-04-13 16:50:24,622 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:24,649 - INFO - Successfully analyzed sentiment for row 78
# 2025-04-13 16:50:24,652 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:24,653 - INFO - Looking for match: Ticker=ALLE, CIK=1579241, FormType=10-Q, FiledAt=2024-10-24
# 2025-04-13 16:50:24,654 - INFO - Found matching MDA text (length: 34876 chars)
# 2025-04-13 16:50:24,655 - INFO - Looking for match: Ticker=GOOGL, CIK=1652044, FormType=10-K, FiledAt=2024-01-30
# 2025-04-13 16:50:24,659 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:24,708 - INFO - Found matching MDA text (length: 45329 chars)
# 2025-04-13 16:50:24,720 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:24,801 - INFO - Found matching MDA text (length: 60815 chars)
# 2025-04-13 16:50:24,849 - WARNING - Text too long (60815 chars), truncating to 60000 chars
# 2025-04-13 16:50:24,884 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:25,078 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:25,291 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:25,319 - INFO - Successfully analyzed sentiment for row 79
# 2025-04-13 16:50:25,321 - INFO - Looking for match: Ticker=GOOG, CIK=1652044, FormType=10-Q, FiledAt=2024-10-29
# 2025-04-13 16:50:25,323 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:25,324 - INFO - Found matching MDA text (length: 53554 chars)
# 2025-04-13 16:50:25,366 - INFO - Successfully analyzed sentiment for row 74
# 2025-04-13 16:50:25,450 - INFO - Looking for match: Ticker=MO, CIK=764180, FormType=10-Q, FiledAt=2024-07-31
# 2025-04-13 16:50:25,516 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:25,519 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:25,520 - INFO - Found matching MDA text (length: 150866 chars)
# 2025-04-13 16:50:25,523 - WARNING - Text too long (150866 chars), truncating to 60000 chars
# 2025-04-13 16:50:25,770 - INFO - Successfully analyzed sentiment for row 69
# 2025-04-13 16:50:25,787 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:25,788 - INFO - Successfully analyzed sentiment for row 64
# 2025-04-13 16:50:25,788 - INFO - Looking for match: Ticker=AMZN, CIK=1018724, FormType=10-Q, FiledAt=2024-04-30
# 2025-04-13 16:50:25,791 - INFO - Looking for match: Ticker=AMCR, CIK=1748790, FormType=10-Q, FiledAt=2024-02-07
# 2025-04-13 16:50:25,795 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:25,798 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:25,798 - INFO - Found matching MDA text (length: 39348 chars)
# 2025-04-13 16:50:25,800 - INFO - Found matching MDA text (length: 43163 chars)
# 2025-04-13 16:50:26,282 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:26,363 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:26,389 - INFO - Successfully analyzed sentiment for row 80
# 2025-04-13 16:50:26,391 - INFO - Looking for match: Ticker=GOOG, CIK=1652044, FormType=10-Q, FiledAt=2024-07-23
# 2025-04-13 16:50:26,394 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:26,395 - INFO - Found matching MDA text (length: 51726 chars)
# 2025-04-13 16:50:26,450 - INFO - Successfully analyzed sentiment for row 85
# 2025-04-13 16:50:26,462 - INFO - Looking for match: Ticker=MO, CIK=764180, FormType=10-Q, FiledAt=2024-04-25
# 2025-04-13 16:50:26,501 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:26,545 - INFO - Found matching MDA text (length: 129841 chars)
# 2025-04-13 16:50:26,577 - WARNING - Text too long (129841 chars), truncating to 60000 chars
# 2025-04-13 16:50:26,597 - INFO - Successfully analyzed sentiment for row 95
# 2025-04-13 16:50:26,619 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:26,654 - INFO - Looking for match: Ticker=AEE, CIK=1002910, FormType=10-Q, FiledAt=2024-11-07
# 2025-04-13 16:50:26,765 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:26,845 - INFO - Found matching MDA text (length: 164143 chars)
# 2025-04-13 16:50:26,894 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:26,894 - WARNING - Text too long (164143 chars), truncating to 60000 chars
# 2025-04-13 16:50:26,964 - INFO - Successfully analyzed sentiment for row 90
# 2025-04-13 16:50:27,080 - INFO - Looking for match: Ticker=AMZN, CIK=1018724, FormType=10-K, FiledAt=2024-02-01
# 2025-04-13 16:50:27,109 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:27,159 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:27,159 - INFO - Found matching MDA text (length: 48215 chars)
# 2025-04-13 16:50:27,356 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:27,384 - INFO - Successfully analyzed sentiment for row 81
# 2025-04-13 16:50:27,386 - INFO - Looking for match: Ticker=GOOG, CIK=1652044, FormType=10-Q, FiledAt=2024-04-25
# 2025-04-13 16:50:27,389 - INFO - Successfully analyzed sentiment for row 86
# 2025-04-13 16:50:27,390 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:27,391 - INFO - Successfully analyzed sentiment for row 91
# 2025-04-13 16:50:27,392 - INFO - Looking for match: Ticker=MO, CIK=764180, FormType=10-K, FiledAt=2024-02-27
# 2025-04-13 16:50:27,393 - INFO - Found matching MDA text (length: 46149 chars)
# 2025-04-13 16:50:27,394 - INFO - Looking for match: Ticker=AMCR, CIK=1748790, FormType=10-Q, FiledAt=2024-11-01
# 2025-04-13 16:50:27,408 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:27,420 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:27,437 - INFO - Found matching MDA text (length: 150936 chars)
# 2025-04-13 16:50:27,469 - INFO - Found matching MDA text (length: 31846 chars)
# 2025-04-13 16:50:27,522 - WARNING - Text too long (150936 chars), truncating to 60000 chars
# 2025-04-13 16:50:27,689 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:27,815 - INFO - Successfully analyzed sentiment for row 96
# 2025-04-13 16:50:27,910 - INFO - Looking for match: Ticker=AEE, CIK=1002910, FormType=10-Q, FiledAt=2024-08-05
# 2025-04-13 16:50:27,986 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:28,020 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:28,031 - INFO - Found matching MDA text (length: 158289 chars)
# 2025-04-13 16:50:28,106 - WARNING - Text too long (158289 chars), truncating to 60000 chars
# 2025-04-13 16:50:28,185 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:28,439 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:28,469 - INFO - Successfully analyzed sentiment for row 97
# 2025-04-13 16:50:28,470 - INFO - Successfully analyzed sentiment for row 82
# 2025-04-13 16:50:28,471 - INFO - Looking for match: Ticker=AEE, CIK=1002910, FormType=10-Q, FiledAt=2024-05-06
# 2025-04-13 16:50:28,472 - INFO - Looking for match: Ticker=GOOG, CIK=1652044, FormType=10-K, FiledAt=2024-01-30
# 2025-04-13 16:50:28,474 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:28,478 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:28,479 - INFO - Found matching MDA text (length: 136892 chars)
# 2025-04-13 16:50:28,480 - INFO - Found matching MDA text (length: 60815 chars)
# 2025-04-13 16:50:28,481 - WARNING - Text too long (136892 chars), truncating to 60000 chars
# 2025-04-13 16:50:28,481 - WARNING - Text too long (60815 chars), truncating to 60000 chars
# 2025-04-13 16:50:28,535 - INFO - Successfully analyzed sentiment for row 92
# 2025-04-13 16:50:28,599 - INFO - Looking for match: Ticker=AMCR, CIK=1748790, FormType=10-K, FiledAt=2024-08-16
# 2025-04-13 16:50:28,604 - INFO - Successfully analyzed sentiment for row 87
# 2025-04-13 16:50:28,633 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:28,671 - INFO - Looking for match: Ticker=AMZN, CIK=1018724, FormType=10-Q, FiledAt=2024-10-31
# 2025-04-13 16:50:28,718 - INFO - Found matching MDA text (length: 52706 chars)
# 2025-04-13 16:50:28,748 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:28,815 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:28,852 - INFO - Found matching MDA text (length: 43821 chars)
# 2025-04-13 16:50:29,768 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:29,813 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:29,864 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:29,882 - INFO - Successfully analyzed sentiment for row 98
# 2025-04-13 16:50:29,883 - INFO - Looking for match: Ticker=AEE, CIK=1002910, FormType=10-K, FiledAt=2024-02-29
# 2025-04-13 16:50:29,885 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:29,886 - INFO - Found matching MDA text (length: 182580 chars)
# 2025-04-13 16:50:29,886 - WARNING - Text too long (182580 chars), truncating to 60000 chars
# 2025-04-13 16:50:30,106 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:30,113 - INFO - Successfully analyzed sentiment for row 93
# 2025-04-13 16:50:30,115 - INFO - Looking for match: Ticker=AMCR, CIK=1748790, FormType=10-Q, FiledAt=2024-05-01
# 2025-04-13 16:50:30,118 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:30,120 - INFO - Found matching MDA text (length: 41581 chars)
# 2025-04-13 16:50:30,299 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:30,304 - INFO - Successfully analyzed sentiment for row 83
# 2025-04-13 16:50:30,305 - INFO - Looking for match: Ticker=MO, CIK=764180, FormType=10-Q, FiledAt=2024-10-31
# 2025-04-13 16:50:30,310 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:30,311 - INFO - Found matching MDA text (length: 154826 chars)
# 2025-04-13 16:50:30,312 - WARNING - Text too long (154826 chars), truncating to 60000 chars
# 2025-04-13 16:50:30,573 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:30,575 - INFO - Successfully analyzed sentiment for row 88
# 2025-04-13 16:50:30,577 - INFO - Looking for match: Ticker=AMZN, CIK=1018724, FormType=10-Q, FiledAt=2024-08-01
# 2025-04-13 16:50:30,580 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:30,581 - INFO - Found matching MDA text (length: 42669 chars)
# 2025-04-13 16:50:30,761 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:30,771 - INFO - Successfully analyzed sentiment for row 99
# 2025-04-13 16:50:30,773 - INFO - Looking for match: Ticker=AEP, CIK=4904, FormType=10-K, FiledAt=2024-02-26
# 2025-04-13 16:50:30,776 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:30,778 - INFO - Found matching MDA text (length: 1007 chars)
# 2025-04-13 16:50:30,785 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:50:30,797 - INFO - Successfully analyzed sentiment for row 94
# 2025-04-13 16:50:30,798 - INFO - Looking for match: Ticker=AIG, CIK=5272, FormType=10-Q, FiledAt=2024-11-07
# 2025-04-13 16:50:30,802 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:50:30,803 - INFO - Found matching MDA text (length: 165929 chars)
# 2025-04-13 16:50:30,804 - WARNING - Text too long (165929 chars), truncating to 60000 chars
# 2025-04-13 16:50:30,904 - INFO - Successfully analyzed sentiment for row 89
# ...
# 2025-04-13 16:55:37,404 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:37,565 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:37,574 - INFO - Successfully analyzed sentiment for row 1317
# 2025-04-13 16:55:37,575 - INFO - Looking for match: Ticker=NEM, CIK=1164727, FormType=10-Q, FiledAt=2024-04-29
# 2025-04-13 16:55:37,577 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:37,578 - INFO - Found matching MDA text (length: 94088 chars)
# 2025-04-13 16:55:37,579 - WARNING - Text too long (94088 chars), truncating to 60000 chars
# 2025-04-13 16:55:37,808 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:37,811 - INFO - Successfully analyzed sentiment for row 1312
# 2025-04-13 16:55:37,812 - INFO - Looking for match: Ticker=NFLX, CIK=1065280, FormType=10-Q, FiledAt=2024-07-19
# 2025-04-13 16:55:37,816 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:37,817 - INFO - Found matching MDA text (length: 36510 chars)
# 2025-04-13 16:55:37,974 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:37,976 - INFO - Successfully analyzed sentiment for row 1320
# 2025-04-13 16:55:37,978 - INFO - Looking for match: Ticker=NWSA, CIK=1564708, FormType=10-K, FiledAt=2024-08-13
# 2025-04-13 16:55:37,980 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:37,982 - INFO - Found matching MDA text (length: 101370 chars)
# 2025-04-13 16:55:37,982 - WARNING - Text too long (101370 chars), truncating to 60000 chars
# 2025-04-13 16:55:38,203 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:38,208 - INFO - Successfully analyzed sentiment for row 1309
# 2025-04-13 16:55:38,210 - INFO - Looking for match: Ticker=NWS, CIK=1564708, FormType=10-K, FiledAt=2024-08-13
# 2025-04-13 16:55:38,213 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:38,213 - INFO - Found matching MDA text (length: 101370 chars)
# 2025-04-13 16:55:38,214 - WARNING - Text too long (101370 chars), truncating to 60000 chars
# 2025-04-13 16:55:38,473 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:38,482 - INFO - Successfully analyzed sentiment for row 1318
# 2025-04-13 16:55:38,483 - INFO - Looking for match: Ticker=NEM, CIK=1164727, FormType=10-K, FiledAt=2024-02-29
# 2025-04-13 16:55:38,487 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:38,489 - INFO - Found matching MDA text (length: 168384 chars)
# 2025-04-13 16:55:38,490 - WARNING - Text too long (168384 chars), truncating to 60000 chars
# 2025-04-13 16:55:38,753 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:38,760 - INFO - Successfully analyzed sentiment for row 1321
# 2025-04-13 16:55:38,761 - INFO - Looking for match: Ticker=NWSA, CIK=1564708, FormType=10-Q, FiledAt=2024-05-09
# 2025-04-13 16:55:38,762 - INFO - Successfully analyzed sentiment for row 1325
# 2025-04-13 16:55:38,763 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:38,763 - INFO - Successfully analyzed sentiment for row 1313
# 2025-04-13 16:55:38,764 - INFO - Looking for match: Ticker=NWS, CIK=1564708, FormType=10-Q, FiledAt=2024-05-09
# 2025-04-13 16:55:38,764 - INFO - Found matching MDA text (length: 84247 chars)
# 2025-04-13 16:55:38,766 - INFO - Looking for match: Ticker=NFLX, CIK=1065280, FormType=10-Q, FiledAt=2024-04-22
# 2025-04-13 16:55:38,768 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:38,769 - WARNING - Text too long (84247 chars), truncating to 60000 chars
# 2025-04-13 16:55:38,772 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:38,773 - INFO - Found matching MDA text (length: 84247 chars)
# 2025-04-13 16:55:38,831 - INFO - Found matching MDA text (length: 27557 chars)
# 2025-04-13 16:55:38,888 - WARNING - Text too long (84247 chars), truncating to 60000 chars
# 2025-04-13 16:55:39,009 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:39,360 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:39,527 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:39,538 - INFO - Successfully analyzed sentiment for row 1319
# 2025-04-13 16:55:39,540 - INFO - Looking for match: Ticker=NEE, CIK=753308, FormType=10-Q, FiledAt=2024-04-23
# 2025-04-13 16:55:39,543 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:39,544 - INFO - Found matching MDA text (length: 43725 chars)
# 2025-04-13 16:55:39,732 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:39,743 - INFO - Successfully analyzed sentiment for row 1322
# 2025-04-13 16:55:39,745 - INFO - Looking for match: Ticker=NWSA, CIK=1564708, FormType=10-Q, FiledAt=2024-02-08
# 2025-04-13 16:55:39,745 - INFO - Successfully analyzed sentiment for row 1314
# 2025-04-13 16:55:39,746 - INFO - Successfully analyzed sentiment for row 1326
# 2025-04-13 16:55:39,747 - INFO - Looking for match: Ticker=NKE, CIK=320187, FormType=10-Q, FiledAt=2024-01-05
# 2025-04-13 16:55:39,748 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:39,749 - INFO - Looking for match: Ticker=NWS, CIK=1564708, FormType=10-Q, FiledAt=2024-02-08
# 2025-04-13 16:55:39,750 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:39,751 - INFO - Found matching MDA text (length: 85840 chars)
# 2025-04-13 16:55:39,754 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:39,754 - INFO - Found matching MDA text (length: 71476 chars)
# 2025-04-13 16:55:39,755 - WARNING - Text too long (85840 chars), truncating to 60000 chars
# 2025-04-13 16:55:39,756 - INFO - Found matching MDA text (length: 85840 chars)
# 2025-04-13 16:55:39,757 - WARNING - Text too long (71476 chars), truncating to 60000 chars
# 2025-04-13 16:55:39,841 - WARNING - Text too long (85840 chars), truncating to 60000 chars
# 2025-04-13 16:55:39,963 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:40,598 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:40,709 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:40,710 - INFO - Successfully analyzed sentiment for row 1330
# 2025-04-13 16:55:40,711 - INFO - Looking for match: Ticker=NEE, CIK=753308, FormType=10-K, FiledAt=2024-02-16
# 2025-04-13 16:55:40,713 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:40,714 - INFO - Found matching MDA text (length: 87016 chars)
# 2025-04-13 16:55:40,715 - WARNING - Text too long (87016 chars), truncating to 60000 chars
# 2025-04-13 16:55:40,937 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:40,953 - INFO - Successfully analyzed sentiment for row 1323
# 2025-04-13 16:55:40,954 - INFO - Looking for match: Ticker=NWS, CIK=1564708, FormType=10-Q, FiledAt=2024-11-08
# 2025-04-13 16:55:40,956 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:40,957 - INFO - Found matching MDA text (length: 55215 chars)
# 2025-04-13 16:55:41,154 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:41,161 - INFO - Successfully analyzed sentiment for row 1331
# 2025-04-13 16:55:41,162 - INFO - Looking for match: Ticker=NKE, CIK=320187, FormType=10-Q, FiledAt=2024-10-07
# 2025-04-13 16:55:41,163 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:41,165 - INFO - Found matching MDA text (length: 47590 chars)
# 2025-04-13 16:55:41,315 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:41,317 - INFO - Successfully analyzed sentiment for row 1327
# 2025-04-13 16:55:41,319 - INFO - Looking for match: Ticker=NEE, CIK=753308, FormType=10-Q, FiledAt=2024-10-23
# 2025-04-13 16:55:41,320 - INFO - Successfully analyzed sentiment for row 1335
# 2025-04-13 16:55:41,322 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:41,323 - INFO - Looking for match: Ticker=NI, CIK=1111711, FormType=10-Q, FiledAt=2024-10-30
# 2025-04-13 16:55:41,325 - INFO - Found matching MDA text (length: 54061 chars)
# 2025-04-13 16:55:41,328 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:41,386 - INFO - Found matching MDA text (length: 73019 chars)
# 2025-04-13 16:55:41,413 - WARNING - Text too long (73019 chars), truncating to 60000 chars
# 2025-04-13 16:55:41,643 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:41,877 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:41,890 - INFO - Successfully analyzed sentiment for row 1324
# 2025-04-13 16:55:41,893 - INFO - Looking for match: Ticker=NDSN, CIK=72331, FormType=10-K, FiledAt=2024-12-18
# 2025-04-13 16:55:41,897 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:41,898 - INFO - Found matching MDA text (length: 31249 chars)
# 2025-04-13 16:55:42,036 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:42,043 - INFO - Successfully analyzed sentiment for row 1332
# 2025-04-13 16:55:42,044 - INFO - Looking for match: Ticker=NKE, CIK=320187, FormType=10-K, FiledAt=2024-07-25
# 2025-04-13 16:55:42,045 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:42,046 - INFO - Found matching MDA text (length: 74397 chars)
# 2025-04-13 16:55:42,047 - WARNING - Text too long (74397 chars), truncating to 60000 chars
# 2025-04-13 16:55:42,231 - INFO - Successfully analyzed sentiment for row 1336
# 2025-04-13 16:55:42,254 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:42,256 - INFO - Looking for match: Ticker=NI, CIK=1111711, FormType=10-Q, FiledAt=2024-08-07
# 2025-04-13 16:55:42,260 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:42,261 - INFO - Found matching MDA text (length: 70751 chars)
# 2025-04-13 16:55:42,262 - WARNING - Text too long (70751 chars), truncating to 60000 chars
# 2025-04-13 16:55:42,539 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:42,542 - INFO - Successfully analyzed sentiment for row 1328
# 2025-04-13 16:55:42,543 - INFO - Looking for match: Ticker=NEE, CIK=753308, FormType=10-Q, FiledAt=2024-07-24
# 2025-04-13 16:55:42,547 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:42,548 - INFO - Found matching MDA text (length: 52030 chars)
# 2025-04-13 16:55:42,787 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:42,789 - INFO - Successfully analyzed sentiment for row 1340
# 2025-04-13 16:55:42,790 - INFO - Looking for match: Ticker=NDSN, CIK=72331, FormType=10-Q, FiledAt=2024-08-22
# 2025-04-13 16:55:42,792 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:42,793 - INFO - Found matching MDA text (length: 20944 chars)
# 2025-04-13 16:55:42,853 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:42,860 - INFO - Successfully analyzed sentiment for row 1333
# 2025-04-13 16:55:42,861 - INFO - Looking for match: Ticker=NKE, CIK=320187, FormType=10-Q, FiledAt=2024-04-04
# 2025-04-13 16:55:42,863 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:42,864 - INFO - Found matching MDA text (length: 75024 chars)
# 2025-04-13 16:55:42,864 - WARNING - Text too long (75024 chars), truncating to 60000 chars
# 2025-04-13 16:55:43,043 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,052 - INFO - Successfully analyzed sentiment for row 1329
# 2025-04-13 16:55:43,053 - INFO - Looking for match: Ticker=NSC, CIK=702165, FormType=10-Q, FiledAt=2024-07-26
# 2025-04-13 16:55:43,054 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,056 - INFO - Successfully analyzed sentiment for row 1337
# 2025-04-13 16:55:43,056 - INFO - Found matching MDA text (length: 31431 chars)
# 2025-04-13 16:55:43,057 - INFO - Looking for match: Ticker=NI, CIK=1111711, FormType=10-Q, FiledAt=2024-05-08
# 2025-04-13 16:55:43,128 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,167 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,168 - INFO - Found matching MDA text (length: 68495 chars)
# 2025-04-13 16:55:43,170 - WARNING - Text too long (68495 chars), truncating to 60000 chars
# 2025-04-13 16:55:43,244 - INFO - Successfully analyzed sentiment for row 1341
# 2025-04-13 16:55:43,286 - INFO - Looking for match: Ticker=NDSN, CIK=72331, FormType=10-Q, FiledAt=2024-05-23
# 2025-04-13 16:55:43,314 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,326 - INFO - Found matching MDA text (length: 20665 chars)
# 2025-04-13 16:55:43,447 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,502 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,511 - INFO - Successfully analyzed sentiment for row 1334
# 2025-04-13 16:55:43,512 - INFO - Looking for match: Ticker=NOC, CIK=1133421, FormType=10-Q, FiledAt=2024-07-25
# 2025-04-13 16:55:43,514 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,515 - INFO - Found matching MDA text (length: 44828 chars)
# 2025-04-13 16:55:43,669 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,676 - INFO - Successfully analyzed sentiment for row 1345
# 2025-04-13 16:55:43,677 - INFO - Looking for match: Ticker=NSC, CIK=702165, FormType=10-Q, FiledAt=2024-04-24
# 2025-04-13 16:55:43,679 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,679 - INFO - Found matching MDA text (length: 25071 chars)
# 2025-04-13 16:55:43,756 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,762 - INFO - Successfully analyzed sentiment for row 1342
# 2025-04-13 16:55:43,763 - INFO - Looking for match: Ticker=NDSN, CIK=72331, FormType=10-Q, FiledAt=2024-02-22
# 2025-04-13 16:55:43,765 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,765 - INFO - Found matching MDA text (length: 15117 chars)
# 2025-04-13 16:55:43,807 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:43,813 - INFO - Successfully analyzed sentiment for row 1338
# 2025-04-13 16:55:43,814 - INFO - Looking for match: Ticker=NI, CIK=1111711, FormType=10-K, FiledAt=2024-02-21
# 2025-04-13 16:55:43,818 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:43,819 - INFO - Found matching MDA text (length: 68752 chars)
# 2025-04-13 16:55:43,820 - WARNING - Text too long (68752 chars), truncating to 60000 chars
# 2025-04-13 16:55:44,090 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:44,093 - INFO - Successfully analyzed sentiment for row 1350
# 2025-04-13 16:55:44,094 - INFO - Looking for match: Ticker=NOC, CIK=1133421, FormType=10-Q, FiledAt=2024-04-25
# 2025-04-13 16:55:44,097 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:44,097 - INFO - Found matching MDA text (length: 37147 chars)
# 2025-04-13 16:55:44,220 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:44,223 - INFO - Successfully analyzed sentiment for row 1346
# 2025-04-13 16:55:44,224 - INFO - Looking for match: Ticker=NSC, CIK=702165, FormType=10-K, FiledAt=2024-02-05
# 2025-04-13 16:55:44,227 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:44,229 - INFO - Found matching MDA text (length: 47194 chars)
# 2025-04-13 16:55:44,454 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:44,459 - INFO - Successfully analyzed sentiment for row 1343
# 2025-04-13 16:55:44,461 - INFO - Looking for match: Ticker=NSC, CIK=702165, FormType=10-Q, FiledAt=2024-10-22
# 2025-04-13 16:55:44,462 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:44,463 - INFO - Found matching MDA text (length: 33694 chars)
# 2025-04-13 16:55:44,578 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:44,587 - INFO - Successfully analyzed sentiment for row 1351
# 2025-04-13 16:55:44,588 - INFO - Looking for match: Ticker=NOC, CIK=1133421, FormType=10-K, FiledAt=2024-01-25
# 2025-04-13 16:55:44,590 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:44,591 - INFO - Found matching MDA text (length: 72548 chars)
# 2025-04-13 16:55:44,592 - WARNING - Text too long (72548 chars), truncating to 60000 chars
# 2025-04-13 16:55:44,821 - INFO - Processing 1 chunks for FinBERT
# 2025-04-13 16:55:44,825 - INFO - Successfully analyzed sentiment for row 1339
# 2025-04-13 16:55:44,827 - INFO - Looking for match: Ticker=NCLH, CIK=1513761, FormType=10-Q, FiledAt=2024-05-07
# 2025-04-13 16:55:44,830 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 16:55:44,830 - INFO - Successfully analyzed sentiment for row 1347
# 2025-04-13 16:55:44,831 - INFO - Found matching MDA text (length: 50043 chars)
