# %% [markdown]
# # Stock Data Processing Documentation
#
# ## Overview
#
# This Python module processes and integrates multiple data sources for stock market analysis, combining price data with sentiment analysis from various sources (Reddit, news, MD&A reports) and financial metrics (ROE, PE ratios). The code creates several dataset variants for comparative machine learning model evaluation, with the goal of predicting stock returns.
#
# ## Installation and Dependencies
#
# The code requires the following Python packages:
# - pandas
# - numpy
# - os
# - logging
# - datetime
# - json
#
# ## Data Sources
#
# The module processes data from five main sources:
#
# 1. **Stock Price Data**: Historical price information including open, high, low, close, volume, and adjusted close
# 2. **Reddit Sentiment**: Aggregated sentiment analysis from Reddit posts
# 3. **News Sentiment**: Sentiment analysis from financial news articles
# 4. **MD&A Sentiment**: Sentiment analysis from Management Discussion & Analysis sections of quarterly reports
# 5. **ROE/PE Data**: Return on Equity and Price-to-Earnings ratio financial metrics
#
# ## File Structure
#
# Input data files should be organized as follows:
# ```
# data/
# ├── stock_price_data/top30/          # Price data CSV files
# │   └── TICKER_prices.csv
# ├── pe_roe_timeseries/               # PE and ROE data
# │   └── TICKER_2023_24.csv
# sentiment_results/
# ├── mda/top30/                       # MD&A sentiment analysis
# │   └── TICKER_2023_24.csv
# ├── news/top30/                      # News sentiment analysis
# │   └── news_sentiment_TICKER_with_vader_finbert.csv
# └── reddit/                          # Reddit sentiment analysis
#     └── reddit_sentiment_YEAR_v3.csv
# ```
#
# Output processed data will be saved to:
# ```
# processed_data/
# └── TICKER_VARIANT.csv
# ```
#
# ## Main Functions
#
# ### Data Loading Functions
#
# #### `load_price_data(ticker)`
# Loads price data from CSV files and calculates log returns and next-day return (target variable).
#
# #### `load_reddit_sentiment(year_list=['2023', '2024'])`
# Loads and aggregates Reddit sentiment data with volume weighting to emphasize days with higher post activity.
#
# #### `load_news_sentiment(ticker)`
# Loads company-specific news sentiment data with volume weighting to emphasize days with more news coverage.
#
# #### `load_mda_sentiment(ticker, alpha=0.2)`
# Loads MD&A sentiment data with dynamic exponential decay weighting. For each daily data point, calculates a weighted average of all previous quarterly reports where weight decays exponentially with time.
#
# #### `load_roe_pe_data(ticker, alpha=0.2)`
# Loads and processes ROE/PE data with similar dynamic exponential decay weighting.
#
# ### Data Processing Functions
#
# #### `merge_datasets(price_df, reddit_df=None, news_df=None, mda_df=None, roe_pe_df=None)`
# Merges all datasets on the Date column, starting with price data as the base.
#
# #### `process_ticker(ticker, alpha_mda=0.2, alpha_roe_pe=0.2, reddit_years=['2023', '2024'])`
# Orchestrates the complete processing pipeline for a single ticker:
# 1. Loads all datasets
# 2. Merges datasets
# 3. Filters to include only data from 2023-01-01 to 2024-12-31
# 4. Handles missing values and performs final preprocessing
#
# #### `create_dataset_variants(merged_data)`
# Creates four different variants of the dataset for model comparison:
# 1. Price data only
# 2. Price + PE/ROE data only
# 3. Price + Sentiment data only
# 4. All data combined
#
# #### `save_processed_data(dataset_variants, ticker, output_dir='processed_data')`
# Saves all dataset variants to CSV files.
#
# ### Main Execution Function
#
# #### `main()`
# Controls the overall execution flow:
# 1. Processes a list of 30 top stock tickers
# 2. Handles special cases (e.g., BRK.B/BRK-B format variations)
# 3. Tracks successful and failed ticker processing
# 4. Creates a summary report of processing results
#
# ## Features and Techniques
#
# ### Sentiment Analysis Integration
# - **Volume Weighting**: Applies log(1+count) weighting to sentiment scores based on post/article volume
# - **Exponential Decay**: Implements dynamic time-based weighting for quarterly reports (MD&A, ROE/PE)
# - **Multiple Sentiment Models**: Integrates various sentiment indicators (VADER, FinBERT, custom models)
#
# ### Data Preprocessing
# - **Log Returns**: Calculates logarithmic returns as the primary financial measurement
# - **Target Variable**: Creates next_day_return as the prediction target
# - **Missing Value Handling**: Robust handling of NaN values with appropriate methods
#
# ## Output Datasets
#
# The module creates four dataset variants for each ticker:
# 1. **price_only**: Contains only price-related variables
# 2. **price_pe_roe**: Price data plus PE ratio and ROE metrics
# 3. **price_sentiment**: Price data plus all sentiment indicators
# 4. **all_data**: Complete dataset with all variables
#
# ## Usage
#
# Run the module directly:
# ```python
# python stock_data_processing.py
# ```
#
# The script will:
# 1. Process all 30 tickers defined in the main function
# 2. Output processed datasets to the 'processed_data' directory
# 3. Generate a processing_summary.json with results
#
# ## Error Handling
#
# The code includes comprehensive error handling and logging:
# - Each function logs detailed information about its execution
# - Processing failures for individual tickers are gracefully handled
# - A summary of successful and failed tickers is generated
#
# ## Customization
#
# Key parameters that can be customized:
# - `alpha_mda` and `alpha_roe_pe`: Control decay rate for exponential weighting
# - `reddit_years`: List of years to include for Reddit sentiment data
# - Ticker list in the main function can be modified to process different stocks

# %%
import pandas as pd
import numpy as np
import os
import logging
from datetime import datetime
import json

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("stock_data_processing")

# Define file paths according to user specifications
PRICE_PATH = 'data/stock_price_data/top30/'
ROE_PE_PATH = 'data/pe_roe_timeseries/'
MDA_PATH = 'sentiment_results/mda/top30/'
NEWS_PATH = 'sentiment_results/news/top30/'
REDDIT_PATH = 'sentiment_results/reddit/'

def load_price_data(ticker):
    """
    Load price data and calculate log returns
    """
    file_path = os.path.join(PRICE_PATH, f"{ticker}_prices.csv")
    logger.info(f"Loading price data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"Price data file not found: {file_path}")
        return None
    
    df = pd.read_csv(file_path)
    
    # Ensure Date column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Sort by date
    df = df.sort_values('Date')
    
    # Calculate log returns
    df['log_return'] = np.log(df['Adjusted_close'] / df['Adjusted_close'].shift(1))
    
    # Add target variable (next day's return)
    df['next_day_return'] = df['log_return'].shift(-1)
    
    logger.info(f"Loaded price data: {df.shape[0]} rows, {df.shape[1]} columns")
    return df


def load_reddit_sentiment(year_list=['2023', '2024']):
    """
    Load and aggregate Reddit sentiment data with volume weighting
    """
    all_data = []
    logger.info(f"Loading Reddit sentiment data for years: {year_list}")
    
    for year in year_list:
        file_path = os.path.join(REDDIT_PATH, f"reddit_sentiment_{year}_v3.csv")
        if os.path.exists(file_path):
            logger.info(f"Loading Reddit data from {file_path}")
            df = pd.read_csv(file_path)
            all_data.append(df)
        else:
            logger.warning(f"Reddit data file not found: {file_path}")
    
    if not all_data:
        logger.error("No Reddit data files found")
        return None
    
    # Concatenate all years of data
    reddit_data = pd.concat(all_data, ignore_index=True)
    
    # Select only the specified columns
    specified_columns = [
        'subreddit', 'date', 
        'polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity',
        'fine_grained_sentiment_avg', 'aspect_based_sentiment_avg', 'topic_sentiment_analysis_avg', 'contextual_sentiment_avg',
        'gemini_overall_sentiment', 'gemini_emotional_sentiment', 'gemini_contextual_sentiment',
        'vader_compound', 'vader_pos', 'vader_neg', 'vader_neu',
        'finbert_positive', 'finbert_negative', 'finbert_neutral', 'finbert_sentiment'
    ]
    
    available_columns = list(set(specified_columns) & set(reddit_data.columns))
    reddit_data = reddit_data[available_columns]
    
    # Convert date to datetime
    reddit_data['date'] = pd.to_datetime(reddit_data['date'])
    
    # Calculate post count per day
    daily_post_count = reddit_data.groupby('date').size().reset_index(name='post_count')
    
    # Calculate mean sentiment for each specified sentiment column
    sentiment_columns = [col for col in available_columns if col not in ['subreddit', 'date']]
    
    # Initialize an empty DataFrame to store results
    daily_sentiment = daily_post_count[['date', 'post_count']].copy()
    
    # Calculate log-weighted sentiment for each column
    for col in sentiment_columns:
        # Calculate mean sentiment per day
        mean_sentiment = reddit_data.groupby('date')[col].mean().reset_index(name=f'mean_{col}')
        
        # Merge with post count
        daily_sentiment = pd.merge(daily_sentiment, mean_sentiment, on='date', how='left')
        
        # Calculate volume-weighted sentiment: Mean Sentiment × log(1+Post Count)
        daily_sentiment[f'reddit_{col}'] = daily_sentiment[f'mean_{col}'] * np.log1p(daily_sentiment['post_count'])
        
        # Drop the mean column to keep the DataFrame clean
        daily_sentiment = daily_sentiment.drop(f'mean_{col}', axis=1)
    
    # Rename date column for consistency
    daily_sentiment = daily_sentiment.rename(columns={'date': 'Date'})
    
    logger.info(f"Processed Reddit sentiment data: {daily_sentiment.shape[0]} rows, {daily_sentiment.shape[1]} columns")
    return daily_sentiment


def load_news_sentiment(ticker):
    """
    Load and aggregate news sentiment data with volume weighting
    """
    file_path = os.path.join(NEWS_PATH, f"news_sentiment_{ticker}_with_vader_finbert.csv")
    logger.info(f"Loading news sentiment data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"News sentiment file not found: {file_path}")
        return None
    
    news_data = pd.read_csv(file_path)
    
    # Select only the specified columns
    specified_columns = [
        'ticker', 'date', 'title',  # Including title to count articles
        'polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity',
        'fine_grained_sentiment_avg', 'aspect_based_sentiment_avg', 'topic_sentiment_analysis_avg', 'contextual_sentiment_avg',
        'gemini_overall_sentiment', 'gemini_emotional_sentiment', 'gemini_contextual_sentiment',
        'vader_compound', 'vader_pos', 'vader_neg', 'vader_neu',
        'finbert_positive', 'finbert_negative', 'finbert_neutral', 'finbert_sentiment'
    ]
    
    available_columns = list(set(specified_columns) & set(news_data.columns))
    news_data = news_data[available_columns]
    
    # Convert date to datetime
    news_data['date'] = pd.to_datetime(news_data['date'])
    
    # Calculate article count per day
    daily_article_count = news_data.groupby('date').size().reset_index(name='article_count')
    
    # Calculate mean sentiment for each specified sentiment column
    sentiment_columns = [col for col in available_columns if col not in ['ticker', 'date', 'title']]
    
    # Initialize an empty DataFrame to store results
    daily_sentiment = daily_article_count[['date', 'article_count']].copy()
    
    # Calculate log-weighted sentiment for each column
    for col in sentiment_columns:
        # Calculate mean sentiment per day
        mean_sentiment = news_data.groupby('date')[col].mean().reset_index(name=f'mean_{col}')
        
        # Merge with article count
        daily_sentiment = pd.merge(daily_sentiment, mean_sentiment, on='date', how='left')
        
        # Calculate volume-weighted sentiment: Mean Sentiment × log(1+Article Count)
        daily_sentiment[f'news_{col}'] = daily_sentiment[f'mean_{col}'] * np.log1p(daily_sentiment['article_count'])
        
        # Drop the mean column to keep the DataFrame clean
        daily_sentiment = daily_sentiment.drop(f'mean_{col}', axis=1)
    
    # Rename date column for consistency
    daily_sentiment = daily_sentiment.rename(columns={'date': 'Date'})
    
    logger.info(f"Processed news sentiment data: {daily_sentiment.shape[0]} rows, {daily_sentiment.shape[1]} columns")
    return daily_sentiment


def load_mda_sentiment(ticker, alpha=0.2):
    """
    Load MDA sentiment data with dynamic exponential decay weighting
    
    For each daily data point, we calculate a weighted average of all previous
    quarterly reports, where the weight decays exponentially with the time distance.
    """
    file_path = os.path.join(MDA_PATH, f"{ticker}_2023_24.csv")
    logger.info(f"Loading MDA sentiment data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"MDA sentiment file not found: {file_path}")
        return None
    
    mda_data = pd.read_csv(file_path)
    
    # Select only the specified columns
    specified_columns = [
        'Date',
        'polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity',
        'gemini_overall_sentiment', 'gemini_emotional_sentiment', 'gemini_contextual_sentiment',
        'fine_grained_sentiment_avg', 'aspect_based_sentiment_avg', 'topic_sentiment_analysis_avg', 'contextual_sentiment_avg',
        'vader_compound', 'vader_pos', 'vader_neg', 'vader_neu',
        'finbert_positive', 'finbert_negative', 'finbert_neutral', 'finbert_sentiment'
    ]
    
    available_columns = list(set(specified_columns) & set(mda_data.columns))
    mda_data = mda_data[available_columns]
    
    # Convert date to datetime
    mda_data['Date'] = pd.to_datetime(mda_data['Date'])
    
    # Sort by date
    mda_data = mda_data.sort_values('Date')
    
    # Get sentiment columns
    sentiment_columns = [col for col in available_columns if col != 'Date']
    
    # Create a date range that spans the entire period (daily)
    start_date = mda_data['Date'].min()
    end_date = mda_data['Date'].max()
    all_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Create a DataFrame with all dates
    daily_df = pd.DataFrame({'Date': all_dates})
    
    # Calculate lambda from alpha
    # Relationship: α ≈ 1 - e^(-λ)
    # So λ ≈ -ln(1-α)
    lambda_param = -np.log(1 - alpha)
    logger.info(f"Using decay parameter lambda={lambda_param:.4f} (from alpha={alpha})")
    
    # For each sentiment column, calculate weighted values for all days
    weighted_columns = {}
    
    for col in sentiment_columns:
        # Create a Series for this column
        col_values = pd.Series(index=mda_data['Date'], data=mda_data[col].values)
        
        # Check variation in original data for this column
        unique_values = col_values.unique()
        value_range = col_values.max() - col_values.min()
        
        # Log information about this column's values
        logger.info(f"Column {col}: {len(unique_values)} unique values, range: {value_range}")
        
        # If this column has minimal variation, potentially adjust lambda to increase decay visibility
        adjusted_lambda = lambda_param
        if len(unique_values) < 3 or value_range < 0.1:
            # Double the decay rate for columns with little variation
            adjusted_lambda = lambda_param * 2
            logger.info(f"Adjusted lambda for {col} to {adjusted_lambda} due to low variation")
        
        # For each day, calculate weighted average of all previous MDA reports
        weighted_values = []
        
        for day in all_dates:
            # Get all MDA reports up to this day
            past_reports = col_values[col_values.index <= day]
            
            if past_reports.empty:
                weighted_values.append(np.nan)
                continue
            
            # Calculate days since each report
            days_since = [(day - report_date).days for report_date in past_reports.index]
            
            # Calculate weights using continuous exponential decay with adjusted lambda
            weights = np.exp(-adjusted_lambda * np.array(days_since))
            
            # Normalize weights to sum to 1
            weights = weights / weights.sum()
            
            # Calculate weighted average
            weighted_avg = np.sum(past_reports.values * weights)
            weighted_values.append(weighted_avg)
        
        # Add to dictionary of weighted columns
        weighted_columns[f'mda_{col}'] = weighted_values
    
    # Add weighted columns to daily DataFrame
    for col_name, values in weighted_columns.items():
        daily_df[col_name] = values
    
    logger.info(f"Processed MDA sentiment data with dynamic decay: {daily_df.shape[0]} rows, {daily_df.shape[1]} columns")
    return daily_df


def load_roe_pe_data(ticker, alpha=0.2):
    """
    Load and process ROE/PE data with dynamic exponential decay weighting
    
    For each daily data point, we calculate a weighted average of all previous
    quarterly reports, where the weight decays exponentially with the time distance.
    """
    file_path = os.path.join(ROE_PE_PATH, f"{ticker}_2023_24.csv")
    logger.info(f"Loading ROE/PE data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"ROE/PE file not found: {file_path}")
        return None
    
    roe_pe_data = pd.read_csv(file_path)
    
    # Convert date to datetime
    roe_pe_data['Date'] = pd.to_datetime(roe_pe_data['Date'])
    
    # Sort by date
    roe_pe_data = roe_pe_data.sort_values('Date')
    
    # Convert ROE from string percentage to float if needed
    if roe_pe_data['ROE'].dtype == 'object':
        roe_pe_data['ROE'] = roe_pe_data['ROE'].str.replace('%', '').astype(float) / 100
    
    # Create a date range that spans the entire period (daily)
    start_date = roe_pe_data['Date'].min()
    end_date = roe_pe_data['Date'].max()
    all_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Create a DataFrame with all dates
    daily_df = pd.DataFrame({'Date': all_dates})
    
    # Calculate lambda from alpha
    # Relationship: α ≈ 1 - e^(-λ)
    # So λ ≈ -ln(1-α)
    lambda_param = -np.log(1 - alpha)
    logger.info(f"Using decay parameter lambda={lambda_param:.4f} (from alpha={alpha})")
    
    # For each financial metric, calculate weighted values for all days
    weighted_columns = {}
    original_columns = {}
    
    for col in ['PE_Ratio', 'ROE']:
        # Create a Series for this column
        col_values = pd.Series(index=roe_pe_data['Date'], data=roe_pe_data[col].values)
        
        # Keep track of original values for each date (for comparison)
        original_series = pd.Series(index=roe_pe_data['Date'], data=roe_pe_data[col].values)
        original_df = pd.DataFrame({'Date': original_series.index, col: original_series.values})
        
        # For each day, calculate weighted average of all previous financial reports
        weighted_values = []
        
        for day in all_dates:
            # Get all financial reports up to this day
            past_reports = col_values[col_values.index <= day]
            
            if past_reports.empty:
                weighted_values.append(np.nan)
                continue
            
            # Calculate days since each report
            days_since = [(day - report_date).days for report_date in past_reports.index]
            
            # Calculate weights using continuous exponential decay
            weights = np.exp(-lambda_param * np.array(days_since))
            
            # Normalize weights to sum to 1
            weights = weights / weights.sum()
            
            # Calculate weighted average
            weighted_avg = np.sum(past_reports.values * weights)
            weighted_values.append(weighted_avg)
        
        # Add to dictionaries
        weighted_columns[f'weighted_{col}'] = weighted_values
        
        # Merge original values
        daily_df = pd.merge(daily_df, original_df, on='Date', how='left')
    
    # Add weighted columns to daily DataFrame
    for col_name, values in weighted_columns.items():
        daily_df[col_name] = values
    
    # Forward fill missing original values
    daily_df = daily_df.fillna(method='ffill')
    
    logger.info(f"Processed ROE/PE data with dynamic decay: {daily_df.shape[0]} rows, {daily_df.shape[1]} columns")
    return daily_df


def merge_datasets(price_df, reddit_df=None, news_df=None, mda_df=None, roe_pe_df=None):
    """
    Merge all datasets on Date
    """
    # Start with price data as the base
    merged_df = price_df.copy()
    logger.info(f"Starting merge with price data: {merged_df.shape[0]} rows")
    
    # Merge Reddit sentiment
    if reddit_df is not None:
        merged_df = pd.merge(merged_df, reddit_df, on='Date', how='left')
        logger.info(f"After merging Reddit data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    # Merge News sentiment
    if news_df is not None:
        merged_df = pd.merge(merged_df, news_df, on='Date', how='left')
        logger.info(f"After merging News data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    # Merge MDA with dynamic decay weighting
    if mda_df is not None:
        # With the new dynamic decay approach, we now have daily values
        # so we can do a simple left join without forward fill
        merged_df = pd.merge(merged_df, mda_df, on='Date', how='left')
        logger.info(f"After merging MDA data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    # Merge ROE/PE with dynamic decay weighting
    if roe_pe_df is not None:
        # With the new dynamic decay approach, we now have daily values
        # so we can do a simple left join without forward fill
        merged_df = pd.merge(merged_df, roe_pe_df, on='Date', how='left')
        logger.info(f"After merging ROE/PE data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    return merged_df


def process_ticker(ticker, alpha_mda=0.2, alpha_roe_pe=0.2, reddit_years=['2023', '2024']):
    """
    Process all data for a single ticker
    """
    logger.info(f"Starting data processing for {ticker}")
    
    # 1. Load all datasets
    price_data = load_price_data(ticker)
    if price_data is None:
        logger.error(f"Failed to load price data for {ticker}")
        return None
    
    reddit_data = load_reddit_sentiment(reddit_years)
    news_data = load_news_sentiment(ticker)
    mda_data = load_mda_sentiment(ticker, alpha=alpha_mda)
    roe_pe_data = load_roe_pe_data(ticker, alpha=alpha_roe_pe)
    
    # 2. Merge datasets
    merged_data = merge_datasets(price_data, reddit_data, news_data, mda_data, roe_pe_data)
    
    # 3. Filter to only include data from 2023-01-01 to 2024-12-31
    start_date = pd.Timestamp('2023-01-01')
    end_date = pd.Timestamp('2024-12-31')
    merged_data = merged_data[(merged_data['Date'] >= start_date) & (merged_data['Date'] <= end_date)]
    logger.info(f"Filtered data to date range: {start_date} to {end_date}")
    
    # 4. Final preprocessing
    # Replace infinities with NaN
    merged_data = merged_data.replace([np.inf, -np.inf], np.nan)
    
    # Drop rows with NaN in log_return or next_day_return
    # These are essential as they are the target variables
    merged_data = merged_data.dropna(subset=['log_return', 'next_day_return'])
    
    # For other columns, fill NaNs with column means
    cols_to_fill = [col for col in merged_data.columns if col not in ['Date', 'log_return', 'next_day_return']]
    merged_data[cols_to_fill] = merged_data[cols_to_fill].fillna(merged_data[cols_to_fill].mean())
    
    logger.info(f"Final dataset for {ticker} has shape: {merged_data.shape}")
    
    # Create a column with the ticker name for reference
    merged_data['ticker'] = ticker
    
    return merged_data


def create_dataset_variants(merged_data):
    """
    Create different variants of the dataset for model comparison:
    1. Price data only
    2. Price + PE/ROE data only
    3. Price + Sentiment data only
    4. All data
    """
    # Price data only (keep necessary columns)
    price_cols = ['Date', 'ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'log_return', 'next_day_return']
    price_only = merged_data[price_cols].copy()
    
    # Price + PE/ROE
    pe_roe_cols = [col for col in merged_data.columns if any(term in col for term in ['PE_Ratio', 'ROE'])]
    price_pe_roe = merged_data[price_cols + pe_roe_cols].copy()
    
    # Price + Sentiment
    sentiment_cols = [col for col in merged_data.columns if any(
        prefix in col for prefix in ['reddit_', 'news_', 'mda_'])]
    price_sentiment = merged_data[price_cols + sentiment_cols].copy()
    
    # All data is already in merged_data
    
    return {
        'price_only': price_only,
        'price_pe_roe': price_pe_roe,
        'price_sentiment': price_sentiment,
        'all_data': merged_data
    }


def save_processed_data(dataset_variants, ticker, output_dir='processed_data'):
    """
    Save all dataset variants to files
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Save each variant
    for variant_name, data in dataset_variants.items():
        file_path = os.path.join(output_dir, f"{ticker}_{variant_name}.csv")
        data.to_csv(file_path, index=False)
        logger.info(f"Saved {variant_name} dataset to {file_path}")


def main():
    """
    Main function to process multiple tickers
    """
    # List of tickers to process
    tickers = [
        "AAPL", "MSFT", "NVDA", "GOOGL", "AMZN", "META", "BRK.B", "AVGO", "TSLA", "LLY", 
        "WMT", "JPM", "V", "MA", "XOM", "COST", "UNH", "HD", "PG", "JNJ",
        "ABBV", "CRM", "BAC", "ORCL", "MRK", "CVX", "WFC", "KO", "CSCO", "ACN"
    ]
    
    # Create a directory for results
    os.makedirs('processed_data', exist_ok=True)
    
    # Track successful and failed tickers
    successful_tickers = []
    failed_tickers = []
    
    # Process each ticker
    for ticker in tickers:
        logger.info(f"Processing ticker: {ticker}")
        
        try:
            # Process the ticker
            merged_data = process_ticker(ticker)
            
            # Handle the BRK.B / BRK-B special case
            if merged_data is None and ticker == "BRK.B":
                logger.info(f"Failed to process {ticker}, trying alternative format BRK-B")
                merged_data = process_ticker("BRK-B")
                
                # If successful with the alternative format, use BRK-B going forward
                if merged_data is not None:
                    ticker = "BRK-B"
            elif merged_data is None and ticker == "BRK-B":
                logger.info(f"Failed to process {ticker}, trying alternative format BRK.B")
                merged_data = process_ticker("BRK.B")
                
                # If successful with the alternative format, use BRK.B going forward
                if merged_data is not None:
                    ticker = "BRK.B"
                    
            # If data processing was successful
            if merged_data is not None:
                # Create dataset variants
                dataset_variants = create_dataset_variants(merged_data)
                
                # Save processed data
                save_processed_data(dataset_variants, ticker)
                
                logger.info(f"Completed processing for {ticker}")
                successful_tickers.append(ticker)
            else:
                logger.error(f"Failed to process {ticker} after all attempts")
                failed_tickers.append(ticker)
                
        except Exception as e:
            logger.error(f"Error processing {ticker}: {str(e)}")
            failed_tickers.append(ticker)
    
    # Print summary
    logger.info("=" * 50)
    logger.info("Processing Summary:")
    logger.info(f"Successfully processed {len(successful_tickers)} tickers: {', '.join(successful_tickers)}")
    logger.info(f"Failed to process {len(failed_tickers)} tickers: {', '.join(failed_tickers)}")
    
    # Create summary file
    summary = {
        'successful_tickers': successful_tickers,
        'failed_tickers': failed_tickers,
        'processing_time': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }
    
    with open('processing_summary.json', 'w') as f:
        json.dump(summary, f, indent=4)
    
    logger.info("Processing complete. Summary saved to processing_summary.json")


if __name__ == "__main__":
    main()
# Out:
# 2025-04-27 16:54:11,960 - stock_data_processing - INFO - Processing ticker: AAPL
# 2025-04-27 16:54:11,961 - stock_data_processing - INFO - Starting data processing for AAPL
# 2025-04-27 16:54:11,962 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/AAPL_prices.csv
# 2025-04-27 16:54:11,969 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:54:11,969 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:54:11,970 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:54:12,069 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:54:12,243 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:54:12,246 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_AAPL_with_vader_finbert.csv
# 2025-04-27 16:54:12,332 - stock_data_processing - INFO - Processed news sentiment data: 721 rows, 21 columns
# 2025-04-27 16:54:12,333 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/AAPL_2023_24.csv
# 2025-04-27 16:54:12,341 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:54:12,342 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 9 unique values, range: 0.31
# 2025-04-27 16:54:12,802 - stock_data_processing - INFO - Column vader_neg: 9 unique values, range: 0.021000000000000005
# 2025-04-27 16:54:12,803 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:13,288 - stock_data_processing - INFO - Column emotion_detection: 3 unique values, range: 0.25
# 2025-04-27 16:54:13,744 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 8 unique values, range: 0.21700000000000003
# 2025-04-27 16:54:14,200 - stock_data_processing - INFO - Column contextual_sentiment_avg: 7 unique values, range: 0.367
# 2025-04-27 16:54:14,658 - stock_data_processing - INFO - Column finbert_positive: 7 unique values, range: 0.5166363893076777
# 2025-04-27 16:54:15,115 - stock_data_processing - INFO - Column vader_compound: 9 unique values, range: 1.9841
# 2025-04-27 16:54:15,571 - stock_data_processing - INFO - Column subjectivity_objectivity: 4 unique values, range: 1.0
# 2025-04-27 16:54:16,026 - stock_data_processing - INFO - Column finbert_sentiment: 7 unique values, range: 1.4253590106964111
# 2025-04-27 16:54:16,484 - stock_data_processing - INFO - Column finbert_neutral: 7 unique values, range: 0.8744398690760137
# 2025-04-27 16:54:16,940 - stock_data_processing - INFO - Column vader_neu: 8 unique values, range: 0.015000000000000013
# 2025-04-27 16:54:16,941 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:17,397 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 8 unique values, range: 0.228
# 2025-04-27 16:54:17,853 - stock_data_processing - INFO - Column vader_pos: 8 unique values, range: 0.022
# 2025-04-27 16:54:17,854 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:18,351 - stock_data_processing - INFO - Column intent_analysis: 7 unique values, range: 0.7
# 2025-04-27 16:54:18,811 - stock_data_processing - INFO - Column polarity_detection: 4 unique values, range: 0.30000000000000004
# 2025-04-27 16:54:19,269 - stock_data_processing - INFO - Column gemini_overall_sentiment: 6 unique values, range: 0.35
# 2025-04-27 16:54:19,727 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 6 unique values, range: 0.25
# 2025-04-27 16:54:20,191 - stock_data_processing - INFO - Column finbert_negative: 7 unique values, range: 0.9087226297706364
# 2025-04-27 16:54:20,648 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 4 unique values, range: 0.5
# 2025-04-27 16:54:21,107 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:54:21,108 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/AAPL_2023_24.csv
# 2025-04-27 16:54:21,113 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:54:22,029 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:54:22,030 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:54:22,032 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:54:22,034 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:54:22,036 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:54:22,038 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:54:22,040 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:54:22,050 - stock_data_processing - INFO - Final dataset for AAPL has shape: (502, 72)
# 2025-04-27 16:54:22,060 - stock_data_processing - INFO - Saved price_only dataset to processed_data/AAPL_price_only.csv
# 2025-04-27 16:54:22,066 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/AAPL_price_pe_roe.csv
# 2025-04-27 16:54:22,099 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/AAPL_price_sentiment.csv
# 2025-04-27 16:54:22,135 - stock_data_processing - INFO - Saved all_data dataset to processed_data/AAPL_all_data.csv
# 2025-04-27 16:54:22,136 - stock_data_processing - INFO - Completed processing for AAPL
# 2025-04-27 16:54:22,136 - stock_data_processing - INFO - Processing ticker: MSFT
# 2025-04-27 16:54:22,136 - stock_data_processing - INFO - Starting data processing for MSFT
# 2025-04-27 16:54:22,137 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/MSFT_prices.csv
# 2025-04-27 16:54:22,143 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:54:22,144 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:54:22,145 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:54:22,247 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:54:22,421 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:54:22,427 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_MSFT_with_vader_finbert.csv
# 2025-04-27 16:54:22,525 - stock_data_processing - INFO - Processed news sentiment data: 717 rows, 21 columns
# 2025-04-27 16:54:22,526 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/MSFT_2023_24.csv
# 2025-04-27 16:54:22,534 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:54:22,535 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 6 unique values, range: 0.35000000000000003
# 2025-04-27 16:54:23,000 - stock_data_processing - INFO - Column vader_neg: 3 unique values, range: 0.002999999999999999
# 2025-04-27 16:54:23,001 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:23,497 - stock_data_processing - INFO - Column emotion_detection: 4 unique values, range: 0.3
# 2025-04-27 16:54:23,956 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 8 unique values, range: 0.267
# 2025-04-27 16:54:24,413 - stock_data_processing - INFO - Column contextual_sentiment_avg: 5 unique values, range: 0.45
# 2025-04-27 16:54:24,868 - stock_data_processing - INFO - Column finbert_positive: 5 unique values, range: 0.7768833078444004
# 2025-04-27 16:54:25,323 - stock_data_processing - INFO - Column vader_compound: 2 unique values, range: 9.999999999998899e-05
# 2025-04-27 16:54:25,324 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:25,779 - stock_data_processing - INFO - Column subjectivity_objectivity: 4 unique values, range: 0.5
# 2025-04-27 16:54:26,235 - stock_data_processing - INFO - Column finbert_sentiment: 5 unique values, range: 0.7860858459025623
# 2025-04-27 16:54:26,688 - stock_data_processing - INFO - Column finbert_neutral: 5 unique values, range: 0.7676806747913362
# 2025-04-27 16:54:27,144 - stock_data_processing - INFO - Column vader_neu: 9 unique values, range: 0.02300000000000002
# 2025-04-27 16:54:27,146 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:27,601 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 7 unique values, range: 0.4
# 2025-04-27 16:54:28,057 - stock_data_processing - INFO - Column vader_pos: 9 unique values, range: 0.024999999999999994
# 2025-04-27 16:54:28,057 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:28,547 - stock_data_processing - INFO - Column intent_analysis: 6 unique values, range: 0.7
# 2025-04-27 16:54:29,001 - stock_data_processing - INFO - Column polarity_detection: 5 unique values, range: 0.5
# 2025-04-27 16:54:29,458 - stock_data_processing - INFO - Column gemini_overall_sentiment: 5 unique values, range: 0.45
# 2025-04-27 16:54:29,914 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 3 unique values, range: 0.2
# 2025-04-27 16:54:30,368 - stock_data_processing - INFO - Column finbert_negative: 5 unique values, range: 0.0109301190823317
# 2025-04-27 16:54:30,369 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:30,825 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 5 unique values, range: 0.5499999999999999
# 2025-04-27 16:54:31,284 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:54:31,285 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/MSFT_2023_24.csv
# 2025-04-27 16:54:31,291 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:54:32,209 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:54:32,211 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:54:32,213 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:54:32,215 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:54:32,218 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:54:32,220 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:54:32,221 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:54:32,232 - stock_data_processing - INFO - Final dataset for MSFT has shape: (502, 72)
# 2025-04-27 16:54:32,240 - stock_data_processing - INFO - Saved price_only dataset to processed_data/MSFT_price_only.csv
# 2025-04-27 16:54:32,245 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/MSFT_price_pe_roe.csv
# 2025-04-27 16:54:32,276 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/MSFT_price_sentiment.csv
# 2025-04-27 16:54:32,310 - stock_data_processing - INFO - Saved all_data dataset to processed_data/MSFT_all_data.csv
# 2025-04-27 16:54:32,310 - stock_data_processing - INFO - Completed processing for MSFT
# 2025-04-27 16:54:32,311 - stock_data_processing - INFO - Processing ticker: NVDA
# 2025-04-27 16:54:32,311 - stock_data_processing - INFO - Starting data processing for NVDA
# 2025-04-27 16:54:32,312 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/NVDA_prices.csv
# 2025-04-27 16:54:32,319 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:54:32,319 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:54:32,320 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:54:32,416 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:54:32,589 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:54:32,595 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_NVDA_with_vader_finbert.csv
# 2025-04-27 16:54:32,711 - stock_data_processing - INFO - Processed news sentiment data: 729 rows, 21 columns
# 2025-04-27 16:54:32,712 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/NVDA_2023_24.csv
# 2025-04-27 16:54:32,719 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:54:32,720 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 7 unique values, range: 0.75
# 2025-04-27 16:54:33,175 - stock_data_processing - INFO - Column vader_neg: 5 unique values, range: 0.010999999999999996
# 2025-04-27 16:54:33,176 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:33,667 - stock_data_processing - INFO - Column emotion_detection: 6 unique values, range: 0.8
# 2025-04-27 16:54:34,124 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 9 unique values, range: 0.55
# 2025-04-27 16:54:34,578 - stock_data_processing - INFO - Column contextual_sentiment_avg: 6 unique values, range: 0.6000000000000001
# 2025-04-27 16:54:35,032 - stock_data_processing - INFO - Column finbert_positive: 6 unique values, range: 0.5376751124858857
# 2025-04-27 16:54:35,488 - stock_data_processing - INFO - Column vader_compound: 4 unique values, range: 0.000500000000000056
# 2025-04-27 16:54:35,489 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:35,944 - stock_data_processing - INFO - Column subjectivity_objectivity: 7 unique values, range: 1.1
# 2025-04-27 16:54:36,399 - stock_data_processing - INFO - Column finbert_sentiment: 6 unique values, range: 0.4232209175825118
# 2025-04-27 16:54:36,854 - stock_data_processing - INFO - Column finbert_neutral: 6 unique values, range: 0.6542102396488191
# 2025-04-27 16:54:37,309 - stock_data_processing - INFO - Column vader_neu: 8 unique values, range: 0.040000000000000036
# 2025-04-27 16:54:37,310 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:37,765 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 8 unique values, range: 0.71
# 2025-04-27 16:54:38,262 - stock_data_processing - INFO - Column vader_pos: 7 unique values, range: 0.034
# 2025-04-27 16:54:38,263 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:38,719 - stock_data_processing - INFO - Column intent_analysis: 6 unique values, range: 0.6
# 2025-04-27 16:54:39,178 - stock_data_processing - INFO - Column polarity_detection: 5 unique values, range: 0.8999999999999999
# 2025-04-27 16:54:39,635 - stock_data_processing - INFO - Column gemini_overall_sentiment: 6 unique values, range: 0.8999999999999999
# 2025-04-27 16:54:40,089 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 5 unique values, range: 0.7
# 2025-04-27 16:54:40,545 - stock_data_processing - INFO - Column finbert_negative: 6 unique values, range: 0.1178797483444214
# 2025-04-27 16:54:41,000 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 6 unique values, range: 0.7
# 2025-04-27 16:54:41,460 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:54:41,461 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/NVDA_2023_24.csv
# 2025-04-27 16:54:41,466 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:54:42,390 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:54:42,392 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:54:42,393 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:54:42,395 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:54:42,397 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:54:42,399 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:54:42,400 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:54:42,410 - stock_data_processing - INFO - Final dataset for NVDA has shape: (502, 72)
# 2025-04-27 16:54:42,417 - stock_data_processing - INFO - Saved price_only dataset to processed_data/NVDA_price_only.csv
# 2025-04-27 16:54:42,422 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/NVDA_price_pe_roe.csv
# 2025-04-27 16:54:42,453 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/NVDA_price_sentiment.csv
# 2025-04-27 16:54:42,486 - stock_data_processing - INFO - Saved all_data dataset to processed_data/NVDA_all_data.csv
# 2025-04-27 16:54:42,487 - stock_data_processing - INFO - Completed processing for NVDA
# 2025-04-27 16:54:42,488 - stock_data_processing - INFO - Processing ticker: GOOGL
# 2025-04-27 16:54:42,488 - stock_data_processing - INFO - Starting data processing for GOOGL
# 2025-04-27 16:54:42,488 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/GOOGL_prices.csv
# 2025-04-27 16:54:42,495 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:54:42,495 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:54:42,496 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:54:42,595 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:54:42,758 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:54:42,761 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_GOOGL_with_vader_finbert.csv
# 2025-04-27 16:54:42,843 - stock_data_processing - INFO - Processed news sentiment data: 712 rows, 21 columns
# 2025-04-27 16:54:42,844 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/GOOGL_2023_24.csv
# 2025-04-27 16:54:42,851 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:54:42,852 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 6 unique values, range: 0.30000000000000004
# 2025-04-27 16:54:43,337 - stock_data_processing - INFO - Column vader_neg: 8 unique values, range: 0.016
# 2025-04-27 16:54:43,338 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:43,799 - stock_data_processing - INFO - Column emotion_detection: 4 unique values, range: 0.25
# 2025-04-27 16:54:44,253 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 8 unique values, range: 0.262
# 2025-04-27 16:54:44,707 - stock_data_processing - INFO - Column contextual_sentiment_avg: 4 unique values, range: 0.25
# 2025-04-27 16:54:45,162 - stock_data_processing - INFO - Column finbert_positive: 7 unique values, range: 0.29957697726786137
# 2025-04-27 16:54:45,616 - stock_data_processing - INFO - Column vader_compound: 2 unique values, range: 9.999999999998899e-05
# 2025-04-27 16:54:45,617 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:46,070 - stock_data_processing - INFO - Column subjectivity_objectivity: 5 unique values, range: 0.5
# 2025-04-27 16:54:46,531 - stock_data_processing - INFO - Column finbert_sentiment: 7 unique values, range: 0.3174912333488464
# 2025-04-27 16:54:46,990 - stock_data_processing - INFO - Column finbert_neutral: 7 unique values, range: 0.3806561827659606
# 2025-04-27 16:54:47,447 - stock_data_processing - INFO - Column vader_neu: 8 unique values, range: 0.04800000000000004
# 2025-04-27 16:54:47,448 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:47,905 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 9 unique values, range: 0.383
# 2025-04-27 16:54:48,398 - stock_data_processing - INFO - Column vader_pos: 6 unique values, range: 0.03799999999999999
# 2025-04-27 16:54:48,399 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:48,855 - stock_data_processing - INFO - Column intent_analysis: 4 unique values, range: 0.30000000000000004
# 2025-04-27 16:54:49,312 - stock_data_processing - INFO - Column polarity_detection: 6 unique values, range: 0.4
# 2025-04-27 16:54:49,775 - stock_data_processing - INFO - Column gemini_overall_sentiment: 5 unique values, range: 0.4
# 2025-04-27 16:54:50,237 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 4 unique values, range: 0.2
# 2025-04-27 16:54:50,699 - stock_data_processing - INFO - Column finbert_negative: 7 unique values, range: 0.08107917010784149
# 2025-04-27 16:54:50,700 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:51,165 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 5 unique values, range: 0.30000000000000004
# 2025-04-27 16:54:51,631 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:54:51,632 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/GOOGL_2023_24.csv
# 2025-04-27 16:54:51,639 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:54:52,558 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:54:52,559 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:54:52,561 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:54:52,563 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:54:52,565 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:54:52,567 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:54:52,568 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:54:52,579 - stock_data_processing - INFO - Final dataset for GOOGL has shape: (502, 72)
# 2025-04-27 16:54:52,585 - stock_data_processing - INFO - Saved price_only dataset to processed_data/GOOGL_price_only.csv
# 2025-04-27 16:54:52,590 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/GOOGL_price_pe_roe.csv
# 2025-04-27 16:54:52,621 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/GOOGL_price_sentiment.csv
# 2025-04-27 16:54:52,655 - stock_data_processing - INFO - Saved all_data dataset to processed_data/GOOGL_all_data.csv
# 2025-04-27 16:54:52,656 - stock_data_processing - INFO - Completed processing for GOOGL
# 2025-04-27 16:54:52,656 - stock_data_processing - INFO - Processing ticker: AMZN
# 2025-04-27 16:54:52,656 - stock_data_processing - INFO - Starting data processing for AMZN
# 2025-04-27 16:54:52,657 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/AMZN_prices.csv
# 2025-04-27 16:54:52,665 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:54:52,665 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:54:52,666 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:54:52,760 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:54:52,921 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:54:52,926 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_AMZN_with_vader_finbert.csv
# 2025-04-27 16:54:53,016 - stock_data_processing - INFO - Processed news sentiment data: 731 rows, 21 columns
# 2025-04-27 16:54:53,017 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/AMZN_2023_24.csv
# 2025-04-27 16:54:53,025 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:54:53,025 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 6 unique values, range: 0.35
# 2025-04-27 16:54:53,504 - stock_data_processing - INFO - Column vader_neg: 5 unique values, range: 0.006999999999999999
# 2025-04-27 16:54:53,504 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:53,962 - stock_data_processing - INFO - Column emotion_detection: 3 unique values, range: 0.4
# 2025-04-27 16:54:54,416 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 8 unique values, range: 0.453
# 2025-04-27 16:54:54,874 - stock_data_processing - INFO - Column contextual_sentiment_avg: 5 unique values, range: 0.5
# 2025-04-27 16:54:55,334 - stock_data_processing - INFO - Column finbert_positive: 6 unique values, range: 0.0080294106155634
# 2025-04-27 16:54:55,335 - stock_data_processing - INFO - Adjusted lambda for finbert_positive to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:55,791 - stock_data_processing - INFO - Column vader_compound: 1 unique values, range: 0.0
# 2025-04-27 16:54:55,792 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:56,246 - stock_data_processing - INFO - Column subjectivity_objectivity: 6 unique values, range: 0.5
# 2025-04-27 16:54:56,704 - stock_data_processing - INFO - Column finbert_sentiment: 6 unique values, range: 0.049005281180143405
# 2025-04-27 16:54:56,705 - stock_data_processing - INFO - Adjusted lambda for finbert_sentiment to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:57,162 - stock_data_processing - INFO - Column finbert_neutral: 6 unique values, range: 0.041120171546936146
# 2025-04-27 16:54:57,164 - stock_data_processing - INFO - Adjusted lambda for finbert_neutral to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:57,618 - stock_data_processing - INFO - Column vader_neu: 8 unique values, range: 0.02400000000000002
# 2025-04-27 16:54:57,619 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:58,106 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 8 unique values, range: 0.5549999999999999
# 2025-04-27 16:54:58,558 - stock_data_processing - INFO - Column vader_pos: 9 unique values, range: 0.021000000000000005
# 2025-04-27 16:54:58,559 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:54:59,012 - stock_data_processing - INFO - Column intent_analysis: 5 unique values, range: 0.5
# 2025-04-27 16:54:59,465 - stock_data_processing - INFO - Column polarity_detection: 4 unique values, range: 0.5
# 2025-04-27 16:54:59,920 - stock_data_processing - INFO - Column gemini_overall_sentiment: 4 unique values, range: 0.5
# 2025-04-27 16:55:00,377 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 4 unique values, range: 0.4
# 2025-04-27 16:55:00,839 - stock_data_processing - INFO - Column finbert_negative: 6 unique values, range: 0.0450626835227012
# 2025-04-27 16:55:00,839 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:01,297 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 4 unique values, range: 0.5
# 2025-04-27 16:55:01,766 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:55:01,766 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/AMZN_2023_24.csv
# 2025-04-27 16:55:01,772 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:55:02,686 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:55:02,687 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:55:02,688 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:55:02,690 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:55:02,693 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:55:02,695 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:55:02,696 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:55:02,705 - stock_data_processing - INFO - Final dataset for AMZN has shape: (502, 72)
# 2025-04-27 16:55:02,715 - stock_data_processing - INFO - Saved price_only dataset to processed_data/AMZN_price_only.csv
# 2025-04-27 16:55:02,720 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/AMZN_price_pe_roe.csv
# 2025-04-27 16:55:02,751 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/AMZN_price_sentiment.csv
# 2025-04-27 16:55:02,784 - stock_data_processing - INFO - Saved all_data dataset to processed_data/AMZN_all_data.csv
# 2025-04-27 16:55:02,784 - stock_data_processing - INFO - Completed processing for AMZN
# 2025-04-27 16:55:02,785 - stock_data_processing - INFO - Processing ticker: META
# 2025-04-27 16:55:02,785 - stock_data_processing - INFO - Starting data processing for META
# 2025-04-27 16:55:02,785 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/META_prices.csv
# 2025-04-27 16:55:02,792 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:55:02,793 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:55:02,793 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:55:02,894 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:55:03,057 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:55:03,063 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_META_with_vader_finbert.csv
# 2025-04-27 16:55:03,122 - stock_data_processing - INFO - Processed news sentiment data: 705 rows, 21 columns
# 2025-04-27 16:55:03,123 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/META_2023_24.csv
# 2025-04-27 16:55:03,129 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:55:03,130 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 6 unique values, range: 0.55
# 2025-04-27 16:55:03,611 - stock_data_processing - INFO - Column vader_neg: 8 unique values, range: 0.010000000000000002
# 2025-04-27 16:55:03,611 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:04,064 - stock_data_processing - INFO - Column emotion_detection: 5 unique values, range: 0.5
# 2025-04-27 16:55:04,519 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 9 unique values, range: 0.45
# 2025-04-27 16:55:04,971 - stock_data_processing - INFO - Column contextual_sentiment_avg: 5 unique values, range: 0.55
# 2025-04-27 16:55:05,426 - stock_data_processing - INFO - Column finbert_positive: 9 unique values, range: 0.0067263208329678
# 2025-04-27 16:55:05,427 - stock_data_processing - INFO - Adjusted lambda for finbert_positive to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:05,881 - stock_data_processing - INFO - Column vader_compound: 2 unique values, range: 9.999999999998899e-05
# 2025-04-27 16:55:05,882 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:06,336 - stock_data_processing - INFO - Column subjectivity_objectivity: 6 unique values, range: 0.6
# 2025-04-27 16:55:06,792 - stock_data_processing - INFO - Column finbert_sentiment: 9 unique values, range: 0.0163571536540984
# 2025-04-27 16:55:06,792 - stock_data_processing - INFO - Adjusted lambda for finbert_sentiment to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:07,248 - stock_data_processing - INFO - Column finbert_neutral: 9 unique values, range: 0.00860196352005016
# 2025-04-27 16:55:07,249 - stock_data_processing - INFO - Adjusted lambda for finbert_neutral to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:07,704 - stock_data_processing - INFO - Column vader_neu: 9 unique values, range: 0.026000000000000023
# 2025-04-27 16:55:07,705 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:08,181 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 8 unique values, range: 0.65
# 2025-04-27 16:55:08,640 - stock_data_processing - INFO - Column vader_pos: 6 unique values, range: 0.019000000000000003
# 2025-04-27 16:55:08,641 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:09,096 - stock_data_processing - INFO - Column intent_analysis: 4 unique values, range: 0.30000000000000004
# 2025-04-27 16:55:09,552 - stock_data_processing - INFO - Column polarity_detection: 7 unique values, range: 0.8
# 2025-04-27 16:55:10,013 - stock_data_processing - INFO - Column gemini_overall_sentiment: 5 unique values, range: 0.65
# 2025-04-27 16:55:10,475 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 5 unique values, range: 0.4
# 2025-04-27 16:55:10,939 - stock_data_processing - INFO - Column finbert_negative: 9 unique values, range: 0.011309973895549795
# 2025-04-27 16:55:10,941 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:11,396 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 5 unique values, range: 0.55
# 2025-04-27 16:55:11,853 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:55:11,854 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/META_2023_24.csv
# 2025-04-27 16:55:11,860 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:55:12,773 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:55:12,774 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:55:12,776 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:55:12,777 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:55:12,780 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:55:12,782 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:55:12,783 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:55:12,793 - stock_data_processing - INFO - Final dataset for META has shape: (502, 72)
# 2025-04-27 16:55:12,800 - stock_data_processing - INFO - Saved price_only dataset to processed_data/META_price_only.csv
# 2025-04-27 16:55:12,805 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/META_price_pe_roe.csv
# 2025-04-27 16:55:12,837 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/META_price_sentiment.csv
# 2025-04-27 16:55:12,870 - stock_data_processing - INFO - Saved all_data dataset to processed_data/META_all_data.csv
# 2025-04-27 16:55:12,870 - stock_data_processing - INFO - Completed processing for META
# 2025-04-27 16:55:12,871 - stock_data_processing - INFO - Processing ticker: BRK.B
# 2025-04-27 16:55:12,871 - stock_data_processing - INFO - Starting data processing for BRK.B
# 2025-04-27 16:55:12,872 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/BRK.B_prices.csv
# 2025-04-27 16:55:12,872 - stock_data_processing - ERROR - Price data file not found: data/stock_price_data/top30/BRK.B_prices.csv
# 2025-04-27 16:55:12,873 - stock_data_processing - ERROR - Failed to load price data for BRK.B
# 2025-04-27 16:55:12,873 - stock_data_processing - INFO - Failed to process BRK.B, trying alternative format BRK-B
# 2025-04-27 16:55:12,873 - stock_data_processing - INFO - Starting data processing for BRK-B
# 2025-04-27 16:55:12,874 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/BRK-B_prices.csv
# 2025-04-27 16:55:12,880 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:55:12,880 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:55:12,881 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:55:12,981 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:55:13,144 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:55:13,151 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_BRK-B_with_vader_finbert.csv
# 2025-04-27 16:55:13,191 - stock_data_processing - INFO - Processed news sentiment data: 624 rows, 21 columns
# 2025-04-27 16:55:13,192 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/BRK-B_2023_24.csv
# 2025-04-27 16:55:13,192 - stock_data_processing - ERROR - MDA sentiment file not found: sentiment_results/mda/top30/BRK-B_2023_24.csv
# 2025-04-27 16:55:13,193 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/BRK-B_2023_24.csv
# 2025-04-27 16:55:13,198 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:55:14,143 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:55:14,144 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:55:14,145 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:55:14,147 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:55:14,148 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 53 columns
# 2025-04-27 16:55:14,149 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:55:14,158 - stock_data_processing - INFO - Final dataset for BRK-B has shape: (502, 53)
# 2025-04-27 16:55:14,164 - stock_data_processing - INFO - Saved price_only dataset to processed_data/BRK-B_price_only.csv
# 2025-04-27 16:55:14,169 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/BRK-B_price_pe_roe.csv
# 2025-04-27 16:55:14,190 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/BRK-B_price_sentiment.csv
# 2025-04-27 16:55:14,214 - stock_data_processing - INFO - Saved all_data dataset to processed_data/BRK-B_all_data.csv
# 2025-04-27 16:55:14,214 - stock_data_processing - INFO - Completed processing for BRK-B
# 2025-04-27 16:55:14,215 - stock_data_processing - INFO - Processing ticker: AVGO
# 2025-04-27 16:55:14,215 - stock_data_processing - INFO - Starting data processing for AVGO
# 2025-04-27 16:55:14,216 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/AVGO_prices.csv
# 2025-04-27 16:55:14,222 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:55:14,223 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:55:14,223 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:55:14,318 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:55:14,479 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:55:14,485 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_AVGO_with_vader_finbert.csv
# 2025-04-27 16:55:14,528 - stock_data_processing - INFO - Processed news sentiment data: 610 rows, 21 columns
# 2025-04-27 16:55:14,529 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/AVGO_2023_24.csv
# 2025-04-27 16:55:14,536 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:55:14,536 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 5 unique values, range: 0.15
# 2025-04-27 16:55:14,989 - stock_data_processing - INFO - Column vader_neg: 7 unique values, range: 0.006999999999999999
# 2025-04-27 16:55:14,990 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:15,442 - stock_data_processing - INFO - Column emotion_detection: 2 unique values, range: 0.05
# 2025-04-27 16:55:15,443 - stock_data_processing - INFO - Adjusted lambda for emotion_detection to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:15,896 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 8 unique values, range: 0.13333333333333341
# 2025-04-27 16:55:16,348 - stock_data_processing - INFO - Column contextual_sentiment_avg: 5 unique values, range: 0.25
# 2025-04-27 16:55:16,803 - stock_data_processing - INFO - Column finbert_positive: 7 unique values, range: 0.064154151827097
# 2025-04-27 16:55:16,804 - stock_data_processing - INFO - Adjusted lambda for finbert_positive to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:17,255 - stock_data_processing - INFO - Column vader_compound: 3 unique values, range: 0.00019999999999997797
# 2025-04-27 16:55:17,256 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:17,709 - stock_data_processing - INFO - Column subjectivity_objectivity: 7 unique values, range: 1.2
# 2025-04-27 16:55:18,162 - stock_data_processing - INFO - Column finbert_sentiment: 7 unique values, range: 0.1043953970074653
# 2025-04-27 16:55:18,638 - stock_data_processing - INFO - Column finbert_neutral: 7 unique values, range: 0.033353209495544545
# 2025-04-27 16:55:18,639 - stock_data_processing - INFO - Adjusted lambda for finbert_neutral to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:19,090 - stock_data_processing - INFO - Column vader_neu: 8 unique values, range: 0.020000000000000018
# 2025-04-27 16:55:19,091 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:19,544 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 7 unique values, range: 0.19
# 2025-04-27 16:55:19,998 - stock_data_processing - INFO - Column vader_pos: 9 unique values, range: 0.021000000000000005
# 2025-04-27 16:55:19,999 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:20,453 - stock_data_processing - INFO - Column intent_analysis: 5 unique values, range: 0.35000000000000003
# 2025-04-27 16:55:20,908 - stock_data_processing - INFO - Column polarity_detection: 3 unique values, range: 0.19999999999999998
# 2025-04-27 16:55:21,362 - stock_data_processing - INFO - Column gemini_overall_sentiment: 4 unique values, range: 0.19999999999999998
# 2025-04-27 16:55:21,819 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 3 unique values, range: 0.1
# 2025-04-27 16:55:22,275 - stock_data_processing - INFO - Column finbert_negative: 7 unique values, range: 0.0416522407904267
# 2025-04-27 16:55:22,276 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:55:22,732 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 5 unique values, range: 0.3
# 2025-04-27 16:55:23,190 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:55:23,191 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/AVGO_2023_24.csv
# 2025-04-27 16:55:23,197 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# ...
# 2025-04-27 16:58:45,350 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:58:45,350 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:58:45,352 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:58:45,353 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:58:45,355 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:58:45,356 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:58:45,357 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:58:45,366 - stock_data_processing - INFO - Final dataset for KO has shape: (502, 72)
# 2025-04-27 16:58:45,373 - stock_data_processing - INFO - Saved price_only dataset to processed_data/KO_price_only.csv
# 2025-04-27 16:58:45,377 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/KO_price_pe_roe.csv
# 2025-04-27 16:58:45,406 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/KO_price_sentiment.csv
# 2025-04-27 16:58:45,439 - stock_data_processing - INFO - Saved all_data dataset to processed_data/KO_all_data.csv
# 2025-04-27 16:58:45,439 - stock_data_processing - INFO - Completed processing for KO
# 2025-04-27 16:58:45,440 - stock_data_processing - INFO - Processing ticker: CSCO
# 2025-04-27 16:58:45,440 - stock_data_processing - INFO - Starting data processing for CSCO
# 2025-04-27 16:58:45,440 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/CSCO_prices.csv
# 2025-04-27 16:58:45,446 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:58:45,446 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:58:45,446 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:58:45,538 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:58:45,701 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:58:45,707 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_CSCO_with_vader_finbert.csv
# 2025-04-27 16:58:45,746 - stock_data_processing - INFO - Processed news sentiment data: 523 rows, 21 columns
# 2025-04-27 16:58:45,746 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/CSCO_2023_24.csv
# 2025-04-27 16:58:45,754 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:58:45,754 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 6 unique values, range: 0.33
# 2025-04-27 16:58:46,212 - stock_data_processing - INFO - Column vader_neg: 5 unique values, range: 0.006999999999999999
# 2025-04-27 16:58:46,213 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:46,691 - stock_data_processing - INFO - Column emotion_detection: 4 unique values, range: 0.25
# 2025-04-27 16:58:47,152 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 8 unique values, range: 0.3
# 2025-04-27 16:58:47,610 - stock_data_processing - INFO - Column contextual_sentiment_avg: 5 unique values, range: 0.4
# 2025-04-27 16:58:48,068 - stock_data_processing - INFO - Column finbert_positive: 9 unique values, range: 0.010478787124156997
# 2025-04-27 16:58:48,069 - stock_data_processing - INFO - Adjusted lambda for finbert_positive to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:48,526 - stock_data_processing - INFO - Column vader_compound: 2 unique values, range: 9.999999999998899e-05
# 2025-04-27 16:58:48,526 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:48,982 - stock_data_processing - INFO - Column subjectivity_objectivity: 5 unique values, range: 0.8
# 2025-04-27 16:58:49,438 - stock_data_processing - INFO - Column finbert_sentiment: 9 unique values, range: 0.0177260469645262
# 2025-04-27 16:58:49,439 - stock_data_processing - INFO - Adjusted lambda for finbert_sentiment to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:49,892 - stock_data_processing - INFO - Column finbert_neutral: 9 unique values, range: 0.004563391208648571
# 2025-04-27 16:58:49,893 - stock_data_processing - INFO - Adjusted lambda for finbert_neutral to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:50,346 - stock_data_processing - INFO - Column vader_neu: 8 unique values, range: 0.019000000000000017
# 2025-04-27 16:58:50,347 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:50,800 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 9 unique values, range: 0.41
# 2025-04-27 16:58:51,253 - stock_data_processing - INFO - Column vader_pos: 8 unique values, range: 0.017
# 2025-04-27 16:58:51,254 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:51,730 - stock_data_processing - INFO - Column intent_analysis: 5 unique values, range: 0.35000000000000003
# 2025-04-27 16:58:52,188 - stock_data_processing - INFO - Column polarity_detection: 6 unique values, range: 0.5
# 2025-04-27 16:58:52,641 - stock_data_processing - INFO - Column gemini_overall_sentiment: 5 unique values, range: 0.4
# 2025-04-27 16:58:53,093 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 3 unique values, range: 0.15000000000000002
# 2025-04-27 16:58:53,544 - stock_data_processing - INFO - Column finbert_negative: 9 unique values, range: 0.0072472598403692
# 2025-04-27 16:58:53,545 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:53,998 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 5 unique values, range: 0.44999999999999996
# 2025-04-27 16:58:54,453 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:58:54,454 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/CSCO_2023_24.csv
# 2025-04-27 16:58:54,460 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:58:55,377 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:58:55,379 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:58:55,381 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:58:55,382 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:58:55,385 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:58:55,387 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:58:55,388 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:58:55,398 - stock_data_processing - INFO - Final dataset for CSCO has shape: (502, 72)
# 2025-04-27 16:58:55,405 - stock_data_processing - INFO - Saved price_only dataset to processed_data/CSCO_price_only.csv
# 2025-04-27 16:58:55,410 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/CSCO_price_pe_roe.csv
# 2025-04-27 16:58:55,441 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/CSCO_price_sentiment.csv
# 2025-04-27 16:58:55,474 - stock_data_processing - INFO - Saved all_data dataset to processed_data/CSCO_all_data.csv
# 2025-04-27 16:58:55,475 - stock_data_processing - INFO - Completed processing for CSCO
# 2025-04-27 16:58:55,475 - stock_data_processing - INFO - Processing ticker: ACN
# 2025-04-27 16:58:55,475 - stock_data_processing - INFO - Starting data processing for ACN
# 2025-04-27 16:58:55,476 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/ACN_prices.csv
# 2025-04-27 16:58:55,482 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:58:55,483 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:58:55,483 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:58:55,583 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:58:55,746 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:58:55,751 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_ACN_with_vader_finbert.csv
# 2025-04-27 16:58:55,786 - stock_data_processing - INFO - Processed news sentiment data: 450 rows, 21 columns
# 2025-04-27 16:58:55,787 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/ACN_2023_24.csv
# 2025-04-27 16:58:55,794 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:58:55,795 - stock_data_processing - INFO - Column fine_grained_sentiment_avg: 4 unique values, range: 0.09999999999999999
# 2025-04-27 16:58:55,795 - stock_data_processing - INFO - Adjusted lambda for fine_grained_sentiment_avg to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:56,252 - stock_data_processing - INFO - Column vader_neg: 7 unique values, range: 0.024999999999999998
# 2025-04-27 16:58:56,252 - stock_data_processing - INFO - Adjusted lambda for vader_neg to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:56,737 - stock_data_processing - INFO - Column emotion_detection: 3 unique values, range: 0.1
# 2025-04-27 16:58:57,189 - stock_data_processing - INFO - Column topic_sentiment_analysis_avg: 9 unique values, range: 0.133
# 2025-04-27 16:58:57,643 - stock_data_processing - INFO - Column contextual_sentiment_avg: 4 unique values, range: 0.2
# 2025-04-27 16:58:58,097 - stock_data_processing - INFO - Column finbert_positive: 8 unique values, range: 0.09956959076225759
# 2025-04-27 16:58:58,097 - stock_data_processing - INFO - Adjusted lambda for finbert_positive to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:58,550 - stock_data_processing - INFO - Column vader_compound: 2 unique values, range: 9.999999999998899e-05
# 2025-04-27 16:58:58,551 - stock_data_processing - INFO - Adjusted lambda for vader_compound to 0.4462871026284194 due to low variation
# 2025-04-27 16:58:59,004 - stock_data_processing - INFO - Column subjectivity_objectivity: 3 unique values, range: 0.30000000000000004
# 2025-04-27 16:58:59,460 - stock_data_processing - INFO - Column finbert_sentiment: 8 unique values, range: 0.11497858911752701
# 2025-04-27 16:58:59,915 - stock_data_processing - INFO - Column finbert_neutral: 8 unique values, range: 0.08416169881820668
# 2025-04-27 16:58:59,916 - stock_data_processing - INFO - Adjusted lambda for finbert_neutral to 0.4462871026284194 due to low variation
# 2025-04-27 16:59:00,372 - stock_data_processing - INFO - Column vader_neu: 9 unique values, range: 0.05300000000000005
# 2025-04-27 16:59:00,373 - stock_data_processing - INFO - Adjusted lambda for vader_neu to 0.4462871026284194 due to low variation
# 2025-04-27 16:59:00,826 - stock_data_processing - INFO - Column aspect_based_sentiment_avg: 8 unique values, range: 0.191
# 2025-04-27 16:59:01,283 - stock_data_processing - INFO - Column vader_pos: 8 unique values, range: 0.037000000000000005
# 2025-04-27 16:59:01,283 - stock_data_processing - INFO - Adjusted lambda for vader_pos to 0.4462871026284194 due to low variation
# 2025-04-27 16:59:01,761 - stock_data_processing - INFO - Column intent_analysis: 4 unique values, range: 0.3
# 2025-04-27 16:59:02,220 - stock_data_processing - INFO - Column polarity_detection: 2 unique values, range: 0.1
# 2025-04-27 16:59:02,221 - stock_data_processing - INFO - Adjusted lambda for polarity_detection to 0.4462871026284194 due to low variation
# 2025-04-27 16:59:02,675 - stock_data_processing - INFO - Column gemini_overall_sentiment: 2 unique values, range: 0.1
# 2025-04-27 16:59:02,676 - stock_data_processing - INFO - Adjusted lambda for gemini_overall_sentiment to 0.4462871026284194 due to low variation
# 2025-04-27 16:59:03,130 - stock_data_processing - INFO - Column gemini_emotional_sentiment: 3 unique values, range: 0.1
# 2025-04-27 16:59:03,585 - stock_data_processing - INFO - Column finbert_negative: 8 unique values, range: 0.015423194505274301
# 2025-04-27 16:59:03,585 - stock_data_processing - INFO - Adjusted lambda for finbert_negative to 0.4462871026284194 due to low variation
# 2025-04-27 16:59:04,041 - stock_data_processing - INFO - Column gemini_contextual_sentiment: 3 unique values, range: 0.2
# 2025-04-27 16:59:04,494 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:59:04,495 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/ACN_2023_24.csv
# 2025-04-27 16:59:04,501 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145775/3228380485.py:374: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:59:05,410 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:59:05,411 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:59:05,412 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:59:05,414 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:59:05,415 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:59:05,417 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:59:05,418 - stock_data_processing - INFO - Filtered data to date range: 2023-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:59:05,428 - stock_data_processing - INFO - Final dataset for ACN has shape: (502, 72)
# 2025-04-27 16:59:05,434 - stock_data_processing - INFO - Saved price_only dataset to processed_data/ACN_price_only.csv
# 2025-04-27 16:59:05,439 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/ACN_price_pe_roe.csv
# 2025-04-27 16:59:05,468 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/ACN_price_sentiment.csv
# 2025-04-27 16:59:05,501 - stock_data_processing - INFO - Saved all_data dataset to processed_data/ACN_all_data.csv
# 2025-04-27 16:59:05,501 - stock_data_processing - INFO - Completed processing for ACN
# 2025-04-27 16:59:05,502 - stock_data_processing - INFO - ==================================================
# 2025-04-27 16:59:05,502 - stock_data_processing - INFO - Processing Summary:
# 2025-04-27 16:59:05,502 - stock_data_processing - INFO - Successfully processed 30 tickers: AAPL, MSFT, NVDA, GOOGL, AMZN, META, BRK-B, AVGO, TSLA, LLY, WMT, JPM, V, MA, XOM, COST, UNH, HD, PG, JNJ, ABBV, CRM, BAC, ORCL, MRK, CVX, WFC, KO, CSCO, ACN
# 2025-04-27 16:59:05,502 - stock_data_processing - INFO - Failed to process 0 tickers:
# 2025-04-27 16:59:05,503 - stock_data_processing - INFO - Processing complete. Summary saved to processing_summary.json

# %% [markdown]
# # Archive

# %%
import pandas as pd
import numpy as np
import os
import logging
from datetime import datetime

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("stock_data_processing")

# Define file paths according to user specifications
PRICE_PATH = 'data/stock_price_data/top30/'
ROE_PE_PATH = 'data/pe_roe_timeseries/'
MDA_PATH = 'sentiment_results/mda/top30/'
NEWS_PATH = 'sentiment_results/news/top30/'
REDDIT_PATH = 'sentiment_results/reddit/'

def load_price_data(ticker):
    """
    Load price data and calculate log returns
    """
    file_path = os.path.join(PRICE_PATH, f"{ticker}_prices.csv")
    logger.info(f"Loading price data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"Price data file not found: {file_path}")
        return None
    
    df = pd.read_csv(file_path)
    
    # Ensure Date column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Sort by date
    df = df.sort_values('Date')
    
    # Calculate log returns
    df['log_return'] = np.log(df['Adjusted_close'] / df['Adjusted_close'].shift(1))
    
    # Add target variable (next day's return)
    df['next_day_return'] = df['log_return'].shift(-1)
    
    logger.info(f"Loaded price data: {df.shape[0]} rows, {df.shape[1]} columns")
    return df


def load_reddit_sentiment(year_list=['2023', '2024']):
    """
    Load and aggregate Reddit sentiment data with volume weighting
    """
    all_data = []
    logger.info(f"Loading Reddit sentiment data for years: {year_list}")
    
    for year in year_list:
        file_path = os.path.join(REDDIT_PATH, f"reddit_sentiment_{year}_v3.csv")
        if os.path.exists(file_path):
            logger.info(f"Loading Reddit data from {file_path}")
            df = pd.read_csv(file_path)
            all_data.append(df)
        else:
            logger.warning(f"Reddit data file not found: {file_path}")
    
    if not all_data:
        logger.error("No Reddit data files found")
        return None
    
    # Concatenate all years of data
    reddit_data = pd.concat(all_data, ignore_index=True)
    
    # Select only the specified columns
    specified_columns = [
        'subreddit', 'date', 
        'polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity',
        'fine_grained_sentiment_avg', 'aspect_based_sentiment_avg', 'topic_sentiment_analysis_avg', 'contextual_sentiment_avg',
        'gemini_overall_sentiment', 'gemini_emotional_sentiment', 'gemini_contextual_sentiment',
        'vader_compound', 'vader_pos', 'vader_neg', 'vader_neu',
        'finbert_positive', 'finbert_negative', 'finbert_neutral', 'finbert_sentiment'
    ]
    
    available_columns = list(set(specified_columns) & set(reddit_data.columns))
    reddit_data = reddit_data[available_columns]
    
    # Convert date to datetime
    reddit_data['date'] = pd.to_datetime(reddit_data['date'])
    
    # Calculate post count per day
    daily_post_count = reddit_data.groupby('date').size().reset_index(name='post_count')
    
    # Calculate mean sentiment for each specified sentiment column
    sentiment_columns = [col for col in available_columns if col not in ['subreddit', 'date']]
    
    # Initialize an empty DataFrame to store results
    daily_sentiment = daily_post_count[['date', 'post_count']].copy()
    
    # Calculate log-weighted sentiment for each column
    for col in sentiment_columns:
        # Calculate mean sentiment per day
        mean_sentiment = reddit_data.groupby('date')[col].mean().reset_index(name=f'mean_{col}')
        
        # Merge with post count
        daily_sentiment = pd.merge(daily_sentiment, mean_sentiment, on='date', how='left')
        
        # Calculate volume-weighted sentiment: Mean Sentiment × log(1+Post Count)
        daily_sentiment[f'reddit_{col}'] = daily_sentiment[f'mean_{col}'] * np.log1p(daily_sentiment['post_count'])
        
        # Drop the mean column to keep the DataFrame clean
        daily_sentiment = daily_sentiment.drop(f'mean_{col}', axis=1)
    
    # Rename date column for consistency
    daily_sentiment = daily_sentiment.rename(columns={'date': 'Date'})
    
    logger.info(f"Processed Reddit sentiment data: {daily_sentiment.shape[0]} rows, {daily_sentiment.shape[1]} columns")
    return daily_sentiment


def load_news_sentiment(ticker):
    """
    Load and aggregate news sentiment data with volume weighting
    """
    file_path = os.path.join(NEWS_PATH, f"news_sentiment_{ticker}_with_vader_finbert.csv")
    logger.info(f"Loading news sentiment data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"News sentiment file not found: {file_path}")
        return None
    
    news_data = pd.read_csv(file_path)
    
    # Select only the specified columns
    specified_columns = [
        'ticker', 'date', 'title',  # Including title to count articles
        'polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity',
        'fine_grained_sentiment_avg', 'aspect_based_sentiment_avg', 'topic_sentiment_analysis_avg', 'contextual_sentiment_avg',
        'gemini_overall_sentiment', 'gemini_emotional_sentiment', 'gemini_contextual_sentiment',
        'vader_compound', 'vader_pos', 'vader_neg', 'vader_neu',
        'finbert_positive', 'finbert_negative', 'finbert_neutral', 'finbert_sentiment'
    ]
    
    available_columns = list(set(specified_columns) & set(news_data.columns))
    news_data = news_data[available_columns]
    
    # Convert date to datetime
    news_data['date'] = pd.to_datetime(news_data['date'])
    
    # Calculate article count per day
    daily_article_count = news_data.groupby('date').size().reset_index(name='article_count')
    
    # Calculate mean sentiment for each specified sentiment column
    sentiment_columns = [col for col in available_columns if col not in ['ticker', 'date', 'title']]
    
    # Initialize an empty DataFrame to store results
    daily_sentiment = daily_article_count[['date', 'article_count']].copy()
    
    # Calculate log-weighted sentiment for each column
    for col in sentiment_columns:
        # Calculate mean sentiment per day
        mean_sentiment = news_data.groupby('date')[col].mean().reset_index(name=f'mean_{col}')
        
        # Merge with article count
        daily_sentiment = pd.merge(daily_sentiment, mean_sentiment, on='date', how='left')
        
        # Calculate volume-weighted sentiment: Mean Sentiment × log(1+Article Count)
        daily_sentiment[f'news_{col}'] = daily_sentiment[f'mean_{col}'] * np.log1p(daily_sentiment['article_count'])
        
        # Drop the mean column to keep the DataFrame clean
        daily_sentiment = daily_sentiment.drop(f'mean_{col}', axis=1)
    
    # Rename date column for consistency
    daily_sentiment = daily_sentiment.rename(columns={'date': 'Date'})
    
    logger.info(f"Processed news sentiment data: {daily_sentiment.shape[0]} rows, {daily_sentiment.shape[1]} columns")
    return daily_sentiment


def load_mda_sentiment(ticker, alpha=0.2):
    """
    Load MDA sentiment data with dynamic exponential decay weighting
    
    For each daily data point, we calculate a weighted average of all previous
    quarterly reports, where the weight decays exponentially with the time distance.
    """
    file_path = os.path.join(MDA_PATH, f"{ticker}_2023_24.csv")
    logger.info(f"Loading MDA sentiment data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"MDA sentiment file not found: {file_path}")
        return None
    
    mda_data = pd.read_csv(file_path)
    
    # Select only the specified columns
    specified_columns = [
        'Date',
        'polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity',
        'gemini_overall_sentiment', 'gemini_emotional_sentiment', 'gemini_contextual_sentiment',
        'fine_grained_sentiment_avg', 'aspect_based_sentiment_avg', 'topic_sentiment_analysis_avg', 'contextual_sentiment_avg',
        'vader_compound', 'vader_pos', 'vader_neg', 'vader_neu',
        'finbert_positive', 'finbert_negative', 'finbert_neutral', 'finbert_sentiment'
    ]
    
    available_columns = list(set(specified_columns) & set(mda_data.columns))
    mda_data = mda_data[available_columns]
    
    # Convert date to datetime
    mda_data['Date'] = pd.to_datetime(mda_data['Date'])
    
    # Sort by date
    mda_data = mda_data.sort_values('Date')
    
    # Get sentiment columns
    sentiment_columns = [col for col in available_columns if col != 'Date']
    
    # Create a date range that spans the entire period (daily)
    start_date = mda_data['Date'].min()
    end_date = mda_data['Date'].max()
    all_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Create a DataFrame with all dates
    daily_df = pd.DataFrame({'Date': all_dates})
    
    # Calculate lambda from alpha
    # Relationship: α ≈ 1 - e^(-λ)
    # So λ ≈ -ln(1-α)
    lambda_param = -np.log(1 - alpha)
    logger.info(f"Using decay parameter lambda={lambda_param:.4f} (from alpha={alpha})")
    
    # For each sentiment column, calculate weighted values for all days
    weighted_columns = {}
    
    for col in sentiment_columns:
        # Create a Series for this column
        col_values = pd.Series(index=mda_data['Date'], data=mda_data[col].values)
        
        # For each day, calculate weighted average of all previous MDA reports
        weighted_values = []
        
        for day in all_dates:
            # Get all MDA reports up to this day
            past_reports = col_values[col_values.index <= day]
            
            if past_reports.empty:
                weighted_values.append(np.nan)
                continue
            
            # Calculate days since each report
            days_since = [(day - report_date).days for report_date in past_reports.index]
            
            # Calculate weights using continuous exponential decay
            weights = np.exp(-lambda_param * np.array(days_since))
            
            # Normalize weights to sum to 1
            weights = weights / weights.sum()
            
            # Calculate weighted average
            weighted_avg = np.sum(past_reports.values * weights)
            weighted_values.append(weighted_avg)
        
        # Add to dictionary of weighted columns
        weighted_columns[f'mda_{col}'] = weighted_values
    
    # Add weighted columns to daily DataFrame
    for col_name, values in weighted_columns.items():
        daily_df[col_name] = values
    
    logger.info(f"Processed MDA sentiment data with dynamic decay: {daily_df.shape[0]} rows, {daily_df.shape[1]} columns")
    return daily_df


def load_roe_pe_data(ticker, alpha=0.2):
    """
    Load and process ROE/PE data with dynamic exponential decay weighting
    
    For each daily data point, we calculate a weighted average of all previous
    quarterly reports, where the weight decays exponentially with the time distance.
    """
    file_path = os.path.join(ROE_PE_PATH, f"{ticker}_2023_24.csv")
    logger.info(f"Loading ROE/PE data from {file_path}")
    
    if not os.path.exists(file_path):
        logger.error(f"ROE/PE file not found: {file_path}")
        return None
    
    roe_pe_data = pd.read_csv(file_path)
    
    # Convert date to datetime
    roe_pe_data['Date'] = pd.to_datetime(roe_pe_data['Date'])
    
    # Sort by date
    roe_pe_data = roe_pe_data.sort_values('Date')
    
    # Convert ROE from string percentage to float if needed
    if roe_pe_data['ROE'].dtype == 'object':
        roe_pe_data['ROE'] = roe_pe_data['ROE'].str.replace('%', '').astype(float) / 100
    
    # Create a date range that spans the entire period (daily)
    start_date = roe_pe_data['Date'].min()
    end_date = roe_pe_data['Date'].max()
    all_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Create a DataFrame with all dates
    daily_df = pd.DataFrame({'Date': all_dates})
    
    # Calculate lambda from alpha
    # Relationship: α ≈ 1 - e^(-λ)
    # So λ ≈ -ln(1-α)
    lambda_param = -np.log(1 - alpha)
    logger.info(f"Using decay parameter lambda={lambda_param:.4f} (from alpha={alpha})")
    
    # For each financial metric, calculate weighted values for all days
    weighted_columns = {}
    original_columns = {}
    
    for col in ['PE_Ratio', 'ROE']:
        # Create a Series for this column
        col_values = pd.Series(index=roe_pe_data['Date'], data=roe_pe_data[col].values)
        
        # Keep track of original values for each date (for comparison)
        original_series = pd.Series(index=roe_pe_data['Date'], data=roe_pe_data[col].values)
        original_df = pd.DataFrame({'Date': original_series.index, col: original_series.values})
        
        # For each day, calculate weighted average of all previous financial reports
        weighted_values = []
        
        for day in all_dates:
            # Get all financial reports up to this day
            past_reports = col_values[col_values.index <= day]
            
            if past_reports.empty:
                weighted_values.append(np.nan)
                continue
            
            # Calculate days since each report
            days_since = [(day - report_date).days for report_date in past_reports.index]
            
            # Calculate weights using continuous exponential decay
            weights = np.exp(-lambda_param * np.array(days_since))
            
            # Normalize weights to sum to 1
            weights = weights / weights.sum()
            
            # Calculate weighted average
            weighted_avg = np.sum(past_reports.values * weights)
            weighted_values.append(weighted_avg)
        
        # Add to dictionaries
        weighted_columns[f'weighted_{col}'] = weighted_values
        
        # Merge original values
        daily_df = pd.merge(daily_df, original_df, on='Date', how='left')
    
    # Add weighted columns to daily DataFrame
    for col_name, values in weighted_columns.items():
        daily_df[col_name] = values
    
    # Forward fill missing original values
    daily_df = daily_df.fillna(method='ffill')
    
    logger.info(f"Processed ROE/PE data with dynamic decay: {daily_df.shape[0]} rows, {daily_df.shape[1]} columns")
    return daily_df


def merge_datasets(price_df, reddit_df=None, news_df=None, mda_df=None, roe_pe_df=None):
    """
    Merge all datasets on Date
    """
    # Start with price data as the base
    merged_df = price_df.copy()
    logger.info(f"Starting merge with price data: {merged_df.shape[0]} rows")
    
    # Merge Reddit sentiment
    if reddit_df is not None:
        merged_df = pd.merge(merged_df, reddit_df, on='Date', how='left')
        logger.info(f"After merging Reddit data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    # Merge News sentiment
    if news_df is not None:
        merged_df = pd.merge(merged_df, news_df, on='Date', how='left')
        logger.info(f"After merging News data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    # Merge MDA with dynamic decay weighting
    if mda_df is not None:
        # With the new dynamic decay approach, we now have daily values
        # so we can do a simple left join without forward fill
        merged_df = pd.merge(merged_df, mda_df, on='Date', how='left')
        logger.info(f"After merging MDA data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    # Merge ROE/PE with dynamic decay weighting
    if roe_pe_df is not None:
        # With the new dynamic decay approach, we now have daily values
        # so we can do a simple left join without forward fill
        merged_df = pd.merge(merged_df, roe_pe_df, on='Date', how='left')
        logger.info(f"After merging ROE/PE data: {merged_df.shape[0]} rows, {merged_df.shape[1]} columns")
    
    return merged_df


def process_ticker(ticker, alpha_mda=0.2, alpha_roe_pe=0.2, reddit_years=['2023', '2024']):
    """
    Process all data for a single ticker
    """
    logger.info(f"Starting data processing for {ticker}")
    
    # 1. Load all datasets
    price_data = load_price_data(ticker)
    if price_data is None:
        logger.error(f"Failed to load price data for {ticker}")
        return None
    
    reddit_data = load_reddit_sentiment(reddit_years)
    news_data = load_news_sentiment(ticker)
    mda_data = load_mda_sentiment(ticker, alpha=alpha_mda)
    roe_pe_data = load_roe_pe_data(ticker, alpha=alpha_roe_pe)
    
    # 2. Merge datasets
    merged_data = merge_datasets(price_data, reddit_data, news_data, mda_data, roe_pe_data)
    
    # 3. Filter to only include data from 2022-01-01 to 2024-12-31
    start_date = pd.Timestamp('2022-01-01')
    end_date = pd.Timestamp('2024-12-31')
    merged_data = merged_data[(merged_data['Date'] >= start_date) & (merged_data['Date'] <= end_date)]
    logger.info(f"Filtered data to date range: {start_date} to {end_date}")
    
    # 4. Final preprocessing
    # Replace infinities with NaN
    merged_data = merged_data.replace([np.inf, -np.inf], np.nan)
    
    # Drop rows with NaN in log_return or next_day_return
    # These are essential as they are the target variables
    merged_data = merged_data.dropna(subset=['log_return', 'next_day_return'])
    
    # For other columns, fill NaNs with column means
    cols_to_fill = [col for col in merged_data.columns if col not in ['Date', 'log_return', 'next_day_return']]
    merged_data[cols_to_fill] = merged_data[cols_to_fill].fillna(merged_data[cols_to_fill].mean())
    
    logger.info(f"Final dataset for {ticker} has shape: {merged_data.shape}")
    
    # Create a column with the ticker name for reference
    merged_data['ticker'] = ticker
    
    return merged_data


def create_dataset_variants(merged_data):
    """
    Create different variants of the dataset for model comparison:
    1. Price data only
    2. Price + PE/ROE data only
    3. Price + Sentiment data only
    4. All data
    """
    # Price data only (keep necessary columns)
    price_cols = ['Date', 'ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'log_return', 'next_day_return']
    price_only = merged_data[price_cols].copy()
    
    # Price + PE/ROE
    pe_roe_cols = [col for col in merged_data.columns if any(term in col for term in ['PE_Ratio', 'ROE'])]
    price_pe_roe = merged_data[price_cols + pe_roe_cols].copy()
    
    # Price + Sentiment
    sentiment_cols = [col for col in merged_data.columns if any(
        prefix in col for prefix in ['reddit_', 'news_', 'mda_'])]
    price_sentiment = merged_data[price_cols + sentiment_cols].copy()
    
    # All data is already in merged_data
    
    return {
        'price_only': price_only,
        'price_pe_roe': price_pe_roe,
        'price_sentiment': price_sentiment,
        'all_data': merged_data
    }


def save_processed_data(dataset_variants, ticker, output_dir='processed_data'):
    """
    Save all dataset variants to files
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Save each variant
    for variant_name, data in dataset_variants.items():
        file_path = os.path.join(output_dir, f"{ticker}_{variant_name}.csv")
        data.to_csv(file_path, index=False)
        logger.info(f"Saved {variant_name} dataset to {file_path}")


def main():
    """
    Main function to process multiple tickers
    """
    # List of tickers to process
    tickers = ['AAPL']  # Replace with your list of tickers
    
    for ticker in tickers:
        # Process the ticker
        merged_data = process_ticker(ticker)
        
        if merged_data is not None:
            # Create dataset variants
            dataset_variants = create_dataset_variants(merged_data)
            
            # Save processed data
            save_processed_data(dataset_variants, ticker)
            
            logger.info(f"Completed processing for {ticker}")
        else:
            logger.error(f"Failed to process {ticker}")


if __name__ == "__main__":
    main()
# Out:
# 2025-04-27 16:34:48,157 - stock_data_processing - INFO - Starting data processing for AAPL
# 2025-04-27 16:34:48,158 - stock_data_processing - INFO - Loading price data from data/stock_price_data/top30/AAPL_prices.csv
# 2025-04-27 16:34:48,164 - stock_data_processing - INFO - Loaded price data: 1561 rows, 9 columns
# 2025-04-27 16:34:48,164 - stock_data_processing - INFO - Loading Reddit sentiment data for years: ['2023', '2024']
# 2025-04-27 16:34:48,165 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2023_v3.csv
# 2025-04-27 16:34:48,265 - stock_data_processing - INFO - Loading Reddit data from sentiment_results/reddit/reddit_sentiment_2024_v3.csv
# 2025-04-27 16:34:48,440 - stock_data_processing - INFO - Processed Reddit sentiment data: 704 rows, 21 columns
# 2025-04-27 16:34:48,443 - stock_data_processing - INFO - Loading news sentiment data from sentiment_results/news/top30/news_sentiment_AAPL_with_vader_finbert.csv
# 2025-04-27 16:34:48,529 - stock_data_processing - INFO - Processed news sentiment data: 721 rows, 21 columns
# 2025-04-27 16:34:48,530 - stock_data_processing - INFO - Loading MDA sentiment data from sentiment_results/mda/top30/AAPL_2023_24.csv
# 2025-04-27 16:34:48,534 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# 2025-04-27 16:34:57,403 - stock_data_processing - INFO - Processed MDA sentiment data with dynamic decay: 731 rows, 20 columns
# 2025-04-27 16:34:57,404 - stock_data_processing - INFO - Loading ROE/PE data from data/pe_roe_timeseries/AAPL_2023_24.csv
# 2025-04-27 16:34:57,409 - stock_data_processing - INFO - Using decay parameter lambda=0.2231 (from alpha=0.2)
# /tmp/ipykernel_145591/1220479671.py:359: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_df = daily_df.fillna(method='ffill')
# 2025-04-27 16:34:58,345 - stock_data_processing - INFO - Processed ROE/PE data with dynamic decay: 731 rows, 5 columns
# 2025-04-27 16:34:58,346 - stock_data_processing - INFO - Starting merge with price data: 1561 rows
# 2025-04-27 16:34:58,348 - stock_data_processing - INFO - After merging Reddit data: 1561 rows, 29 columns
# 2025-04-27 16:34:58,349 - stock_data_processing - INFO - After merging News data: 1561 rows, 49 columns
# 2025-04-27 16:34:58,352 - stock_data_processing - INFO - After merging MDA data: 1561 rows, 68 columns
# 2025-04-27 16:34:58,354 - stock_data_processing - INFO - After merging ROE/PE data: 1561 rows, 72 columns
# 2025-04-27 16:34:58,355 - stock_data_processing - INFO - Filtered data to date range: 2022-01-01 00:00:00 to 2024-12-31 00:00:00
# 2025-04-27 16:34:58,366 - stock_data_processing - INFO - Final dataset for AAPL has shape: (753, 72)
# 2025-04-27 16:34:58,377 - stock_data_processing - INFO - Saved price_only dataset to processed_data/AAPL_price_only.csv
# 2025-04-27 16:34:58,386 - stock_data_processing - INFO - Saved price_pe_roe dataset to processed_data/AAPL_price_pe_roe.csv
# 2025-04-27 16:34:58,436 - stock_data_processing - INFO - Saved price_sentiment dataset to processed_data/AAPL_price_sentiment.csv
# 2025-04-27 16:34:58,491 - stock_data_processing - INFO - Saved all_data dataset to processed_data/AAPL_all_data.csv
# 2025-04-27 16:34:58,492 - stock_data_processing - INFO - Completed processing for AAPL
