# %% [markdown]
# # Documentation: Retrieving Historical Stock Data for S&P 500 Tickers Using EODHD API
#
# ---
#
# ## Overview
#
# This Python script retrieves historical end-of-day stock data for all S&P 500 tickers from January 1, 2019, to the present using the EODHD API. The data includes the following fields for each trading day:
#
# - `date`
# - `open`
# - `high`
# - `low`
# - `close`
# - `adjusted_close`
# - `volume`
#
# The script processes each ticker individually, making one API call per ticker, and saves the data into separate CSV files (e.g., `AAPL_full_data.csv`) within a folder named `sp500_full_data`. This approach ensures that the data is organized and easily accessible for individual stocks.
#
# ---
#
# ## Prerequisites
#
# Before running the script, ensure you have the following:
#
# - **EODHD API Key**: Obtain a valid API key from [EODHD](https://eodhd.com/). You will need to replace `"YOUR_EODHD_API_KEY"` in the script with your actual key.
# - **Python Environment**: The script requires Python 3.x and the following libraries:
#   - `pandas`
#   - `requests`
#   - `os` (standard library)
#   - `csv` (standard library)
#   - `datetime` (standard library)
# - **Ticker List**: A CSV file named `sp500_constituents.csv` containing the S&P 500 ticker symbols in a column named `Ticker`. This file must be placed in the same directory as the script.
#
# ---
#
# ## Setup
#
# 1. **Install Required Libraries**
#    If not already installed, use pip to install the necessary Python libraries:
#    ```bash
#    pip install pandas requests
#    ```
#    Note: The `os`, `csv`, and `datetime` modules are part of Python's standard library and do not require installation.
#
# 2. **Prepare the Ticker List**
#    Ensure that `sp500_constituents.csv` is correctly formatted with a `Ticker` column. Example format:
#    ```
#    Ticker,Company,Sector,CIK
#    MMM,3M Company,Industrials,66740
#    AOS,A. O. Smith Corporation,Industrials,91142
#    ABT,Abbott Laboratories,Health Care,1800
#    ...
#    ```
#
# 3. **Insert API Key**
#    Open the script and replace `"YOUR_EODHD_API_KEY"` with your actual EODHD API key.
#
# ---
#
# ## How the Script Works
#
# The script performs the following steps:
#
# 1. **Load Ticker List**
#    Reads the `Ticker` column from `sp500_constituents.csv` to obtain the list of approximately 505 S&P 500 tickers.
#
# 2. **Define Date Range**
#    Sets the start date to January 1, 2019, and the end date to the current date using `datetime.today()`.
#
# 3. **Create Output Folder**
#    Creates a folder named `sp500_full_data` to store the CSV files for each ticker. If the folder already exists, it is reused without modification.
#
# 4. **Process Each Ticker**
#    - Constructs the API URL for the EODHD `eod` endpoint, specifying the ticker, date range, API key, and CSV format.
#    - Sends an API request to fetch the historical data for the ticker.
#    - If the request succeeds (HTTP status code 200), parses the CSV response.
#    - Saves the data to a file named `<ticker>_full_data.csv` (e.g., `AAPL_full_data.csv`) in the `sp500_full_data` folder, including all fields: `date`, `open`, `high`, `low`, `close`, `adjusted_close`, and `volume`.
#
# 5. **Error Handling**
#    If an API request fails (e.g., due to an invalid ticker or network issues), the script prints an error message with the ticker and status code, then continues processing the remaining tickers.
#
# 6. **API Rate Limits**
#    The script makes one API call per ticker (approximately 505 calls). With EODHD's limits of 1000 calls per minute and 100,000 calls per day, this usage is well within bounds, requiring no delays.
#
# ---
#
# ## Output
#
# - **Folder**: All files are saved in the `sp500_full_data` folder.
# - **Files**: Each ticker has its own CSV file, named `<ticker>_full_data.csv` (e.g., `MMM_full_data.csv`).
# - **File Structure**: Each CSV contains:
#   - `date`: Trading day (e.g., `2019-01-02`)
#   - `open`: Opening price
#   - `high`: Highest price
#   - `low`: Lowest price
#   - `close`: Closing price
#   - `adjusted_close`: Adjusted closing price (accounts for splits, dividends, etc.)
#   - `volume`: Shares traded
#
# - **Sample Data** (from `AAPL_full_data.csv`):
#   ```
#   date,open,high,low,close,adjusted_close,volume
#   2019-01-02,38.72,39.71,38.56,39.48,38.27,37039700
#   2019-01-03,35.55,36.43,35.50,35.55,34.46,91312200
#   ...
#   2023-01-03,118.47,118.80,104.64,108.10,108.10,231402797
#   ...
#   ```
#
# - **Row Count**: Approximately 1,200 rows per file, reflecting trading days from 2019 to the present.
#
# ---
#
# ## Usage Instructions
#
# 1. **Prepare the Environment**
#    - Install Python and required libraries.
#    - Place `sp500_constituents.csv` in the script’s directory.
#    - Insert your EODHD API key into the script.
#
# 2. **Run the Script**
#    Execute the script from the command line:
#    ```bash
#    python script_name.py
#    ```
#    - The script will process each ticker, display progress, and save data to `sp500_full_data`.
#    - Completion takes approximately 4-5 minutes, depending on network speed.
#
# 3. **Verify the Output**
#    - Check the `sp500_full_data` folder for CSV files.
#    - Open a file (e.g., `MMM_full_data.csv`) to confirm it contains the expected data.
#
# ---
#
# ## API Usage and Rate Limits
#
# - **Total API Calls**: Approximately 505 calls (one per ticker).
# - **Rate Limits**:
#   - **Per Minute**: 1000 calls allowed; 505 calls are within this limit.
#   - **Per Day**: 100,000 calls allowed; 505 calls use only 0.505% of the daily limit.
# - **Shared Accounts**: If the API key is shared, coordinate with others to stay under 100,000 daily calls. This script’s usage is minimal and unlikely to cause conflicts.
#
# ---
#
# ## Additional Notes
#
# - **Testing**: For a smaller test run, modify the ticker list (e.g., `tickers = tickers[:5]`).
# - **Error Handling**: Failed requests are logged to the console; the script continues running.
# - **Data Updates**: To update existing files, adjust `start_date` to the last recorded date and append new data.
#
# This documentation provides a complete guide to setting up, running, and understanding the script’s output for retrieving S&P 500 historical stock data.

# %%
import pandas as pd
import requests
import csv
import os
from datetime import datetime

# Replace with your EODHD API key
API_KEY = "603eafd117ce29.12741264"

# Load S&P 500 tickers from a CSV file (assumed to have a 'Ticker' column)
df = pd.read_csv("sp500_constituents.csv")
tickers = df["Ticker"].tolist()  # Approximately 505 tickers

# Define the date range
start_date = "2019-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")  # Today's date

# Create a folder to store the CSV files
folder_name = "sp500_prices"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Process each ticker
for i, ticker in enumerate(tickers):
    # Construct the API URL
    url = (
        f"https://eodhd.com/api/eod/{ticker}.US?"
        f"from={start_date}&"
        f"to={end_date}&"
        f"api_token={API_KEY}&"
        f"fmt=csv"
    )
    
    # Fetch the data
    response = requests.get(url)
    if response.status_code == 200:
        # Parse the CSV response
        lines = response.text.splitlines()
        # Save to a ticker-specific file in the folder
        file_path = os.path.join(folder_name, f"{ticker}_prices.csv")
        with open(file_path, mode="w", newline="") as f:
            writer = csv.writer(f)
            # Write the header (first line of the response)
            writer.writerow(lines[0].split(","))
            # Write the data rows
            for line in lines[1:]:
                writer.writerow(line.split(","))
        print(f"Processed {ticker} ({i+1}/{len(tickers)})")
    else:
        print(f"Failed to fetch {ticker}: {response.status_code}")

print(f"All tickers processed. Data saved in individual CSV files inside '{folder_name}' folder.")
# Out:
# Processed MMM (1/503)
# Processed AOS (2/503)
# Processed ABT (3/503)
# Processed ABBV (4/503)
# Processed ACN (5/503)
# Processed ADBE (6/503)
# Processed AMD (7/503)
# Processed AES (8/503)
# Processed AFL (9/503)
# Processed A (10/503)
# Processed APD (11/503)
# Processed ABNB (12/503)
# Processed AKAM (13/503)
# Processed ALB (14/503)
# Processed ARE (15/503)
# Processed ALGN (16/503)
# Processed ALLE (17/503)
# Processed LNT (18/503)
# Processed ALL (19/503)
# Processed GOOGL (20/503)
# Processed GOOG (21/503)
# Processed MO (22/503)
# Processed AMZN (23/503)
# Processed AMCR (24/503)
# Processed AEE (25/503)
# Processed AEP (26/503)
# Processed AXP (27/503)
# Processed AIG (28/503)
# Processed AMT (29/503)
# Processed AWK (30/503)
# Processed AMP (31/503)
# Processed AME (32/503)
# Processed AMGN (33/503)
# Processed APH (34/503)
# Processed ADI (35/503)
# Processed ANSS (36/503)
# Processed AON (37/503)
# Processed APA (38/503)
# Processed APO (39/503)
# Processed AAPL (40/503)
# Processed AMAT (41/503)
# Processed APTV (42/503)
# Processed ACGL (43/503)
# Processed ADM (44/503)
# Processed ANET (45/503)
# Processed AJG (46/503)
# Processed AIZ (47/503)
# Processed T (48/503)
# Processed ATO (49/503)
# Processed ADSK (50/503)
# Processed ADP (51/503)
# Processed AZO (52/503)
# Processed AVB (53/503)
# Processed AVY (54/503)
# Processed AXON (55/503)
# Processed BKR (56/503)
# Processed BALL (57/503)
# Processed BAC (58/503)
# Processed BAX (59/503)
# Processed BDX (60/503)
# Failed to fetch BRK.B: 404
# Processed BBY (62/503)
# Processed TECH (63/503)
# Processed BIIB (64/503)
# Processed BLK (65/503)
# Processed BX (66/503)
# Processed BK (67/503)
# Processed BA (68/503)
# Processed BKNG (69/503)
# Processed BWA (70/503)
# Processed BSX (71/503)
# Processed BMY (72/503)
# Processed AVGO (73/503)
# Processed BR (74/503)
# Processed BRO (75/503)
# Failed to fetch BF.B: 404
# Processed BLDR (77/503)
# Processed BG (78/503)
# Processed BXP (79/503)
# Processed CHRW (80/503)
# Processed CDNS (81/503)
# Processed CZR (82/503)
# Processed CPT (83/503)
# Processed CPB (84/503)
# Processed COF (85/503)
# Processed CAH (86/503)
# Processed KMX (87/503)
# Processed CCL (88/503)
# Processed CARR (89/503)
# Processed CAT (90/503)
# Processed CBOE (91/503)
# Processed CBRE (92/503)
# Processed CDW (93/503)
# Processed CE (94/503)
# Processed COR (95/503)
# Processed CNC (96/503)
# Processed CNP (97/503)
# Processed CF (98/503)
# Processed CRL (99/503)
# Processed SCHW (100/503)
# Processed CHTR (101/503)
# Processed CVX (102/503)
# Processed CMG (103/503)
# Processed CB (104/503)
# Processed CHD (105/503)
# Processed CI (106/503)
# Processed CINF (107/503)
# Processed CTAS (108/503)
# Processed CSCO (109/503)
# Processed C (110/503)
# Processed CFG (111/503)
# Processed CLX (112/503)
# Processed CME (113/503)
# Processed CMS (114/503)
# Processed KO (115/503)
# Processed CTSH (116/503)
# Processed CL (117/503)
# Processed CMCSA (118/503)
# Processed CAG (119/503)
# Processed COP (120/503)
# Processed ED (121/503)
# Processed STZ (122/503)
# Processed CEG (123/503)
# Processed COO (124/503)
# Processed CPRT (125/503)
# Processed GLW (126/503)
# Processed CPAY (127/503)
# Processed CTVA (128/503)
# Processed CSGP (129/503)
# Processed COST (130/503)
# Processed CTRA (131/503)
# Processed CRWD (132/503)
# Processed CCI (133/503)
# Processed CSX (134/503)
# Processed CMI (135/503)
# Processed CVS (136/503)
# Processed DHR (137/503)
# Processed DRI (138/503)
# Processed DVA (139/503)
# Processed DAY (140/503)
# Processed DECK (141/503)
# Processed DE (142/503)
# Processed DELL (143/503)
# Processed DAL (144/503)
# Processed DVN (145/503)
# Processed DXCM (146/503)
# Processed FANG (147/503)
# Processed DLR (148/503)
# Processed DFS (149/503)
# Processed DG (150/503)
# Processed DLTR (151/503)
# Processed D (152/503)
# Processed DPZ (153/503)
# Processed DOV (154/503)
# Processed DOW (155/503)
# Processed DHI (156/503)
# Processed DTE (157/503)
# Processed DUK (158/503)
# Processed DD (159/503)
# Processed EMN (160/503)
# Processed ETN (161/503)
# Processed EBAY (162/503)
# Processed ECL (163/503)
# Processed EIX (164/503)
# Processed EW (165/503)
# Processed EA (166/503)
# Processed ELV (167/503)
# Processed EMR (168/503)
# Processed ENPH (169/503)
# Processed ETR (170/503)
# Processed EOG (171/503)
# Processed EPAM (172/503)
# Processed EQT (173/503)
# Processed EFX (174/503)
# Processed EQIX (175/503)
# Processed EQR (176/503)
# Processed ERIE (177/503)
# Processed ESS (178/503)
# Processed EL (179/503)
# Processed EG (180/503)
# Processed EVRG (181/503)
# Processed ES (182/503)
# Processed EXC (183/503)
# Processed EXPE (184/503)
# Processed EXPD (185/503)
# Processed EXR (186/503)
# Processed XOM (187/503)
# Processed FFIV (188/503)
# Processed FDS (189/503)
# Processed FICO (190/503)
# Processed FAST (191/503)
# Processed FRT (192/503)
# Processed FDX (193/503)
# Processed FIS (194/503)
# Processed FITB (195/503)
# Processed FSLR (196/503)
# Processed FE (197/503)
# Processed FI (198/503)
# Processed FMC (199/503)
# Processed F (200/503)
# Processed FTNT (201/503)
# Processed FTV (202/503)
# Processed FOXA (203/503)
# Processed FOX (204/503)
# Processed BEN (205/503)
# Processed FCX (206/503)
# Processed GRMN (207/503)
# Processed IT (208/503)
# Processed GE (209/503)
# Processed GEHC (210/503)
# Processed GEV (211/503)
# Processed GEN (212/503)
# Processed GNRC (213/503)
# Processed GD (214/503)
# Processed GIS (215/503)
# Processed GM (216/503)
# Processed GPC (217/503)
# Processed GILD (218/503)
# Processed GPN (219/503)
# Processed GL (220/503)
# Processed GDDY (221/503)
# Processed GS (222/503)
# Processed HAL (223/503)
# Processed HIG (224/503)
# Processed HAS (225/503)
# Processed HCA (226/503)
# Processed DOC (227/503)
# Processed HSIC (228/503)
# Processed HSY (229/503)
# Processed HES (230/503)
# Processed HPE (231/503)
# Processed HLT (232/503)
# Processed HOLX (233/503)
# Processed HD (234/503)
# Processed HON (235/503)
# Processed HRL (236/503)
# Processed HST (237/503)
# Processed HWM (238/503)
# Processed HPQ (239/503)
# Processed HUBB (240/503)
# Processed HUM (241/503)
# Processed HBAN (242/503)
# Processed HII (243/503)
# Processed IBM (244/503)
# Processed IEX (245/503)
# Processed IDXX (246/503)
# Processed ITW (247/503)
# Processed INCY (248/503)
# Processed IR (249/503)
# Processed PODD (250/503)
# Processed INTC (251/503)
# Processed ICE (252/503)
# Processed IFF (253/503)
# Processed IP (254/503)
# Processed IPG (255/503)
# Processed INTU (256/503)
# Processed ISRG (257/503)
# Processed IVZ (258/503)
# Processed INVH (259/503)
# Processed IQV (260/503)
# Processed IRM (261/503)
# Processed JBHT (262/503)
# Processed JBL (263/503)
# Processed JKHY (264/503)
# Processed J (265/503)
# Processed JNJ (266/503)
# Processed JCI (267/503)
# Processed JPM (268/503)
# Processed JNPR (269/503)
# Processed K (270/503)
# Processed KVUE (271/503)
# Processed KDP (272/503)
# Processed KEY (273/503)
# Processed KEYS (274/503)
# Processed KMB (275/503)
# Processed KIM (276/503)
# Processed KMI (277/503)
# Processed KKR (278/503)
# Processed KLAC (279/503)
# Processed KHC (280/503)
# Processed KR (281/503)
# Processed LHX (282/503)
# Processed LH (283/503)
# Processed LRCX (284/503)
# Processed LW (285/503)
# Processed LVS (286/503)
# Processed LDOS (287/503)
# Processed LEN (288/503)
# Processed LII (289/503)
# Processed LLY (290/503)
# Processed LIN (291/503)
# Processed LYV (292/503)
# Processed LKQ (293/503)
# Processed LMT (294/503)
# Processed L (295/503)
# Processed LOW (296/503)
# Processed LULU (297/503)
# Processed LYB (298/503)
# Processed MTB (299/503)
# Processed MPC (300/503)
# Processed MKTX (301/503)
# Processed MAR (302/503)
# Processed MMC (303/503)
# Processed MLM (304/503)
# Processed MAS (305/503)
# Processed MA (306/503)
# Processed MTCH (307/503)
# Processed MKC (308/503)
# Processed MCD (309/503)
# Processed MCK (310/503)
# Processed MDT (311/503)
# Processed MRK (312/503)
# Processed META (313/503)
# Processed MET (314/503)
# Processed MTD (315/503)
# Processed MGM (316/503)
# Processed MCHP (317/503)
# Processed MU (318/503)
# Processed MSFT (319/503)
# Processed MAA (320/503)
# Processed MRNA (321/503)
# Processed MHK (322/503)
# Processed MOH (323/503)
# Processed TAP (324/503)
# Processed MDLZ (325/503)
# Processed MPWR (326/503)
# Processed MNST (327/503)
# Processed MCO (328/503)
# Processed MS (329/503)
# Processed MOS (330/503)
# Processed MSI (331/503)
# Processed MSCI (332/503)
# Processed NDAQ (333/503)
# Processed NTAP (334/503)
# Processed NFLX (335/503)
# Processed NEM (336/503)
# Processed NWSA (337/503)
# Processed NWS (338/503)
# Processed NEE (339/503)
# Processed NKE (340/503)
# Processed NI (341/503)
# Processed NDSN (342/503)
# Processed NSC (343/503)
# Processed NTRS (344/503)
# Processed NOC (345/503)
# Processed NCLH (346/503)
# Processed NRG (347/503)
# Processed NUE (348/503)
# Processed NVDA (349/503)
# Processed NVR (350/503)
# Processed NXPI (351/503)
# Processed ORLY (352/503)
# Processed OXY (353/503)
# Processed ODFL (354/503)
# Processed OMC (355/503)
# Processed ON (356/503)
# Processed OKE (357/503)
# Processed ORCL (358/503)
# Processed OTIS (359/503)
# Processed PCAR (360/503)
# Processed PKG (361/503)
# Processed PLTR (362/503)
# Processed PANW (363/503)
# Processed PARA (364/503)
# Processed PH (365/503)
# Processed PAYX (366/503)
# Processed PAYC (367/503)
# Processed PYPL (368/503)
# Processed PNR (369/503)
# Processed PEP (370/503)
# Processed PFE (371/503)
# Processed PCG (372/503)
# Processed PM (373/503)
# Processed PSX (374/503)
# Processed PNW (375/503)
# Processed PNC (376/503)
# Processed POOL (377/503)
# Processed PPG (378/503)
# Processed PPL (379/503)
# Processed PFG (380/503)
# Processed PG (381/503)
# Processed PGR (382/503)
# Processed PLD (383/503)
# Processed PRU (384/503)
# Processed PEG (385/503)
# Processed PTC (386/503)
# Processed PSA (387/503)
# Processed PHM (388/503)
# Processed PWR (389/503)
# Processed QCOM (390/503)
# Processed DGX (391/503)
# Processed RL (392/503)
# Processed RJF (393/503)
# Processed RTX (394/503)
# Processed O (395/503)
# Processed REG (396/503)
# Processed REGN (397/503)
# Processed RF (398/503)
# Processed RSG (399/503)
# Processed RMD (400/503)
# Processed RVTY (401/503)
# Processed ROK (402/503)
# Processed ROL (403/503)
# Processed ROP (404/503)
# Processed ROST (405/503)
# Processed RCL (406/503)
# Processed SPGI (407/503)
# Processed CRM (408/503)
# Processed SBAC (409/503)
# Processed SLB (410/503)
# Processed STX (411/503)
# Processed SRE (412/503)
# Processed NOW (413/503)
# Processed SHW (414/503)
# Processed SPG (415/503)
# Processed SWKS (416/503)
# Processed SJM (417/503)
# Processed SW (418/503)
# Processed SNA (419/503)
# Processed SOLV (420/503)
# Processed SO (421/503)
# Processed LUV (422/503)
# Processed SWK (423/503)
# Processed SBUX (424/503)
# Processed STT (425/503)
# Processed STLD (426/503)
# Processed STE (427/503)
# Processed SYK (428/503)
# Processed SMCI (429/503)
# Processed SYF (430/503)
# Processed SNPS (431/503)
# Processed SYY (432/503)
# Processed TMUS (433/503)
# Processed TROW (434/503)
# Processed TTWO (435/503)
# Processed TPR (436/503)
# Processed TRGP (437/503)
# Processed TGT (438/503)
# Processed TEL (439/503)
# Processed TDY (440/503)
# Processed TFX (441/503)
# Processed TER (442/503)
# Processed TSLA (443/503)
# Processed TXN (444/503)
# Processed TPL (445/503)
# Processed TXT (446/503)
# Processed TMO (447/503)
# Processed TJX (448/503)
# Processed TSCO (449/503)
# Processed TT (450/503)
# Processed TDG (451/503)
# Processed TRV (452/503)
# Processed TRMB (453/503)
# Processed TFC (454/503)
# Processed TYL (455/503)
# Processed TSN (456/503)
# Processed USB (457/503)
# Processed UBER (458/503)
# Processed UDR (459/503)
# Processed ULTA (460/503)
# Processed UNP (461/503)
# Processed UAL (462/503)
# Processed UPS (463/503)
# Processed URI (464/503)
# Processed UNH (465/503)
# Processed UHS (466/503)
# Processed VLO (467/503)
# Processed VTR (468/503)
# Processed VLTO (469/503)
# Processed VRSN (470/503)
# Processed VRSK (471/503)
# Processed VZ (472/503)
# Processed VRTX (473/503)
# Processed VTRS (474/503)
# Processed VICI (475/503)
# Processed V (476/503)
# Processed VST (477/503)
# Processed VMC (478/503)
# Processed WRB (479/503)
# Processed GWW (480/503)
# Processed WAB (481/503)
# Processed WBA (482/503)
# Processed WMT (483/503)
# Processed DIS (484/503)
# Processed WBD (485/503)
# Processed WM (486/503)
# Processed WAT (487/503)
# Processed WEC (488/503)
# Processed WFC (489/503)
# Processed WELL (490/503)
# Processed WST (491/503)
# Processed WDC (492/503)
# Processed WY (493/503)
# Processed WMB (494/503)
# Processed WTW (495/503)
# Processed WDAY (496/503)
# Processed WYNN (497/503)
# Processed XEL (498/503)
# Processed XYL (499/503)
# Processed YUM (500/503)
# Processed ZBRA (501/503)
# Processed ZBH (502/503)
# Processed ZTS (503/503)
# All tickers processed. Data saved in individual CSV files inside 'sp500_prices' folder.

# %% [markdown]
# ## Running the code for BRK-B and BF-B

# %%
import requests
import csv
import os
from datetime import datetime

# Replace with your EODHD API key
API_KEY = "603eafd117ce29.12741264"

# Hardcoded list of tickers
tickers = ["BRK-B", "BF-B"]

# Define the date range
start_date = "2019-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")  # Today's date

# Create a folder to store the CSV files
folder_name = "sp500_prices"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Process each ticker
for i, ticker in enumerate(tickers):
    # Construct the API URL
    url = (
        f"https://eodhd.com/api/eod/{ticker}.US?"
        f"from={start_date}&"
        f"to={end_date}&"
        f"api_token={API_KEY}&"
        f"fmt=csv"
    )

    # Fetch the data
    response = requests.get(url)

    if response.status_code == 200:
        # Parse the CSV response
        lines = response.text.splitlines()

        # Save to a ticker-specific file in the folder
        file_path = os.path.join(folder_name, f"{ticker}_prices.csv")
        with open(file_path, mode="w", newline="") as f:
            writer = csv.writer(f)
            # Write the header (first line of the response)
            writer.writerow(lines[0].split(","))
            # Write the data rows
            for line in lines[1:]:
                writer.writerow(line.split(","))
        print(f"Processed {ticker} ({i+1}/{len(tickers)})")
    else:
        print(f"Failed to fetch {ticker}: {response.status_code}")

print(f"All tickers processed. Data saved in individual CSV files inside '{folder_name}' folder.")
# Out:
# Processed BRK-B (1/2)
# Processed BF-B (2/2)
# All tickers processed. Data saved in individual CSV files inside 'sp500_prices' folder.
