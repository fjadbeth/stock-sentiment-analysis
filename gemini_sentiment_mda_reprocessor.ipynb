# %% [markdown]
# # Gemini Financial Sentiment Analysis Tool Reprocessing
#
# ## Overview
#
# This Python script uses Google's Gemini API to analyze sentiment in Management Discussion and Analysis (MDA) sections from financial filings. It focuses on reprocessing documents with missing sentiment scores, extracting various sentiment metrics, and saving results in structured formats.
#
# ## Key Features
#
# - Automated sentiment analysis of financial texts using Google's Gemini AI
# - Reprocessing capability for documents with missing sentiment scores
# - Multiple sentiment analysis methods on a scale from -1 (negative) to 1 (positive):
#   - Basic polarity detection
#   - Aspect-based analysis (revenue, earnings, management, etc.)
#   - Topic-based analysis
#   - Emotion and intent detection
# - Robust rate limiting to prevent API throttling
# - Comprehensive error handling and logging
#
# ## Installation
#
# ### Requirements
# - Python 3.6+
# - Google Gemini API key
# - Required packages: pandas, tqdm, google-generativeai
#
# ### Setup
# ```bash
# pip install pandas tqdm google-generativeai
# ```
#
# ## Configuration
#
# Edit these parameters at the top of the script:
#
# ```python
# API_KEY = "your-api-key-here"  # Required
# MODEL = "gemini-2.0-flash"     # Gemini model to use
# BATCH_SIZE = 5                 # Number of texts per batch
# MAX_REQUESTS_PER_MINUTE = 1900 # API rate limit
# REQUEST_DELAY = 0.5            # Seconds between requests
# SAVE_FREQUENCY = 20            # How often to save progress
# MAX_TEXT_LENGTH = 60000        # Maximum text length for API
# ```
#
# ## Usage
#
# ### Basic Operation
#
# 1. Run the script:
#    ```bash
#    python gemini_reprocess.py
#    ```
#
# 2. Follow the interactive prompts:
#    - Enter years to process (comma-separated or "all")
#    - Confirm file paths or provide alternatives
#    - Review progress in the terminal
#
# ### Expected File Structure
#
# ```
# project/
# ├── data/
# │   └── mda_data/
# │       └── mda_sections_YEAR.csv    # Original MDA text data
# ├── sentiment_results/
# │   └── mda/
# │       ├── mda_sentiment_YEAR_results.csv      # Input with missing scores
# │       └── mda_sentiment_YEAR_results_v2.csv   # Output with updated scores
# └── gemini_reprocess.py
# ```
#
# ## Output Files
#
# The script generates:
#
# 1. **Updated CSV file** (`mda_sentiment_YEAR_results_v2.csv`): Contains all sentiment scores
# 2. **Full JSON results** (`mda_sentiment_YEAR_results_v2_full_results.json`): Detailed sentiment data
# 3. **Log file** (`gemini_reprocess_DATETIME.log`): Processing details and errors
#
# ## Sentiment Analysis Details
#
# The script extracts multiple sentiment metrics:
#
# - **Polarity Detection**: Overall positive/negative sentiment
# - **Aspect-Based Analysis**: Sentiment for specific aspects:
#   - Financial Performance (Revenue, Earnings, Margins, Debt, Cash Flow)
#   - Management and Leadership
#   - Product/Service Performance
#   - Future Outlook
#   - Legal and Risk
# - **Topic-Based Analysis**: Sentiment across key financial topics
# - **Emotion Detection**: Dominant emotions in the text
# - **Intent Analysis**: Purpose behind the text
# - **Subjectivity/Objectivity**: Factual vs. opinion-based content
# - **Contextual Analysis**: Sentiment in broader context
#
# ## Troubleshooting
#
# - **Missing files**: The script will search for alternative paths or prompt for the correct location
# - **API failures**: Multiple retry attempts with detailed error logging
# - **Rate limits**: Automatic waiting when approaching API limits
#
# ## Error Handling
#
# The script implements robust error handling:
# - Graceful handling of API failures
# - Detailed logging of all operations
# - Safe JSON parsing with cleanup for malformed responses
# - Multiple matching strategies for finding corresponding MDA texts

# %%
import pandas as pd
import json
import time
import os
import logging
import re
from datetime import datetime
from collections import deque
from tqdm import tqdm
from google import genai

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'gemini_reprocess_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# Gemini API configuration
API_KEY = "AIzaSyAyPLiF-ckAV2N81bNwUZPzk1Vrrs-R9MI"  # Replace with your actual API key
MODEL = "gemini-2.0-flash"

# Set up Gemini client
client = genai.Client(api_key=API_KEY)

# Configure Gemini (optional parameters)
try:
    genai.configure(api_key=API_KEY)
except Exception as e:
    logger.warning(f"Could not configure genai: {e}, continuing with client-only approach")

# Constants for API limits and processing
BATCH_SIZE = 5
MAX_REQUESTS_PER_MINUTE = 1900
MAX_REQUESTS_PER_DAY = 1000000000
REQUEST_DELAY = 0.5
SAVE_FREQUENCY = 20
MAX_TEXT_LENGTH = 60000
SAVE_MDA_TEXT = False

# Create directories for outputs
os.makedirs("sentiment_results/mda", exist_ok=True)

# Class to track and enforce rate limits
class RateLimiter:
    def __init__(self, max_per_minute, max_per_day):
        self.max_per_minute = max_per_minute
        self.max_per_day = max_per_day
        self.minute_requests = deque()
        self.daily_requests = 0
        self.start_time = time.time()
    
    def check_and_wait(self):
        """Check if we can make a request, wait if needed, and track the request"""
        current_time = time.time()
        
        # Check daily limit
        if self.daily_requests >= self.max_per_day:
            logger.warning(f"Reached maximum daily request limit of {self.max_per_day}")
            return False
        
        # Clean up minute_requests older than 60 seconds
        while self.minute_requests and current_time - self.minute_requests[0] > 60:
            self.minute_requests.popleft()
        
        # Check if we're at the per-minute limit
        if len(self.minute_requests) >= self.max_per_minute:
            wait_time = 60 - (current_time - self.minute_requests[0])
            if wait_time > 0:
                logger.info(f"Rate limit approaching: Waiting {wait_time:.2f} seconds before next request")
                time.sleep(wait_time)
        
        # Always wait the minimum delay between requests
        time.sleep(REQUEST_DELAY)
        
        # Record this request
        self.minute_requests.append(time.time())
        self.daily_requests += 1
        
        return True

# Function to analyze sentiment via Gemini API with rate limiting
def analyze_sentiment_with_gemini(text):
    """
    Analyze sentiment of a single text using Gemini API
    """
    try:
        # For very long texts, use a simpler prompt to reduce token count
        if len(text) > 30000:
            prompt = f"""
Analyze this financial text for sentiment and provide a JSON response. 
Use a scale from -1 (strongly negative) to 1 (strongly positive) for all scores.

Text: {text}

Even if some aspects or topics are not explicitly mentioned, provide a score of 0 for them.

Format your response in this JSON structure:
{{
  "polarity_detection": score,
  "emotion_detection": score,
  "intent_analysis": score,
  "subjectivity_objectivity": score,
  "fine_grained_sentiment": {{
    "average_score": score
  }},
  "aspect_based_sentiment": {{
    "aspect_scores": [
      {{"Financial Performance - Revenue Growth": score}},
      {{"Financial Performance - Earnings": score}},
      {{"Financial Performance - Profit Margins": score}},
      {{"Financial Performance - Debt Levels": score}},
      {{"Financial Performance - Cash Flow": score}},
      {{"Management and Leadership": score}},
      {{"Product/Service Performance": score}},
      {{"Future Outlook": score}},
      {{"Legal and Risk": score}}
    ],
    "average_score": score
  }},
  "topic_sentiment_analysis": {{
    "topic_scores": [
      {{"Financial Performance": score}},
      {{"Management and Leadership": score}},
      {{"Product/Service Performance": score}},
      {{"Industry and Market Factors": score}},
      {{"Future Outlook": score}},
      {{"Legal and Risk": score}}
    ],
    "average_score": score
  }},
  "contextual_sentiment": {{
    "average_score": score
  }},
  "gemini_analysis": {{
    "overall_sentiment": score,
    "emotional_sentiment": score,
    "contextual_sentiment": score
  }}
}}
"""
        else:
            # Full detailed analysis for shorter texts
            prompt = f"""
Analyze the following text for sentiment using multiple methods. Provide sentiment scores between -1 (strongly negative) and 1 (strongly positive) for each method.

Text: {text}

Methods:

1. Polarity Detection (Basic Sentiment): Provide a single score representing the overall positive, negative, or neutral sentiment.

2. Fine-Grained Sentiment Analysis: Provide individual scores for different sections or perspectives within the text, if applicable, and an average score.

3. Aspect-Based Sentiment Analysis (ABSA): Identify key aspects or attributes in the text and provide sentiment scores for each aspect, and an average score. Use the following consistent aspects:
   * Financial Performance:
       * Revenue Growth
       * Earnings (EPS)
       * Profit Margins
       * Debt Levels
       * Cash Flow
   * Management and Leadership:
       * CEO Performance
       * Management Team
       * Corporate Governance
   * Product/Service Performance:
       * Product Innovation
       * Market Share
       * Customer Satisfaction
       * Product Quality
   * Future Outlook:
       * Growth Potential
       * Expansion Plans
       * Analyst Ratings
       * Investor Confidence
   * Legal and Risk:
       * Litigation
       * Financial Risks
       * Reputation Risks

4. Topic-Sentiment Analysis: Identify key topics or themes in the text and provide sentiment scores for each topic, and an average score. Use the following consistent topics:
   * Financial Performance
   * Management and Leadership
   * Product/Service Performance
   * Industry and Market Factors
   * Future Outlook
   * Legal and Risk

5. Emotion Detection: Provide a score representing the dominant emotion(s) expressed in the text. If multiple emotions are present, provide a weighted average.

6. Intent Analysis: Provide a score representing the overall intent or purpose of the text. If there are multiple intents, provide an average score.

7. Subjectivity/Objectivity Detection: Provide a score representing the overall level of subjectivity or objectivity in the text.

8. Contextual Sentiment Analysis: Provide individual scores for different contextual elements or speakers within the text, and an average score.

9. Deep Learning-Based Approach (Gemini's Analysis): Provide overall, emotional, and contextual sentiment scores using Gemini's advanced analysis.

Instructions for handling missing aspects or topics:
- If an aspect or topic is not mentioned in the text, assign it a score of 0 (neutral)
- Do not skip any predefined aspects or topics in your response
- For aspects or topics with minimal information, base the score on whatever limited information is available

Format your response as a JSON object with the following structure:

{{
  "polarity_detection": score,
  "fine_grained_sentiment": {{
    "individual_scores": [{{"section/perspective": score}}],
    "average_score": score
  }},
  "aspect_based_sentiment": {{
    "aspect_scores": [{{"aspect": score}}],
    "average_score": score
  }},
  "topic_sentiment_analysis": {{
    "topic_scores": [{{"topic": score}}],
    "average_score": score
  }},
  "emotion_detection": score,
  "intent_analysis": score,
  "subjectivity_objectivity": score,
  "contextual_sentiment": {{
    "context_scores": [{{"context_element": score}}],
    "average_score": score
  }},
  "gemini_analysis": {{
    "overall_sentiment": score,
    "emotional_sentiment": score,
    "contextual_sentiment": score
  }}
}}
"""

        # Check rate limits
        if not rate_limiter.check_and_wait():
            logger.warning("Rate limit reached. Skipping request.")
            return None

        # Use Gemini API with explicit safety settings to avoid filter issues
        try:
            logger.info("Sending request to Gemini API...")
            # Fixed approach: Create a simple prompt structure
            response = client.models.generate_content(
                model=MODEL,
                contents=[{"role": "user", "parts": [{"text": prompt}]}]
            )
            
            # Safety checks and handling
            if not hasattr(response, 'text'):
                if hasattr(response, 'prompt_feedback'):
                    logger.error(f"Content filtered: {response.prompt_feedback}")
                    return None
                elif hasattr(response, 'candidates') and len(response.candidates) > 0:
                    # Try to extract text from candidates
                    text_parts = []
                    for candidate in response.candidates:
                        if hasattr(candidate, 'content') and hasattr(candidate.content, 'parts'):
                            for part in candidate.content.parts:
                                if hasattr(part, 'text'):
                                    text_parts.append(part.text)
                    if text_parts:
                        return "".join(text_parts)
                    else:
                        logger.error("Could not extract text from response candidates")
                        return None
                else:
                    logger.error("Empty response from Gemini API")
                    logger.error(f"Response structure: {dir(response)}")
                    return None
            
            logger.info(f"Received response from Gemini API: {response.text[:100]}...")
            return response.text
        except Exception as e:
            logger.error(f"Error in Gemini API call: {e}")
            # Print more detailed error info if available
            import traceback
            logger.error(f"Error details: {traceback.format_exc()}")
            return None
    
    except Exception as e:
        logger.error(f"Error preparing sentiment analysis: {e}")
        logger.error(f"Error traceback: {traceback.format_exc()}")
        return None

def extract_json_from_response(response_text):
    """
    Extract the JSON object from the API response text
    """
    try:
        # Find the start and end of the JSON object
        start_idx = response_text.find('{')
        end_idx = response_text.rfind('}') + 1
        
        if start_idx != -1 and end_idx != -1:
            json_str = response_text[start_idx:end_idx]
            # Clean up potential issues before parsing
            json_str = re.sub(r',\s*}', '}', json_str)  # Remove trailing commas
            json_str = re.sub(r',\s*]', ']', json_str)  # Remove trailing commas in arrays
            return json.loads(json_str)
        else:
            logger.error("JSON object not found in response")
            return None
    except json.JSONDecodeError as e:
        logger.error(f"Error parsing JSON: {e}")
        logger.error(f"Problematic JSON: {response_text}")
        return None
    except Exception as e:
        logger.error(f"Unexpected error extracting JSON: {e}")
        return None

def flatten_sentiment_json(json_obj):
    """
    Flatten the nested JSON structure into a dictionary with simple key-value pairs
    """
    flat_dict = {}
    
    if not json_obj:
        logger.warning("Empty JSON object passed to flatten_sentiment_json")
        return flat_dict
    
    # Debug: Print the raw JSON
    logger.info(f"Flattening JSON with keys: {list(json_obj.keys())}")
    
    # Add default values for key metrics to ensure they exist even if missing in the JSON
    flat_dict["polarity_detection"] = 0.0
    flat_dict["emotion_detection"] = 0.0
    flat_dict["intent_analysis"] = 0.0
    flat_dict["subjectivity_objectivity"] = 0.0
    flat_dict["gemini_overall_sentiment"] = 0.0
    flat_dict["gemini_emotional_sentiment"] = 0.0
    flat_dict["gemini_contextual_sentiment"] = 0.0
    
    # Extract top-level simple scores
    for key in ['polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity']:
        if key in json_obj:
            try:
                # Extract the value and convert to float if needed
                value = json_obj[key]
                if isinstance(value, list) and len(value) > 0:
                    value = value[0]  # Extract first element if it's a list
                flat_dict[key] = float(value)
                logger.info(f"Extracted {key}: {flat_dict[key]}")
            except Exception as e:
                logger.error(f"Error extracting {key}: {e}, value was: {json_obj[key]}")
    
    # Extract Gemini Analysis scores
    if 'gemini_analysis' in json_obj:
        for sub_key, value in json_obj['gemini_analysis'].items():
            try:
                if isinstance(value, list) and len(value) > 0:
                    value = value[0]  # Extract first element if it's a list
                flat_dict[f"gemini_{sub_key}"] = float(value)
                logger.info(f"Extracted gemini_{sub_key}: {flat_dict[f'gemini_{sub_key}']}")
            except Exception as e:
                logger.error(f"Error extracting gemini_{sub_key}: {e}, value was: {value}")
    
    # Extract average scores from complex objects
    for key in ['fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'contextual_sentiment']:
        if key in json_obj and 'average_score' in json_obj[key]:
            try:
                value = json_obj[key]['average_score']
                if isinstance(value, list) and len(value) > 0:
                    value = value[0]  # Extract first element if it's a list
                flat_dict[f"{key}_avg"] = float(value)
                logger.info(f"Extracted {key}_avg: {flat_dict[f'{key}_avg']}")
            except Exception as e:
                logger.error(f"Error extracting {key}_avg: {e}, value was: {json_obj[key]['average_score']}")
    
    # Extract standardized aspect and topic scores
    if 'aspect_based_sentiment' in json_obj and 'aspect_scores' in json_obj['aspect_based_sentiment']:
        aspect_scores = json_obj['aspect_based_sentiment']['aspect_scores']
        if isinstance(aspect_scores, list):
            for score_dict in aspect_scores:
                try:
                    for aspect, score in score_dict.items():
                        # Clean up the aspect name for column naming
                        clean_aspect = aspect.strip().replace(' - ', '_').replace('/', '_').replace(' ', '_').lower()
                        if isinstance(score, list) and len(score) > 0:
                            score = score[0]  # Extract first element if it's a list
                        flat_dict[f"aspect_{clean_aspect}"] = float(score)
                        logger.info(f"Extracted aspect_{clean_aspect}: {flat_dict[f'aspect_{clean_aspect}']}")
                except Exception as e:
                    logger.error(f"Error extracting aspect score: {e}, value was: {score_dict}")
    
    if 'topic_sentiment_analysis' in json_obj and 'topic_scores' in json_obj['topic_sentiment_analysis']:
        topic_scores = json_obj['topic_sentiment_analysis']['topic_scores']
        if isinstance(topic_scores, list):
            for score_dict in topic_scores:
                try:
                    for topic, score in score_dict.items():
                        # Clean up the topic name for column naming
                        clean_topic = topic.strip().replace('/', '_').replace(' ', '_').lower()
                        if isinstance(score, list) and len(score) > 0:
                            score = score[0]  # Extract first element if it's a list
                        flat_dict[f"topic_{clean_topic}"] = float(score)
                        logger.info(f"Extracted topic_{clean_topic}: {flat_dict[f'topic_{clean_topic}']}")
                except Exception as e:
                    logger.error(f"Error extracting topic score: {e}, value was: {score_dict}")
    
    # Store the complete JSON as a string for reference
    try:
        flat_dict['full_sentiment_json'] = json.dumps(json_obj)
    except Exception as e:
        logger.error(f"Error converting JSON to string: {e}")
        flat_dict['full_sentiment_json'] = str(json_obj)
    
    logger.info(f"Flattened JSON into {len(flat_dict)} key-value pairs")
    return flat_dict

def convert_filed_date(date_str):
    """Convert filing date string to date only (YYYY-MM-DD)"""
    try:
        # Handle different date formats
        date_formats = [
            "%Y-%m-%dT%H:%M:%S%z",    # Format with timezone offset
            "%Y-%m-%dT%H:%M:%S-%z",   # Format with timezone offset separated by dash
            "%Y-%m-%dT%H:%M:%S",      # Format without timezone
            "%Y-%m-%d"                # Just date
        ]
        
        for fmt in date_formats:
            try:
                # Convert to datetime then extract only the date part
                dt = pd.to_datetime(date_str, format=fmt)
                return dt.date()  # Return only the date part (YYYY-MM-DD)
            except:
                continue
                
        # If specific formats fail, try pandas default parser
        dt = pd.to_datetime(date_str)
        return dt.date()  # Return only the date part
    except:
        # Return original if all parsing attempts fail
        logger.warning(f"Could not parse date: {date_str}")
        return date_str

# New function to reprocess only rows with NaN sentiment scores
def standardize_date_format(date_str):
    """
    Standardize date string to YYYY-MM-DD format for consistent matching
    
    Parameters:
    -----------
    date_str : str
        Date string to standardize
    
    Returns:
    --------
    str
        Standardized date string in YYYY-MM-DD format
    """
    if pd.isna(date_str) or date_str is None or date_str == '':
        return None
    
    try:
        # Try to parse using pandas (handles many formats)
        dt = pd.to_datetime(date_str)
        return dt.strftime('%Y-%m-%d')
    except:
        logger.warning(f"Could not standardize date: {date_str}")
        return date_str

def reprocess_nan_sentiment_rows(input_file, output_file, mda_file_path, retry_limit=3):
    """
    Reprocess rows with NaN sentiment scores from an existing results file
    
    Parameters:
    -----------
    input_file : str
        Path to the input CSV file with sentiment results
    output_file : str
        Path to save the updated results
    mda_file_path : str
        Path to the original MDA file with the text data
    retry_limit : int
        Number of retries for API calls
    """
    try:
        logger.info(f"Loading existing sentiment results file: {input_file}")
        # Load the existing results
        results_df = pd.read_csv(input_file)
        
        # Load the original MDA file to get the text data
        logger.info(f"Loading original MDA file: {mda_file_path}")
        mda_df = pd.read_csv(mda_file_path)
        
        # Standardize date formats in both dataframes for accurate matching
        if 'FiledAt' in results_df.columns:
            logger.info("Standardizing FiledAt dates in results dataframe")
            results_df['FiledAt'] = results_df['FiledAt'].apply(standardize_date_format)
        
        if 'FiledAt' in mda_df.columns:
            logger.info("Standardizing FiledAt dates in MDA dataframe")
            mda_df['FiledAt'] = mda_df['FiledAt'].apply(standardize_date_format)
        
        # Identify sentiment columns (they all have NaN for failed rows)
        sentiment_columns = [col for col in results_df.columns if any(term in col.lower() for term in 
                                                                   ['polarity', 'emotion', 'intent', 'sentiment', 'aspect', 'topic'])]
        
        # If no sentiment columns found, use a default set
        if not sentiment_columns:
            sentiment_columns = [
                'polarity_detection', 'emotion_detection', 'intent_analysis', 
                'subjectivity_objectivity', 'gemini_overall_sentiment'
            ]
        
        logger.info(f"Found {len(sentiment_columns)} sentiment columns")
        
        # Find rows with NaN in any sentiment column
        nan_rows = results_df[results_df[sentiment_columns].isnull().any(axis=1)]
        logger.info(f"Found {len(nan_rows)} rows with NaN sentiment scores out of {len(results_df)} total rows")
        
        if len(nan_rows) == 0:
            logger.info("No rows with NaN sentiment scores found. No reprocessing needed.")
            return results_df
        
        # Create rate limiter for API calls
        global rate_limiter
        rate_limiter = RateLimiter(MAX_REQUESTS_PER_MINUTE, MAX_REQUESTS_PER_DAY)
        
        # Track results
        results = {}
        processed_indices = set()
        
        # Process each row with NaN scores
        for idx in tqdm(nan_rows.index, desc="Reprocessing rows with NaN scores"):
            # Extract row data for matching
            ticker = results_df.loc[idx, 'Ticker'] if 'Ticker' in results_df.columns else None
            cik = results_df.loc[idx, 'CIK'] if 'CIK' in results_df.columns else None
            form_type = results_df.loc[idx, 'FormType'] if 'FormType' in results_df.columns else None
            filed_at = results_df.loc[idx, 'FiledAt'] if 'FiledAt' in results_df.columns else None
            
            # Log what we're trying to match
            logger.info(f"Looking for match: Ticker={ticker}, CIK={cik}, FormType={form_type}, FiledAt={filed_at}")
            
            # Try different matching strategies
            matching_rows = None
            
            # Strategy 1: Try matching on all fields
            if matching_rows is None or len(matching_rows) == 0:
                mask = pd.Series([True] * len(mda_df), index=mda_df.index)
                
                if ticker is not None and 'Ticker' in mda_df.columns:
                    mask = mask & (mda_df['Ticker'] == ticker)
                
                if cik is not None and 'CIK' in mda_df.columns:
                    mask = mask & (mda_df['CIK'] == cik)
                
                if form_type is not None and 'FormType' in mda_df.columns:
                    mask = mask & (mda_df['FormType'] == form_type)
                
                if filed_at is not None and 'FiledAt' in mda_df.columns:
                    mask = mask & (mda_df['FiledAt'] == filed_at)
                
                matching_rows = mda_df[mask]
                logger.info(f"Strategy 1 (all fields): Found {len(matching_rows)} matches")
            
            # Strategy 2: Match on Ticker, CIK, and FormType but not date
            if matching_rows is None or len(matching_rows) == 0:
                mask = pd.Series([True] * len(mda_df), index=mda_df.index)
                
                if ticker is not None and 'Ticker' in mda_df.columns:
                    mask = mask & (mda_df['Ticker'] == ticker)
                
                if cik is not None and 'CIK' in mda_df.columns:
                    mask = mask & (mda_df['CIK'] == cik)
                
                if form_type is not None and 'FormType' in mda_df.columns:
                    mask = mask & (mda_df['FormType'] == form_type)
                
                matching_rows = mda_df[mask]
                logger.info(f"Strategy 2 (no date): Found {len(matching_rows)} matches")
            
            # Strategy 3: Match on just Ticker and CIK
            if matching_rows is None or len(matching_rows) == 0:
                mask = pd.Series([True] * len(mda_df), index=mda_df.index)
                
                if ticker is not None and 'Ticker' in mda_df.columns:
                    mask = mask & (mda_df['Ticker'] == ticker)
                
                if cik is not None and 'CIK' in mda_df.columns:
                    mask = mask & (mda_df['CIK'] == cik)
                
                matching_rows = mda_df[mask]
                logger.info(f"Strategy 3 (Ticker+CIK): Found {len(matching_rows)} matches")
            
            # If we still have no matches, log and continue
            if len(matching_rows) == 0:
                logger.warning(f"Could not find matching row in MDA file for row {idx}")
                processed_indices.add(idx)  # Mark as processed so we don't try again
                continue
            elif len(matching_rows) > 1:
                logger.warning(f"Found multiple matching rows ({len(matching_rows)}) in MDA file for row {idx}, using the first one")
            
            # Get the MDA text from the first matching row
            try:
                mda_text = matching_rows.iloc[0]['MDA_Text']
                
                if not isinstance(mda_text, str) or not mda_text.strip():
                    logger.warning(f"Empty or invalid MDA_Text for row {idx}, skipping")
                    processed_indices.add(idx)
                    continue
                
                logger.info(f"Found matching MDA text for row {idx} (length: {len(mda_text)} chars)")
                
                # Truncate text if too long
                if len(mda_text) > MAX_TEXT_LENGTH:
                    logger.warning(f"Text too long ({len(mda_text)} chars), truncating to {MAX_TEXT_LENGTH} chars")
                    mda_text = mda_text[:MAX_TEXT_LENGTH]
                
                # Retry mechanism for API calls
                success = False
                for attempt in range(retry_limit):
                    try:
                        # Call Gemini API
                        response_text = analyze_sentiment_with_gemini(mda_text)
                        
                        if not response_text:
                            logger.error(f"No response from API for row {idx}, attempt {attempt+1}/{retry_limit}")
                            time.sleep(3)  # Wait before retry
                            continue
                        
                        # Extract JSON from response
                        sentiment_json = extract_json_from_response(response_text)
                        
                        if not sentiment_json:
                            logger.error(f"Failed to extract JSON from response for row {idx}, attempt {attempt+1}/{retry_limit}")
                            time.sleep(3)  # Wait before retry
                            continue
                        
                        # Flatten JSON
                        flat_sentiment = flatten_sentiment_json(sentiment_json)
                        
                        # Store results
                        results[idx] = flat_sentiment
                        processed_indices.add(idx)
                        
                        logger.info(f"Successfully analyzed sentiment for row {idx}")
                        success = True
                        break
                        
                    except Exception as e:
                        logger.error(f"Error on attempt {attempt+1}/{retry_limit} for row {idx}: {e}")
                        time.sleep(3)  # Wait before retry
                
                if not success:
                    logger.error(f"Failed to analyze sentiment for row {idx} after {retry_limit} attempts")
                    processed_indices.add(idx)  # Mark as processed so we don't try again
            
            except Exception as e:
                logger.error(f"Error processing row {idx}: {e}")
                processed_indices.add(idx)  # Mark as processed so we don't try again
                
            # Save progress periodically
            if len(results) % 5 == 0 and len(results) > 0:
                logger.info(f"Processed {len(results)} rows with NaN scores so far")
                
                # Periodically save intermediate results
                if len(results) % SAVE_FREQUENCY == 0:
                    # Create a temporary copy with updated results
                    temp_df = results_df.copy()
                    for tmp_idx, result in results.items():
                        for key, value in result.items():
                            if key != 'full_sentiment_json':
                                temp_df.at[tmp_idx, key] = value
                    
                    # Save intermediate results
                    temp_output = output_file.replace('.csv', f'_temp_{len(results)}.csv')
                    temp_df.to_csv(temp_output, index=False)
                    logger.info(f"Saved intermediate results to {temp_output}")
        
        # Update the results dataframe with new sentiment scores
        if results:
            logger.info(f"Updating dataframe with {len(results)} new results")
            for idx, result in results.items():
                for key, value in result.items():
                    if key != 'full_sentiment_json':  # Exclude the full JSON from the main dataframe
                        results_df.at[idx, key] = value
        else:
            logger.warning("No new results to add to dataframe!")
        
        # Save the updated results
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        results_df.to_csv(output_file, index=False)
        logger.info(f"Saved updated results to {output_file}")
        
        # Save full results with JSON
        if results:
            output_dir = os.path.dirname(output_file)
            base_name = os.path.basename(output_file).split('.')[0]
            full_output_file = os.path.join(output_dir, f"{base_name}_full_results.json")
            with open(full_output_file, 'w') as f:
                json.dump({str(idx): results[idx]['full_sentiment_json'] for idx in results if 'full_sentiment_json' in results[idx]}, f)
            logger.info(f"Saved full JSON results to {full_output_file}")
        
        return results_df
        
    except Exception as e:
        logger.error(f"Error reprocessing NaN rows: {e}")
        import traceback
        logger.error(f"Traceback: {traceback.format_exc()}")
        return None

def test_gemini_api():
    """Test the Gemini API with a small sample text"""
    logger.info("Testing Gemini API with a small sample...")
    sample_text = "The company reported strong revenue growth and exceeded analyst expectations for the quarter. However, challenges in the supply chain have impacted margins."
    
    try:
        # Simple prompt for testing
        prompt = "Analyze this text for sentiment and respond with a single word: positive, negative, or neutral: " + sample_text
        
        response = client.models.generate_content(
            model=MODEL,
            contents=prompt
        )
        
        logger.info(f"API Test Response: {response.text}")
        logger.info("Gemini API test successful!")
        return True
    except Exception as e:
        logger.error(f"Gemini API test failed: {e}")
        return False

def find_and_fix_mda_file_paths(year):
    """
    Attempt to find the correct MDA file path even if the default path doesn't exist
    
    Parameters:
    -----------
    year : str
        Year to process
    
    Returns:
    --------
    str
        Path to MDA file if found, None otherwise
    """
    # Default path
    default_path = f"data/mda_data/mda_sections_{year}.csv"
    
    # Check if default path exists
    if os.path.exists(default_path):
        return default_path
    
    # Try alternative paths
    alternatives = [
        f"mda_data/mda_sections_{year}.csv",
        f"data/mda_sections_{year}.csv",
        f"mda_sections_{year}.csv"
    ]
    
    # Check parent directories
    current_dir = os.getcwd()
    parent_dir = os.path.dirname(current_dir)
    
    for alt_path in alternatives:
        # Check in current directory
        if os.path.exists(alt_path):
            return alt_path
        
        # Check in parent directory
        parent_path = os.path.join(parent_dir, alt_path)
        if os.path.exists(parent_path):
            return parent_path
    
    # If we've made it here, try to find any file that might match
    possible_paths = []
    
    # Search patterns
    patterns = [
        f"**/mda_*{year}*.csv",
        f"**/mda*{year}*.csv",
        f"**/*mda*{year}*.csv"
    ]
    
    for pattern in patterns:
        matches = glob.glob(pattern, recursive=True)
        possible_paths.extend(matches)
    
    if possible_paths:
        logger.info(f"Found possible MDA files: {possible_paths}")
        return possible_paths[0]  # Return the first match
    
    return None

def check_mda_text_column(mda_df):
    """
    Check if MDA_Text column exists in the dataframe, try to find alternatives if not
    
    Parameters:
    -----------
    mda_df : pandas.DataFrame
        MDA dataframe to check
    
    Returns:
    --------
    pandas.DataFrame
        Modified dataframe with MDA_Text column
    """
    if 'MDA_Text' in mda_df.columns:
        return mda_df
    
    # Try to find alternative text column
    text_columns = [col for col in mda_df.columns if 'text' in col.lower() or 'mda' in col.lower()]
    
    if text_columns:
        logger.info(f"Found potential text columns: {text_columns}")
        # Use the first as MDA_Text
        mda_df['MDA_Text'] = mda_df[text_columns[0]]
        return mda_df
    
    # If no obvious text column, look for the column with the longest strings
    max_len = 0
    max_col = None
    
    for col in mda_df.columns:
        if mda_df[col].dtype == 'object':  # Only check string columns
            sample = mda_df[col].dropna().head(10)
            if len(sample) > 0:
                avg_len = sample.astype(str).apply(len).mean()
                if avg_len > max_len:
                    max_len = avg_len
                    max_col = col
    
    if max_col and max_len > 100:  # Only use if strings are reasonably long
        logger.info(f"Using column '{max_col}' as MDA_Text (avg length: {max_len})")
        mda_df['MDA_Text'] = mda_df[max_col]
    
    return mda_df

def main():
    # First test if the API is working
    if not test_gemini_api():
        logger.error("Gemini API test failed. Please check your API key and connection.")
        return
    
    print("\n=== REPROCESSING ROWS WITH MISSING SENTIMENT SCORES ===")
    
    # Ask user for years to process
    years_input = input("Which years would you like to process? (Enter comma-separated values, e.g., '2023,2024' or 'all' for all years): ")
    
    if years_input.lower() == 'all':
        years = ['2023', '2024']  # Default years
    else:
        years = [year.strip() for year in years_input.split(',')]
    
    # Process each year
    for year in years:
        # Define file paths
        sentiment_file = f"sentiment_results/mda/mda_sentiment_{year}_results.csv"
        output_file = f"sentiment_results/mda/mda_sentiment_{year}_results_v2.csv"
        
        print(f"\n=== PROCESSING YEAR: {year} ===")
        print(f"Input file: {sentiment_file}")
        
        # Check if sentiment file exists
        if not os.path.exists(sentiment_file):
            print(f"Error: Sentiment file not found: {sentiment_file}")
            # Try alternative paths
            alternatives = [
                f"mda_sentiment_{year}_results.csv",
                f"sentiment_results_mda_{year}.csv",
                f"*sentiment*{year}*.csv"
            ]
            
            found = False
            for alt_pattern in alternatives:
                matches = glob.glob(alt_pattern)
                if matches:
                    sentiment_file = matches[0]
                    print(f"Found alternative sentiment file: {sentiment_file}")
                    found = True
                    break
            
            if not found:
                print("Could not find sentiment file. Skipping year.")
                continue
        
        # Try to find MDA file
        mda_file = find_and_fix_mda_file_paths(year)
        
        if not mda_file:
            print(f"Error: Could not find MDA file for year {year}")
            # Ask user to provide path
            user_path = input(f"Please provide the path to the MDA file for {year} (or press Enter to skip): ")
            if user_path.strip():
                mda_file = user_path
            else:
                print(f"Skipping year {year}")
                continue
        
        print(f"MDA file: {mda_file}")
        print(f"Output file: {output_file}")
        
        # Ask user to confirm
        confirm = input(f"Process {year}? (y/n): ")
        if confirm.lower() != 'y':
            print(f"Skipping year {year}")
            continue
        
        # Load MDA file to check if it has the right column
        try:
            test_mda_df = pd.read_csv(mda_file)
            test_mda_df = check_mda_text_column(test_mda_df)
            if 'MDA_Text' not in test_mda_df.columns:
                print(f"Warning: Could not find or create MDA_Text column in {mda_file}")
                if input("Continue anyway? (y/n): ").lower() != 'y':
                    print(f"Skipping year {year}")
                    continue
        except Exception as e:
            print(f"Error loading MDA file: {e}")
            if input("Continue anyway? (y/n): ").lower() != 'y':
                print(f"Skipping year {year}")
                continue
        
        # Reprocess missing rows
        reprocess_nan_sentiment_rows(sentiment_file, output_file, mda_file)
        
        print(f"Completed reprocessing for year {year}")
        
        # Clean up temporary files
        temp_files = [f for f in os.listdir(os.path.dirname(output_file)) if f.startswith(f"mda_sentiment_{year}_results_v2_temp_")]
        if temp_files and input("Remove temporary files? (y/n): ").lower() == 'y':
            for temp_file in temp_files:
                temp_path = os.path.join(os.path.dirname(output_file), temp_file)
                try:
                    os.remove(temp_path)
                    print(f"Removed {temp_file}")
                except Exception as e:
                    print(f"Could not remove {temp_file}: {e}")

if __name__ == "__main__":
    main()
# Out:
# 2025-04-13 13:57:02,122 - WARNING - Could not configure genai: module 'google.genai' has no attribute 'configure', continuing with client-only approach
# 2025-04-13 13:57:02,127 - INFO - Testing Gemini API with a small sample...
# 2025-04-13 13:57:02,127 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:02,508 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:02,508 - INFO - API Test Response: Positive
#
# 2025-04-13 13:57:02,509 - INFO - Gemini API test successful!
# === REPROCESSING ROWS WITH MISSING SENTIMENT SCORES ===
# Which years would you like to process? (Enter comma-separated values, e.g., '2023,2024' or 'all' for all years):  all
# === PROCESSING YEAR: 2023 ===
# Input file: sentiment_results/mda/mda_sentiment_2023_results.csv
# MDA file: data/mda_data/mda_sections_2023.csv
# Output file: sentiment_results/mda/mda_sentiment_2023_results_v2.csv
# Process 2023? (y/n):  y
# 2025-04-13 13:57:09,972 - INFO - Loading existing sentiment results file: sentiment_results/mda/mda_sentiment_2023_results.csv
# 2025-04-13 13:57:09,977 - INFO - Loading original MDA file: data/mda_data/mda_sections_2023.csv
# 2025-04-13 13:57:10,840 - INFO - Standardizing FiledAt dates in results dataframe
# 2025-04-13 13:57:11,142 - INFO - Standardizing FiledAt dates in MDA dataframe
# 2025-04-13 13:57:11,583 - INFO - Found 25 sentiment columns
# 2025-04-13 13:57:11,586 - INFO - Found 176 rows with NaN sentiment scores out of 1943 total rows
# Reprocessing rows with NaN scores:   0%|          | 0/176 [00:00<?, ?it/s]2025-04-13 13:57:11,590 - INFO - Looking for match: Ticker=AOS, CIK=91142, FormType=10-Q, FiledAt=2023-07-28
# 2025-04-13 13:57:11,591 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:11,592 - INFO - Found matching MDA text for row 5 (length: 29493 chars)
# 2025-04-13 13:57:12,093 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:12,094 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:15,589 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:15,590 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:15,591 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:15,591 - INFO - Extracted polarity_detection: 0.1
# 2025-04-13 13:57:15,592 - INFO - Extracted emotion_detection: 0.0
# 2025-04-13 13:57:15,593 - INFO - Extracted intent_analysis: 0.1
# 2025-04-13 13:57:15,593 - INFO - Extracted subjectivity_objectivity: -0.5
# 2025-04-13 13:57:15,594 - INFO - Extracted gemini_overall_sentiment: 0.1
# 2025-04-13 13:57:15,594 - INFO - Extracted gemini_emotional_sentiment: 0.0
# 2025-04-13 13:57:15,595 - INFO - Extracted gemini_contextual_sentiment: 0.1
# 2025-04-13 13:57:15,596 - INFO - Extracted fine_grained_sentiment_avg: 0.1
# 2025-04-13 13:57:15,596 - INFO - Extracted aspect_based_sentiment_avg: 0.08
# 2025-04-13 13:57:15,597 - INFO - Extracted topic_sentiment_analysis_avg: 0.08
# 2025-04-13 13:57:15,597 - INFO - Extracted contextual_sentiment_avg: 0.1
# 2025-04-13 13:57:15,598 - INFO - Extracted aspect_financial_performance: 0.2
# 2025-04-13 13:57:15,598 - INFO - Extracted aspect_management_and_leadership: 0.1
# 2025-04-13 13:57:15,599 - INFO - Extracted aspect_product_service_performance: 0.2
# 2025-04-13 13:57:15,600 - INFO - Extracted aspect_future_outlook: 0.1
# 2025-04-13 13:57:15,600 - INFO - Extracted aspect_legal_and_risk: -0.1
# 2025-04-13 13:57:15,601 - INFO - Extracted aspect_revenue_growth: 0.2
# 2025-04-13 13:57:15,601 - INFO - Extracted aspect_earnings_(eps): 0.2
# 2025-04-13 13:57:15,602 - INFO - Extracted aspect_profit_margins: 0.3
# 2025-04-13 13:57:15,602 - INFO - Extracted aspect_debt_levels: 0.2
# 2025-04-13 13:57:15,603 - INFO - Extracted aspect_cash_flow: 0.3
# 2025-04-13 13:57:15,603 - INFO - Extracted aspect_ceo_performance: 0.0
# 2025-04-13 13:57:15,604 - INFO - Extracted aspect_management_team: 0.0
# 2025-04-13 13:57:15,604 - INFO - Extracted aspect_corporate_governance: 0.0
# 2025-04-13 13:57:15,605 - INFO - Extracted aspect_product_innovation: 0.0
# 2025-04-13 13:57:15,605 - INFO - Extracted aspect_market_share: 0.1
# 2025-04-13 13:57:15,606 - INFO - Extracted aspect_customer_satisfaction: 0.1
# 2025-04-13 13:57:15,606 - INFO - Extracted aspect_product_quality: 0.0
# 2025-04-13 13:57:15,608 - INFO - Extracted aspect_growth_potential: 0.1
# 2025-04-13 13:57:15,608 - INFO - Extracted aspect_expansion_plans: 0.1
# 2025-04-13 13:57:15,609 - INFO - Extracted aspect_analyst_ratings: 0.0
# 2025-04-13 13:57:15,609 - INFO - Extracted aspect_investor_confidence: 0.1
# 2025-04-13 13:57:15,609 - INFO - Extracted aspect_litigation: 0.0
# 2025-04-13 13:57:15,610 - INFO - Extracted aspect_financial_risks: -0.2
# 2025-04-13 13:57:15,611 - INFO - Extracted aspect_reputation_risks: 0.0
# 2025-04-13 13:57:15,611 - INFO - Extracted topic_financial_performance: 0.2
# 2025-04-13 13:57:15,612 - INFO - Extracted topic_management_and_leadership: 0.1
# 2025-04-13 13:57:15,612 - INFO - Extracted topic_product_service_performance: 0.2
# 2025-04-13 13:57:15,613 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 13:57:15,614 - INFO - Extracted topic_future_outlook: 0.1
# 2025-04-13 13:57:15,614 - INFO - Extracted topic_legal_and_risk: -0.1
# 2025-04-13 13:57:15,615 - INFO - Flattened JSON into 42 key-value pairs
# 2025-04-13 13:57:15,615 - INFO - Successfully analyzed sentiment for row 5
# Reprocessing rows with NaN scores:   1%|          | 1/176 [00:04<11:44,  4.03s/it]2025-04-13 13:57:15,617 - INFO - Looking for match: Ticker=AOS, CIK=91142, FormType=10-Q, FiledAt=2023-04-28
# 2025-04-13 13:57:15,620 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:15,621 - INFO - Found matching MDA text for row 6 (length: 23947 chars)
# 2025-04-13 13:57:16,122 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:16,123 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:19,799 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:19,800 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.2,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:19,801 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:19,801 - INFO - Extracted polarity_detection: 0.2
# 2025-04-13 13:57:19,801 - INFO - Extracted emotion_detection: 0.1
# 2025-04-13 13:57:19,802 - INFO - Extracted intent_analysis: 0.4
# 2025-04-13 13:57:19,803 - INFO - Extracted subjectivity_objectivity: -0.5
# 2025-04-13 13:57:19,803 - INFO - Extracted gemini_overall_sentiment: 0.2
# 2025-04-13 13:57:19,804 - INFO - Extracted gemini_emotional_sentiment: 0.1
# 2025-04-13 13:57:19,804 - INFO - Extracted gemini_contextual_sentiment: 0.1
# 2025-04-13 13:57:19,805 - INFO - Extracted fine_grained_sentiment_avg: 0.157
# 2025-04-13 13:57:19,805 - INFO - Extracted aspect_based_sentiment_avg: 0.146
# 2025-04-13 13:57:19,805 - INFO - Extracted topic_sentiment_analysis_avg: 0.133
# 2025-04-13 13:57:19,806 - INFO - Extracted contextual_sentiment_avg: 0.125
# 2025-04-13 13:57:19,807 - INFO - Extracted aspect_financial_performance: 0.3
# 2025-04-13 13:57:19,807 - INFO - Extracted aspect_management_and_leadership: 0.2
# 2025-04-13 13:57:19,808 - INFO - Extracted aspect_product_service_performance: 0.3
# 2025-04-13 13:57:19,808 - INFO - Extracted aspect_future_outlook: 0.1
# 2025-04-13 13:57:19,809 - INFO - Extracted aspect_legal_and_risk: -0.1
# 2025-04-13 13:57:19,809 - INFO - Extracted aspect_revenue_growth: 0.2
# 2025-04-13 13:57:19,810 - INFO - Extracted aspect_earnings_(eps): 0.3
# 2025-04-13 13:57:19,810 - INFO - Extracted aspect_profit_margins: 0.4
# 2025-04-13 13:57:19,811 - INFO - Extracted aspect_debt_levels: 0.3
# 2025-04-13 13:57:19,811 - INFO - Extracted aspect_cash_flow: 0.5
# 2025-04-13 13:57:19,812 - INFO - Extracted aspect_ceo_performance: 0.0
# 2025-04-13 13:57:19,812 - INFO - Extracted aspect_management_team: 0.2
# 2025-04-13 13:57:19,813 - INFO - Extracted aspect_corporate_governance: 0.2
# 2025-04-13 13:57:19,813 - INFO - Extracted aspect_product_innovation: 0.1
# 2025-04-13 13:57:19,814 - INFO - Extracted aspect_market_share: 0.2
# 2025-04-13 13:57:19,814 - INFO - Extracted aspect_customer_satisfaction: 0.1
# 2025-04-13 13:57:19,815 - INFO - Extracted aspect_product_quality: 0.1
# 2025-04-13 13:57:19,815 - INFO - Extracted aspect_growth_potential: 0.1
# 2025-04-13 13:57:19,816 - INFO - Extracted aspect_expansion_plans: 0.2
# 2025-04-13 13:57:19,816 - INFO - Extracted aspect_analyst_ratings: 0.0
# 2025-04-13 13:57:19,816 - INFO - Extracted aspect_investor_confidence: 0.1
# 2025-04-13 13:57:19,817 - INFO - Extracted aspect_litigation: 0.0
# 2025-04-13 13:57:19,817 - INFO - Extracted aspect_financial_risks: -0.2
# 2025-04-13 13:57:19,818 - INFO - Extracted aspect_reputation_risks: 0.0
# 2025-04-13 13:57:19,819 - INFO - Extracted topic_financial_performance: 0.3
# 2025-04-13 13:57:19,819 - INFO - Extracted topic_management_and_leadership: 0.2
# 2025-04-13 13:57:19,820 - INFO - Extracted topic_product_service_performance: 0.2
# 2025-04-13 13:57:19,820 - INFO - Extracted topic_industry_and_market_factors: 0.1
# 2025-04-13 13:57:19,820 - INFO - Extracted topic_future_outlook: 0.1
# 2025-04-13 13:57:19,821 - INFO - Extracted topic_legal_and_risk: -0.1
# 2025-04-13 13:57:19,822 - INFO - Flattened JSON into 42 key-value pairs
# 2025-04-13 13:57:19,822 - INFO - Successfully analyzed sentiment for row 6
# Reprocessing rows with NaN scores:   1%|          | 2/176 [00:08<11:59,  4.13s/it]2025-04-13 13:57:19,823 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-Q, FiledAt=2023-11-01
# 2025-04-13 13:57:19,825 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:19,825 - INFO - Found matching MDA text for row 8 (length: 25584 chars)
# 2025-04-13 13:57:20,326 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:20,327 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:23,834 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:23,835 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:23,836 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:23,836 - INFO - Extracted polarity_detection: 0.1
# 2025-04-13 13:57:23,836 - INFO - Extracted emotion_detection: 0.0
# 2025-04-13 13:57:23,836 - INFO - Extracted intent_analysis: 0.6
# 2025-04-13 13:57:23,836 - INFO - Extracted subjectivity_objectivity: -0.5
# 2025-04-13 13:57:23,837 - INFO - Extracted gemini_overall_sentiment: 0.05
# 2025-04-13 13:57:23,837 - INFO - Extracted gemini_emotional_sentiment: -0.1
# 2025-04-13 13:57:23,837 - INFO - Extracted gemini_contextual_sentiment: 0.1
# 2025-04-13 13:57:23,837 - INFO - Extracted fine_grained_sentiment_avg: 0.075
# 2025-04-13 13:57:23,838 - INFO - Extracted aspect_based_sentiment_avg: 0.026
# 2025-04-13 13:57:23,838 - INFO - Extracted topic_sentiment_analysis_avg: 0.0
# 2025-04-13 13:57:23,838 - INFO - Extracted contextual_sentiment_avg: 0.066
# 2025-04-13 13:57:23,838 - INFO - Extracted aspect_financial_performance:_revenue_growth: 0.2
# 2025-04-13 13:57:23,838 - INFO - Extracted aspect_financial_performance:_earnings_(eps): 0.1
# 2025-04-13 13:57:23,839 - INFO - Extracted aspect_financial_performance:_profit_margins: -0.1
# 2025-04-13 13:57:23,839 - INFO - Extracted aspect_financial_performance:_debt_levels: 0.1
# 2025-04-13 13:57:23,840 - INFO - Extracted aspect_financial_performance:_cash_flow: -0.1
# 2025-04-13 13:57:23,840 - INFO - Extracted aspect_management_and_leadership:_ceo_performance: 0.0
# 2025-04-13 13:57:23,840 - INFO - Extracted aspect_management_and_leadership:_management_team: 0.0
# 2025-04-13 13:57:23,840 - INFO - Extracted aspect_management_and_leadership:_corporate_governance: 0.0
# 2025-04-13 13:57:23,841 - INFO - Extracted aspect_product_service_performance:_product_innovation: 0.3
# 2025-04-13 13:57:23,841 - INFO - Extracted aspect_product_service_performance:_market_share: 0.2
# 2025-04-13 13:57:23,841 - INFO - Extracted aspect_product_service_performance:_customer_satisfaction: 0.0
# 2025-04-13 13:57:23,841 - INFO - Extracted aspect_product_service_performance:_product_quality: 0.0
# 2025-04-13 13:57:23,842 - INFO - Extracted aspect_future_outlook:_growth_potential: 0.2
# 2025-04-13 13:57:23,842 - INFO - Extracted aspect_future_outlook:_expansion_plans: 0.0
# 2025-04-13 13:57:23,842 - INFO - Extracted aspect_future_outlook:_analyst_ratings: 0.0
# 2025-04-13 13:57:23,842 - INFO - Extracted aspect_future_outlook:_investor_confidence: 0.0
# 2025-04-13 13:57:23,843 - INFO - Extracted aspect_legal_and_risk:_litigation: -0.3
# 2025-04-13 13:57:23,843 - INFO - Extracted aspect_legal_and_risk:_financial_risks: -0.2
# 2025-04-13 13:57:23,843 - INFO - Extracted aspect_legal_and_risk:_reputation_risks: 0.0
# 2025-04-13 13:57:23,843 - INFO - Extracted topic_financial_performance: 0.0
# 2025-04-13 13:57:23,843 - INFO - Extracted topic_management_and_leadership: 0.0
# 2025-04-13 13:57:23,844 - INFO - Extracted topic_product_service_performance: 0.2
# 2025-04-13 13:57:23,844 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 13:57:23,844 - INFO - Extracted topic_future_outlook: 0.0
# 2025-04-13 13:57:23,844 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 13:57:23,844 - INFO - Flattened JSON into 37 key-value pairs
# 2025-04-13 13:57:23,845 - INFO - Successfully analyzed sentiment for row 8
# Reprocessing rows with NaN scores:   2%|▏         | 3/176 [00:12<11:46,  4.08s/it]2025-04-13 13:57:23,846 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-Q, FiledAt=2023-08-03
# 2025-04-13 13:57:23,848 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:23,849 - INFO - Found matching MDA text for row 9 (length: 22058 chars)
# 2025-04-13 13:57:24,349 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:24,350 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:28,152 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:28,153 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": -0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#    ...
# 2025-04-13 13:57:28,154 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:28,155 - INFO - Extracted polarity_detection: -0.1
# 2025-04-13 13:57:28,155 - INFO - Extracted emotion_detection: -0.1
# 2025-04-13 13:57:28,156 - INFO - Extracted intent_analysis: 0.1
# 2025-04-13 13:57:28,156 - INFO - Extracted subjectivity_objectivity: -0.6
# 2025-04-13 13:57:28,157 - INFO - Extracted gemini_overall_sentiment: -0.1
# 2025-04-13 13:57:28,157 - INFO - Extracted gemini_emotional_sentiment: -0.2
# 2025-04-13 13:57:28,158 - INFO - Extracted gemini_contextual_sentiment: -0.1
# 2025-04-13 13:57:28,158 - INFO - Extracted fine_grained_sentiment_avg: -0.044
# 2025-04-13 13:57:28,158 - INFO - Extracted aspect_based_sentiment_avg: 0.0167
# 2025-04-13 13:57:28,160 - INFO - Extracted topic_sentiment_analysis_avg: -0.033
# 2025-04-13 13:57:28,160 - INFO - Extracted contextual_sentiment_avg: -0.06
# 2025-04-13 13:57:28,160 - INFO - Extracted aspect_financial_performance: -0.2
# 2025-04-13 13:57:28,161 - INFO - Extracted aspect_revenue_growth: -0.2
# 2025-04-13 13:57:28,161 - INFO - Extracted aspect_earnings_(eps): -0.1
# 2025-04-13 13:57:28,162 - INFO - Extracted aspect_profit_margins: -0.1
# 2025-04-13 13:57:28,162 - INFO - Extracted aspect_debt_levels: 0.1
# 2025-04-13 13:57:28,163 - INFO - Extracted aspect_cash_flow: -0.1
# 2025-04-13 13:57:28,164 - INFO - Extracted aspect_management_and_leadership: 0.0
# 2025-04-13 13:57:28,164 - INFO - Extracted aspect_ceo_performance: 0.0
# 2025-04-13 13:57:28,165 - INFO - Extracted aspect_management_team: 0.0
# 2025-04-13 13:57:28,165 - INFO - Extracted aspect_corporate_governance: 0.0
# 2025-04-13 13:57:28,166 - INFO - Extracted aspect_product_service_performance: 0.2
# 2025-04-13 13:57:28,166 - INFO - Extracted aspect_product_innovation: 0.3
# 2025-04-13 13:57:28,166 - INFO - Extracted aspect_market_share: 0.1
# 2025-04-13 13:57:28,167 - INFO - Extracted aspect_customer_satisfaction: 0.0
# 2025-04-13 13:57:28,167 - INFO - Extracted aspect_product_quality: 0.0
# 2025-04-13 13:57:28,168 - INFO - Extracted aspect_future_outlook: 0.1
# 2025-04-13 13:57:28,168 - INFO - Extracted aspect_growth_potential: 0.2
# 2025-04-13 13:57:28,169 - INFO - Extracted aspect_expansion_plans: 0.0
# 2025-04-13 13:57:28,169 - INFO - Extracted aspect_analyst_ratings: 0.0
# 2025-04-13 13:57:28,170 - INFO - Extracted aspect_investor_confidence: 0.0
# 2025-04-13 13:57:28,170 - INFO - Extracted aspect_legal_and_risk: -0.2
# 2025-04-13 13:57:28,171 - INFO - Extracted aspect_litigation: 0.0
# 2025-04-13 13:57:28,171 - INFO - Extracted aspect_financial_risks: -0.2
# 2025-04-13 13:57:28,172 - INFO - Extracted aspect_reputation_risks: -0.1
# 2025-04-13 13:57:28,172 - INFO - Extracted topic_financial_performance: -0.2
# 2025-04-13 13:57:28,173 - INFO - Extracted topic_management_and_leadership: 0.0
# 2025-04-13 13:57:28,173 - INFO - Extracted topic_product_service_performance: 0.2
# 2025-04-13 13:57:28,174 - INFO - Extracted topic_industry_and_market_factors: -0.1
# 2025-04-13 13:57:28,174 - INFO - Extracted topic_future_outlook: 0.1
# 2025-04-13 13:57:28,175 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 13:57:28,176 - INFO - Flattened JSON into 42 key-value pairs
# 2025-04-13 13:57:28,176 - INFO - Successfully analyzed sentiment for row 9
# Reprocessing rows with NaN scores:   2%|▏         | 4/176 [00:16<11:59,  4.18s/it]2025-04-13 13:57:28,178 - INFO - Looking for match: Ticker=ABT, CIK=1800, FormType=10-Q, FiledAt=2023-05-04
# 2025-04-13 13:57:28,180 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:28,181 - INFO - Found matching MDA text for row 10 (length: 17847 chars)
# 2025-04-13 13:57:28,682 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:28,683 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:32,653 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:32,654 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:32,655 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:32,655 - INFO - Extracted polarity_detection: 0.1
# 2025-04-13 13:57:32,656 - INFO - Extracted emotion_detection: 0.05
# 2025-04-13 13:57:32,657 - INFO - Extracted intent_analysis: 0.6
# 2025-04-13 13:57:32,657 - INFO - Extracted subjectivity_objectivity: -0.7
# 2025-04-13 13:57:32,657 - INFO - Extracted gemini_overall_sentiment: 0.1
# 2025-04-13 13:57:32,658 - INFO - Extracted gemini_emotional_sentiment: 0.0
# 2025-04-13 13:57:32,659 - INFO - Extracted gemini_contextual_sentiment: 0.0
# 2025-04-13 13:57:32,659 - INFO - Extracted fine_grained_sentiment_avg: 0.04
# 2025-04-13 13:57:32,660 - INFO - Extracted aspect_based_sentiment_avg: 0.042
# 2025-04-13 13:57:32,660 - INFO - Extracted topic_sentiment_analysis_avg: 0.03
# 2025-04-13 13:57:32,661 - INFO - Extracted contextual_sentiment_avg: -0.05
# 2025-04-13 13:57:32,661 - INFO - Extracted aspect_financial_performance:_revenue_growth: -0.1
# 2025-04-13 13:57:32,662 - INFO - Extracted aspect_financial_performance:_earnings_(eps): 0.0
# 2025-04-13 13:57:32,662 - INFO - Extracted aspect_financial_performance:_profit_margins: -0.2
# 2025-04-13 13:57:32,663 - INFO - Extracted aspect_financial_performance:_debt_levels: 0.1
# 2025-04-13 13:57:32,663 - INFO - Extracted aspect_financial_performance:_cash_flow: 0.0
# 2025-04-13 13:57:32,663 - INFO - Extracted aspect_management_and_leadership:_ceo_performance: 0.0
# 2025-04-13 13:57:32,664 - INFO - Extracted aspect_management_and_leadership:_management_team: 0.0
# 2025-04-13 13:57:32,664 - INFO - Extracted aspect_management_and_leadership:_corporate_governance: 0.0
# 2025-04-13 13:57:32,665 - INFO - Extracted aspect_product_service_performance:_product_innovation: 0.3
# 2025-04-13 13:57:32,665 - INFO - Extracted aspect_product_service_performance:_market_share: 0.2
# 2025-04-13 13:57:32,665 - INFO - Extracted aspect_product_service_performance:_customer_satisfaction: 0.0
# 2025-04-13 13:57:32,667 - INFO - Extracted aspect_product_service_performance:_product_quality: 0.0
# 2025-04-13 13:57:32,667 - INFO - Extracted aspect_future_outlook:_growth_potential: 0.1
# 2025-04-13 13:57:32,668 - INFO - Extracted aspect_future_outlook:_expansion_plans: 0.2
# 2025-04-13 13:57:32,668 - INFO - Extracted aspect_future_outlook:_analyst_ratings: 0.0
# 2025-04-13 13:57:32,669 - INFO - Extracted aspect_future_outlook:_investor_confidence: 0.0
# 2025-04-13 13:57:32,669 - INFO - Extracted aspect_legal_and_risk:_litigation: 0.0
# 2025-04-13 13:57:32,670 - INFO - Extracted aspect_legal_and_risk:_financial_risks: -0.1
# 2025-04-13 13:57:32,670 - INFO - Extracted aspect_legal_and_risk:_reputation_risks: 0.0
# 2025-04-13 13:57:32,671 - INFO - Extracted topic_financial_performance: -0.04
# 2025-04-13 13:57:32,671 - INFO - Extracted topic_management_and_leadership: 0.0
# 2025-04-13 13:57:32,672 - INFO - Extracted topic_product_service_performance: 0.17
# 2025-04-13 13:57:32,672 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 13:57:32,673 - INFO - Extracted topic_future_outlook: 0.08
# 2025-04-13 13:57:32,673 - INFO - Extracted topic_legal_and_risk: -0.03
# 2025-04-13 13:57:32,674 - INFO - Flattened JSON into 37 key-value pairs
# 2025-04-13 13:57:32,674 - INFO - Successfully analyzed sentiment for row 10
# 2025-04-13 13:57:32,675 - INFO - Processed 5 rows with NaN scores so far
# Reprocessing rows with NaN scores:   3%|▎         | 5/176 [00:21<12:14,  4.30s/it]2025-04-13 13:57:32,676 - INFO - Looking for match: Ticker=ABBV, CIK=1551152, FormType=10-Q, FiledAt=2023-05-05
# 2025-04-13 13:57:32,679 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:32,680 - INFO - Found matching MDA text for row 14 (length: 27182 chars)
# 2025-04-13 13:57:33,180 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:33,181 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:37,780 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:37,781 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:37,781 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:37,782 - INFO - Extracted polarity_detection: 0.1
# 2025-04-13 13:57:37,783 - INFO - Extracted emotion_detection: 0.05
# 2025-04-13 13:57:37,783 - INFO - Extracted intent_analysis: 0.1
# 2025-04-13 13:57:37,784 - INFO - Extracted subjectivity_objectivity: -0.8
# 2025-04-13 13:57:37,784 - INFO - Extracted gemini_overall_sentiment: 0.05
# 2025-04-13 13:57:37,784 - INFO - Extracted gemini_emotional_sentiment: 0.02
# 2025-04-13 13:57:37,785 - INFO - Extracted gemini_contextual_sentiment: 0.03
# 2025-04-13 13:57:37,786 - INFO - Extracted fine_grained_sentiment_avg: 0.064
# 2025-04-13 13:57:37,786 - INFO - Extracted aspect_based_sentiment_avg: 0.047
# 2025-04-13 13:57:37,787 - INFO - Extracted topic_sentiment_analysis_avg: 0.022
# 2025-04-13 13:57:37,787 - INFO - Extracted contextual_sentiment_avg: 0.05
# 2025-04-13 13:57:37,788 - INFO - Extracted aspect_financial_performance:_revenue_growth: -0.2
# 2025-04-13 13:57:37,788 - INFO - Extracted aspect_financial_performance:_earnings_(eps): -0.3
# 2025-04-13 13:57:37,789 - INFO - Extracted aspect_financial_performance:_profit_margins: -0.2
# 2025-04-13 13:57:37,789 - INFO - Extracted aspect_financial_performance:_debt_levels: 0.3
# 2025-04-13 13:57:37,790 - INFO - Extracted aspect_financial_performance:_cash_flow: 0.2
# 2025-04-13 13:57:37,790 - INFO - Extracted aspect_management_and_leadership:_ceo_performance: 0.0
# 2025-04-13 13:57:37,791 - INFO - Extracted aspect_management_and_leadership:_management_team: 0.1
# 2025-04-13 13:57:37,791 - INFO - Extracted aspect_management_and_leadership:_corporate_governance: 0.0
# 2025-04-13 13:57:37,792 - INFO - Extracted aspect_product_service_performance:_product_innovation: 0.4
# 2025-04-13 13:57:37,792 - INFO - Extracted aspect_product_service_performance:_market_share: 0.2
# 2025-04-13 13:57:37,793 - INFO - Extracted aspect_product_service_performance:_customer_satisfaction: 0.0
# 2025-04-13 13:57:37,793 - INFO - Extracted aspect_product_service_performance:_product_quality: 0.0
# 2025-04-13 13:57:37,794 - INFO - Extracted aspect_future_outlook:_growth_potential: 0.3
# 2025-04-13 13:57:37,794 - INFO - Extracted aspect_future_outlook:_expansion_plans: 0.1
# 2025-04-13 13:57:37,795 - INFO - Extracted aspect_future_outlook:_analyst_ratings: 0.0
# 2025-04-13 13:57:37,795 - INFO - Extracted aspect_future_outlook:_investor_confidence: 0.0
# 2025-04-13 13:57:37,796 - INFO - Extracted aspect_legal_and_risk:_litigation: 0.0
# 2025-04-13 13:57:37,796 - INFO - Extracted aspect_legal_and_risk:_financial_risks: -0.2
# 2025-04-13 13:57:37,797 - INFO - Extracted aspect_legal_and_risk:_reputation_risks: 0.0
# 2025-04-13 13:57:37,797 - INFO - Extracted topic_financial_performance: -0.1
# 2025-04-13 13:57:37,798 - INFO - Extracted topic_management_and_leadership: 0.03
# 2025-04-13 13:57:37,798 - INFO - Extracted topic_product_service_performance: 0.2
# 2025-04-13 13:57:37,798 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 13:57:37,799 - INFO - Extracted topic_future_outlook: 0.1
# 2025-04-13 13:57:37,799 - INFO - Extracted topic_legal_and_risk: -0.1
# 2025-04-13 13:57:37,800 - INFO - Flattened JSON into 37 key-value pairs
# 2025-04-13 13:57:37,800 - INFO - Successfully analyzed sentiment for row 14
# Reprocessing rows with NaN scores:   3%|▎         | 6/176 [00:26<12:58,  4.58s/it]2025-04-13 13:57:37,802 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-Q, FiledAt=2023-11-01
# 2025-04-13 13:57:37,804 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:37,805 - INFO - Found matching MDA text for row 24 (length: 29550 chars)
# 2025-04-13 13:57:38,306 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:38,307 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:41,679 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:41,680 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.2,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:41,681 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:41,681 - INFO - Extracted polarity_detection: 0.2
# 2025-04-13 13:57:41,682 - INFO - Extracted emotion_detection: 0.1
# 2025-04-13 13:57:41,682 - INFO - Extracted intent_analysis: 0.7
# 2025-04-13 13:57:41,683 - INFO - Extracted subjectivity_objectivity: -0.6
# 2025-04-13 13:57:41,683 - INFO - Extracted gemini_overall_sentiment: 0.2
# 2025-04-13 13:57:41,684 - INFO - Extracted gemini_emotional_sentiment: 0.0
# 2025-04-13 13:57:41,685 - INFO - Extracted gemini_contextual_sentiment: 0.3
# 2025-04-13 13:57:41,685 - INFO - Extracted fine_grained_sentiment_avg: 0.2
# 2025-04-13 13:57:41,686 - INFO - Extracted aspect_based_sentiment_avg: 0.17
# 2025-04-13 13:57:41,687 - INFO - Extracted topic_sentiment_analysis_avg: 0.18
# 2025-04-13 13:57:41,687 - INFO - Extracted contextual_sentiment_avg: 0.2
# 2025-04-13 13:57:41,688 - INFO - Extracted aspect_financial_performance: 0.4
# 2025-04-13 13:57:41,688 - INFO - Extracted aspect_management_and_leadership: 0.1
# 2025-04-13 13:57:41,689 - INFO - Extracted aspect_product_service_performance: 0.5
# 2025-04-13 13:57:41,689 - INFO - Extracted aspect_future_outlook: 0.2
# 2025-04-13 13:57:41,690 - INFO - Extracted aspect_legal_and_risk: -0.2
# 2025-04-13 13:57:41,690 - INFO - Extracted aspect_revenue_growth: 0.4
# 2025-04-13 13:57:41,691 - INFO - Extracted aspect_earnings_(eps): 0.4
# 2025-04-13 13:57:41,692 - INFO - Extracted aspect_profit_margins: 0.4
# 2025-04-13 13:57:41,692 - INFO - Extracted aspect_debt_levels: 0.2
# 2025-04-13 13:57:41,692 - INFO - Extracted aspect_cash_flow: 0.4
# 2025-04-13 13:57:41,693 - INFO - Extracted aspect_ceo_performance: 0.0
# 2025-04-13 13:57:41,694 - INFO - Extracted aspect_management_team: 0.1
# 2025-04-13 13:57:41,694 - INFO - Extracted aspect_corporate_governance: 0.1
# 2025-04-13 13:57:41,694 - INFO - Extracted aspect_product_innovation: 0.5
# 2025-04-13 13:57:41,695 - INFO - Extracted aspect_market_share: 0.3
# 2025-04-13 13:57:41,695 - INFO - Extracted aspect_customer_satisfaction: 0.0
# 2025-04-13 13:57:41,696 - INFO - Extracted aspect_product_quality: 0.3
# 2025-04-13 13:57:41,696 - INFO - Extracted aspect_growth_potential: 0.3
# 2025-04-13 13:57:41,697 - INFO - Extracted aspect_expansion_plans: 0.0
# 2025-04-13 13:57:41,697 - INFO - Extracted aspect_analyst_ratings: 0.0
# 2025-04-13 13:57:41,698 - INFO - Extracted aspect_investor_confidence: 0.2
# 2025-04-13 13:57:41,698 - INFO - Extracted aspect_litigation: 0.0
# 2025-04-13 13:57:41,699 - INFO - Extracted aspect_financial_risks: -0.2
# 2025-04-13 13:57:41,699 - INFO - Extracted aspect_reputation_risks: 0.0
# 2025-04-13 13:57:41,700 - INFO - Extracted topic_financial_performance: 0.4
# 2025-04-13 13:57:41,700 - INFO - Extracted topic_management_and_leadership: 0.1
# 2025-04-13 13:57:41,701 - INFO - Extracted topic_product_service_performance: 0.5
# 2025-04-13 13:57:41,702 - INFO - Extracted topic_industry_and_market_factors: 0.1
# 2025-04-13 13:57:41,702 - INFO - Extracted topic_future_outlook: 0.2
# 2025-04-13 13:57:41,703 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 13:57:41,703 - INFO - Flattened JSON into 42 key-value pairs
# 2025-04-13 13:57:41,704 - INFO - Successfully analyzed sentiment for row 24
# Reprocessing rows with NaN scores:   4%|▍         | 7/176 [00:30<12:16,  4.36s/it]2025-04-13 13:57:41,705 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-Q, FiledAt=2023-08-02
# 2025-04-13 13:57:41,707 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:41,708 - INFO - Found matching MDA text for row 25 (length: 28732 chars)
# 2025-04-13 13:57:42,209 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:42,210 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:46,306 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:46,307 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": -0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#    ...
# 2025-04-13 13:57:46,308 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:46,309 - INFO - Extracted polarity_detection: -0.1
# 2025-04-13 13:57:46,309 - INFO - Extracted emotion_detection: -0.2
# 2025-04-13 13:57:46,309 - INFO - Extracted intent_analysis: 0.0
# 2025-04-13 13:57:46,310 - INFO - Extracted subjectivity_objectivity: -0.8
# 2025-04-13 13:57:46,311 - INFO - Extracted gemini_overall_sentiment: -0.15
# 2025-04-13 13:57:46,311 - INFO - Extracted gemini_emotional_sentiment: -0.2
# 2025-04-13 13:57:46,312 - INFO - Extracted gemini_contextual_sentiment: 0.0
# 2025-04-13 13:57:46,312 - INFO - Extracted fine_grained_sentiment_avg: -0.17777777777777778
# 2025-04-13 13:57:46,313 - INFO - Extracted aspect_based_sentiment_avg: -0.042105263157894736
# 2025-04-13 13:57:46,313 - INFO - Extracted topic_sentiment_analysis_avg: -0.08333333333333333
# 2025-04-13 13:57:46,314 - INFO - Extracted contextual_sentiment_avg: -0.05
# 2025-04-13 13:57:46,314 - INFO - Extracted aspect_financial_performance_revenue_growth: -0.3
# 2025-04-13 13:57:46,314 - INFO - Extracted aspect_financial_performance_earnings_(eps): -0.4
# 2025-04-13 13:57:46,315 - INFO - Extracted aspect_financial_performance_profit_margins: -0.1
# 2025-04-13 13:57:46,315 - INFO - Extracted aspect_financial_performance_debt_levels: 0.1
# 2025-04-13 13:57:46,316 - INFO - Extracted aspect_financial_performance_cash_flow: 0.2
# 2025-04-13 13:57:46,317 - INFO - Extracted aspect_management_and_leadership_ceo_performance: 0.0
# 2025-04-13 13:57:46,317 - INFO - Extracted aspect_management_and_leadership_management_team: 0.0
# 2025-04-13 13:57:46,318 - INFO - Extracted aspect_management_and_leadership_corporate_governance: 0.0
# 2025-04-13 13:57:46,318 - INFO - Extracted aspect_product_service_performance_product_innovation: 0.3
# 2025-04-13 13:57:46,319 - INFO - Extracted aspect_product_service_performance_market_share: -0.1
# 2025-04-13 13:57:46,319 - INFO - Extracted aspect_product_service_performance_customer_satisfaction: 0.0
# 2025-04-13 13:57:46,319 - INFO - Extracted aspect_product_service_performance_product_quality: 0.0
# 2025-04-13 13:57:46,320 - INFO - Extracted aspect_future_outlook_growth_potential: 0.1
# 2025-04-13 13:57:46,321 - INFO - Extracted aspect_future_outlook_expansion_plans: 0.0
# 2025-04-13 13:57:46,321 - INFO - Extracted aspect_future_outlook_analyst_ratings: 0.0
# 2025-04-13 13:57:46,321 - INFO - Extracted aspect_future_outlook_investor_confidence: 0.0
# 2025-04-13 13:57:46,322 - INFO - Extracted aspect_legal_and_risk_litigation: 0.0
# 2025-04-13 13:57:46,322 - INFO - Extracted aspect_legal_and_risk_financial_risks: -0.3
# 2025-04-13 13:57:46,323 - INFO - Extracted aspect_legal_and_risk_reputation_risks: 0.0
# 2025-04-13 13:57:46,323 - INFO - Extracted topic_financial_performance: -0.2
# 2025-04-13 13:57:46,324 - INFO - Extracted topic_management_and_leadership: 0.0
# 2025-04-13 13:57:46,324 - INFO - Extracted topic_product_service_performance: 0.1
# 2025-04-13 13:57:46,324 - INFO - Extracted topic_industry_and_market_factors: -0.3
# 2025-04-13 13:57:46,325 - INFO - Extracted topic_future_outlook: 0.0
# 2025-04-13 13:57:46,326 - INFO - Extracted topic_legal_and_risk: -0.1
# 2025-04-13 13:57:46,326 - INFO - Flattened JSON into 37 key-value pairs
# 2025-04-13 13:57:46,327 - INFO - Successfully analyzed sentiment for row 25
# Reprocessing rows with NaN scores:   5%|▍         | 8/176 [00:34<12:26,  4.44s/it]2025-04-13 13:57:46,328 - INFO - Looking for match: Ticker=AMD, CIK=2488, FormType=10-Q, FiledAt=2023-05-03
# 2025-04-13 13:57:46,331 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:46,331 - INFO - Found matching MDA text for row 26 (length: 24007 chars)
# 2025-04-13 13:57:46,832 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:46,833 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:52,430 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:52,431 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": -0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#    ...
# 2025-04-13 13:57:52,431 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:52,432 - INFO - Extracted polarity_detection: -0.1
# 2025-04-13 13:57:52,433 - INFO - Extracted emotion_detection: -0.2
# 2025-04-13 13:57:52,433 - INFO - Extracted intent_analysis: 0.0
# 2025-04-13 13:57:52,433 - INFO - Extracted subjectivity_objectivity: 0.6
# 2025-04-13 13:57:52,434 - INFO - Extracted gemini_overall_sentiment: -0.15
# 2025-04-13 13:57:52,434 - INFO - Extracted gemini_emotional_sentiment: -0.2
# 2025-04-13 13:57:52,435 - INFO - Extracted gemini_contextual_sentiment: -0.1
# 2025-04-13 13:57:52,436 - INFO - Extracted fine_grained_sentiment_avg: -0.105
# 2025-04-13 13:57:52,436 - INFO - Extracted aspect_based_sentiment_avg: -0.07894736842105263
# 2025-04-13 13:57:52,437 - INFO - Extracted topic_sentiment_analysis_avg: -0.06666666666666667
# 2025-04-13 13:57:52,437 - INFO - Extracted contextual_sentiment_avg: -0.13333333333333333
# 2025-04-13 13:57:52,438 - INFO - Extracted aspect_financial_performance:_revenue_growth: -0.3
# 2025-04-13 13:57:52,438 - INFO - Extracted aspect_financial_performance:_earnings_(eps): -0.6
# 2025-04-13 13:57:52,439 - INFO - Extracted aspect_financial_performance:_profit_margins: -0.4
# 2025-04-13 13:57:52,439 - INFO - Extracted aspect_financial_performance:_debt_levels: -0.1
# 2025-04-13 13:57:52,439 - INFO - Extracted aspect_financial_performance:_cash_flow: 0.1
# 2025-04-13 13:57:52,440 - INFO - Extracted aspect_management_and_leadership:_ceo_performance: 0.0
# 2025-04-13 13:57:52,440 - INFO - Extracted aspect_management_and_leadership:_management_team: 0.0
# 2025-04-13 13:57:52,441 - INFO - Extracted aspect_management_and_leadership:_corporate_governance: 0.0
# 2025-04-13 13:57:52,441 - INFO - Extracted aspect_product_service_performance:_product_innovation: 0.3
# 2025-04-13 13:57:52,442 - INFO - Extracted aspect_product_service_performance:_market_share: 0.0
# 2025-04-13 13:57:52,442 - INFO - Extracted aspect_product_service_performance:_customer_satisfaction: 0.0
# 2025-04-13 13:57:52,442 - INFO - Extracted aspect_product_service_performance:_product_quality: 0.0
# 2025-04-13 13:57:52,443 - INFO - Extracted aspect_future_outlook:_growth_potential: 0.1
# 2025-04-13 13:57:52,444 - INFO - Extracted aspect_future_outlook:_expansion_plans: 0.0
# 2025-04-13 13:57:52,444 - INFO - Extracted aspect_future_outlook:_analyst_ratings: 0.0
# 2025-04-13 13:57:52,444 - INFO - Extracted aspect_future_outlook:_investor_confidence: 0.0
# 2025-04-13 13:57:52,445 - INFO - Extracted aspect_legal_and_risk:_litigation: 0.0
# 2025-04-13 13:57:52,445 - INFO - Extracted aspect_legal_and_risk:_financial_risks: -0.2
# 2025-04-13 13:57:52,446 - INFO - Extracted aspect_legal_and_risk:_reputation_risks: 0.0
# 2025-04-13 13:57:52,446 - INFO - Extracted topic_financial_performance: -0.4
# 2025-04-13 13:57:52,447 - INFO - Extracted topic_management_and_leadership: 0.0
# 2025-04-13 13:57:52,447 - INFO - Extracted topic_product_service_performance: 0.1
# 2025-04-13 13:57:52,448 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 13:57:52,448 - INFO - Extracted topic_future_outlook: 0.0
# 2025-04-13 13:57:52,449 - INFO - Extracted topic_legal_and_risk: -0.1
# 2025-04-13 13:57:52,449 - INFO - Flattened JSON into 37 key-value pairs
# 2025-04-13 13:57:52,450 - INFO - Successfully analyzed sentiment for row 26
# Reprocessing rows with NaN scores:   5%|▌         | 9/176 [00:40<13:49,  4.97s/it]2025-04-13 13:57:52,451 - INFO - Looking for match: Ticker=LNT, CIK=352541, FormType=10-Q, FiledAt=2023-08-04
# 2025-04-13 13:57:52,454 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:52,454 - INFO - Found matching MDA text for row 69 (length: 28937 chars)
# 2025-04-13 13:57:52,955 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:52,956 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:57:56,490 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:57:56,491 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:57:56,491 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:57:56,492 - INFO - Extracted polarity_detection: 0.1
# 2025-04-13 13:57:56,493 - INFO - Extracted emotion_detection: 0.0
# 2025-04-13 13:57:56,493 - INFO - Extracted intent_analysis: 0.5
# 2025-04-13 13:57:56,493 - INFO - Extracted subjectivity_objectivity: -0.5
# 2025-04-13 13:57:56,494 - INFO - Extracted gemini_overall_sentiment: 0.1
# 2025-04-13 13:57:56,494 - INFO - Extracted gemini_emotional_sentiment: 0.0
# 2025-04-13 13:57:56,495 - INFO - Extracted gemini_contextual_sentiment: 0.1
# 2025-04-13 13:57:56,496 - INFO - Extracted fine_grained_sentiment_avg: 0.07
# 2025-04-13 13:57:56,496 - INFO - Extracted aspect_based_sentiment_avg: 0.06
# 2025-04-13 13:57:56,497 - INFO - Extracted topic_sentiment_analysis_avg: 0.05
# 2025-04-13 13:57:56,497 - INFO - Extracted contextual_sentiment_avg: 0.03
# 2025-04-13 13:57:56,498 - INFO - Extracted aspect_financial_performance: 0.1
# 2025-04-13 13:57:56,498 - INFO - Extracted aspect_management_and_leadership: 0.1
# 2025-04-13 13:57:56,499 - INFO - Extracted aspect_product_service_performance: 0.1
# 2025-04-13 13:57:56,499 - INFO - Extracted aspect_future_outlook: 0.2
# 2025-04-13 13:57:56,500 - INFO - Extracted aspect_legal_and_risk: -0.2
# 2025-04-13 13:57:56,500 - INFO - Extracted topic_financial_performance: 0.1
# 2025-04-13 13:57:56,501 - INFO - Extracted topic_management_and_leadership: 0.1
# 2025-04-13 13:57:56,501 - INFO - Extracted topic_product_service_performance: 0.1
# 2025-04-13 13:57:56,501 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 13:57:56,502 - INFO - Extracted topic_future_outlook: 0.2
# 2025-04-13 13:57:56,502 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 13:57:56,503 - INFO - Flattened JSON into 23 key-value pairs
# 2025-04-13 13:57:56,504 - INFO - Successfully analyzed sentiment for row 69
# 2025-04-13 13:57:56,504 - INFO - Processed 10 rows with NaN scores so far
# Reprocessing rows with NaN scores:   6%|▌         | 10/176 [00:44<12:57,  4.69s/it]2025-04-13 13:57:56,505 - INFO - Looking for match: Ticker=LNT, CIK=352541, FormType=10-Q, FiledAt=2023-05-05
# 2025-04-13 13:57:56,508 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:57:56,509 - INFO - Found matching MDA text for row 70 (length: 18799 chars)
# 2025-04-13 13:57:57,009 - INFO - Sending request to Gemini API...
# 2025-04-13 13:57:57,010 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:58:02,128 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:58:02,129 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.1,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:58:02,130 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:58:02,130 - INFO - Extracted polarity_detection: 0.1
# 2025-04-13 13:58:02,131 - INFO - Extracted emotion_detection: 0.0
# 2025-04-13 13:58:02,132 - INFO - Extracted intent_analysis: 0.8
# 2025-04-13 13:58:02,132 - INFO - Extracted subjectivity_objectivity: -0.6
# 2025-04-13 13:58:02,133 - INFO - Extracted gemini_overall_sentiment: 0.1
# 2025-04-13 13:58:02,133 - INFO - Extracted gemini_emotional_sentiment: -0.1
# 2025-04-13 13:58:02,134 - INFO - Extracted gemini_contextual_sentiment: 0.2
# 2025-04-13 13:58:02,135 - INFO - Extracted fine_grained_sentiment_avg: 0.03
# 2025-04-13 13:58:02,135 - INFO - Extracted aspect_based_sentiment_avg: 0.04
# 2025-04-13 13:58:02,136 - INFO - Extracted topic_sentiment_analysis_avg: 0.01
# 2025-04-13 13:58:02,136 - INFO - Extracted contextual_sentiment_avg: 0.03
# 2025-04-13 13:58:02,137 - INFO - Extracted aspect_financial_performance:_revenue_growth: -0.1
# 2025-04-13 13:58:02,138 - INFO - Extracted aspect_financial_performance:_earnings_(eps): 0.05
# 2025-04-13 13:58:02,138 - INFO - Extracted aspect_financial_performance:_profit_margins: 0.0
# 2025-04-13 13:58:02,138 - INFO - Extracted aspect_financial_performance:_debt_levels: -0.1
# 2025-04-13 13:58:02,139 - INFO - Extracted aspect_financial_performance:_cash_flow: 0.1
# 2025-04-13 13:58:02,139 - INFO - Extracted aspect_management_and_leadership:_ceo_performance: 0.0
# 2025-04-13 13:58:02,140 - INFO - Extracted aspect_management_and_leadership:_management_team: 0.0
# 2025-04-13 13:58:02,140 - INFO - Extracted aspect_management_and_leadership:_corporate_governance: 0.0
# 2025-04-13 13:58:02,140 - INFO - Extracted aspect_product_service_performance:_product_innovation: 0.2
# 2025-04-13 13:58:02,141 - INFO - Extracted aspect_product_service_performance:_market_share: 0.0
# 2025-04-13 13:58:02,142 - INFO - Extracted aspect_product_service_performance:_customer_satisfaction: 0.0
# 2025-04-13 13:58:02,143 - INFO - Extracted aspect_product_service_performance:_product_quality: 0.0
# 2025-04-13 13:58:02,143 - INFO - Extracted aspect_future_outlook:_growth_potential: 0.2
# 2025-04-13 13:58:02,143 - INFO - Extracted aspect_future_outlook:_expansion_plans: 0.2
# 2025-04-13 13:58:02,144 - INFO - Extracted aspect_future_outlook:_analyst_ratings: 0.0
# 2025-04-13 13:58:02,144 - INFO - Extracted aspect_future_outlook:_investor_confidence: 0.0
# 2025-04-13 13:58:02,145 - INFO - Extracted aspect_legal_and_risk:_litigation: 0.0
# 2025-04-13 13:58:02,145 - INFO - Extracted aspect_legal_and_risk:_financial_risks: -0.1
# 2025-04-13 13:58:02,145 - INFO - Extracted aspect_legal_and_risk:_reputation_risks: 0.0
# 2025-04-13 13:58:02,146 - INFO - Extracted topic_financial_performance: -0.01
# 2025-04-13 13:58:02,147 - INFO - Extracted topic_management_and_leadership: 0.0
# 2025-04-13 13:58:02,147 - INFO - Extracted topic_product_service_performance: 0.07
# 2025-04-13 13:58:02,148 - INFO - Extracted topic_industry_and_market_factors: -0.1
# 2025-04-13 13:58:02,148 - INFO - Extracted topic_future_outlook: 0.13
# 2025-04-13 13:58:02,149 - INFO - Extracted topic_legal_and_risk: -0.03
# 2025-04-13 13:58:02,150 - INFO - Flattened JSON into 37 key-value pairs
# 2025-04-13 13:58:02,150 - INFO - Successfully analyzed sentiment for row 70
# Reprocessing rows with NaN scores:   6%|▋         | 11/176 [00:50<13:41,  4.98s/it]2025-04-13 13:58:02,151 - INFO - Looking for match: Ticker=AEP, CIK=4904, FormType=10-K, FiledAt=2023-02-23
# 2025-04-13 13:58:02,154 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 13:58:02,155 - INFO - Found matching MDA text for row 100 (length: 1007 chars)
# 2025-04-13 13:58:02,656 - INFO - Sending request to Gemini API...
# 2025-04-13 13:58:02,657 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 13:58:05,745 - INFO - AFC remote call 1 is done.
# 2025-04-13 13:58:05,746 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.0,
#   "fine_grained_sentiment": {
#     "individual_scores": [
#     ...
# 2025-04-13 13:58:05,746 - INFO - Flattening JSON with keys: ['polarity_detection', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 13:58:05,747 - INFO - Extracted polarity_detection: 0.0
# 2025-04-13 13:58:05,747 - INFO - Extracted emotion_detection: 0.0
# 2025-04-13 13:58:05,748 - INFO - Extracted intent_analysis: 0.0
# 2025-04-13 13:58:05,749 - INFO - Extracted subjectivity_objectivity: -0.5
# 2025-04-13 13:58:05,749 - INFO - Extracted gemini_overall_sentiment: 0.0
# 2025-04-13 13:58:05,749 - INFO - Extracted gemini_emotional_sentiment: 0.0
# 2025-04-13 13:58:05,750 - INFO - Extracted gemini_contextual_sentiment: 0.0
# 2025-04-13 13:58:05,750 - INFO - Extracted fine_grained_sentiment_avg: 0.0
# 2025-04-13 13:58:05,751 - INFO - Extracted aspect_based_sentiment_avg: 0.0
# 2025-04-13 13:58:05,751 - INFO - Extracted topic_sentiment_analysis_avg: 0.0
# 2025-04-13 13:58:05,751 - INFO - Extracted contextual_sentiment_avg: 0.0
# ...
# 2025-04-13 14:21:42,498 - INFO - Extracted polarity_detection: 0.2
# 2025-04-13 14:21:42,498 - INFO - Extracted emotion_detection: 0.1
# 2025-04-13 14:21:42,499 - INFO - Extracted intent_analysis: 0.3
# 2025-04-13 14:21:42,499 - INFO - Extracted subjectivity_objectivity: 0.1
# 2025-04-13 14:21:42,500 - INFO - Extracted gemini_overall_sentiment: 0.2
# 2025-04-13 14:21:42,500 - INFO - Extracted gemini_emotional_sentiment: 0.1
# 2025-04-13 14:21:42,501 - INFO - Extracted gemini_contextual_sentiment: 0.1
# 2025-04-13 14:21:42,502 - INFO - Extracted fine_grained_sentiment_avg: 0.15
# 2025-04-13 14:21:42,502 - INFO - Extracted aspect_based_sentiment_avg: 0.2
# 2025-04-13 14:21:42,503 - INFO - Extracted topic_sentiment_analysis_avg: 0.1
# 2025-04-13 14:21:42,503 - INFO - Extracted contextual_sentiment_avg: 0.1
# 2025-04-13 14:21:42,504 - INFO - Extracted aspect_financial_performance_revenue_growth: 0.4
# 2025-04-13 14:21:42,505 - INFO - Extracted aspect_financial_performance_earnings: 0.4
# 2025-04-13 14:21:42,505 - INFO - Extracted aspect_financial_performance_profit_margins: 0.3
# 2025-04-13 14:21:42,505 - INFO - Extracted aspect_financial_performance_debt_levels: -0.1
# 2025-04-13 14:21:42,506 - INFO - Extracted aspect_financial_performance_cash_flow: 0.3
# 2025-04-13 14:21:42,506 - INFO - Extracted aspect_management_and_leadership: 0.2
# 2025-04-13 14:21:42,507 - INFO - Extracted aspect_product_service_performance: 0.2
# 2025-04-13 14:21:42,507 - INFO - Extracted aspect_future_outlook: 0.1
# 2025-04-13 14:21:42,508 - INFO - Extracted aspect_legal_and_risk: -0.2
# 2025-04-13 14:21:42,508 - INFO - Extracted topic_financial_performance: 0.3
# 2025-04-13 14:21:42,508 - INFO - Extracted topic_management_and_leadership: 0.2
# 2025-04-13 14:21:42,510 - INFO - Extracted topic_product_service_performance: 0.2
# 2025-04-13 14:21:42,510 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 14:21:42,511 - INFO - Extracted topic_future_outlook: 0.1
# 2025-04-13 14:21:42,511 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 14:21:42,512 - INFO - Flattened JSON into 27 key-value pairs
# 2025-04-13 14:21:42,512 - INFO - Successfully analyzed sentiment for row 202
# Reprocessing rows with NaN scores:  10%|█         | 202/1958 [10:56<1:25:32,  2.92s/it]2025-04-13 14:21:42,513 - INFO - Looking for match: Ticker=AZO, CIK=866787, FormType=10-Q, FiledAt=2024-03-15
# 2025-04-13 14:21:42,516 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 14:21:42,517 - INFO - Found matching MDA text for row 203 (length: 40263 chars)
# 2025-04-13 14:21:43,018 - INFO - Sending request to Gemini API...
# 2025-04-13 14:21:43,020 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 14:21:45,274 - INFO - AFC remote call 1 is done.
# 2025-04-13 14:21:45,275 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.3,
#   "emotion_detection": 0.2,
#   "intent_analysis": 0.4,
#   "subj...
# 2025-04-13 14:21:45,276 - INFO - Flattening JSON with keys: ['polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 14:21:45,276 - INFO - Extracted polarity_detection: 0.3
# 2025-04-13 14:21:45,277 - INFO - Extracted emotion_detection: 0.2
# 2025-04-13 14:21:45,278 - INFO - Extracted intent_analysis: 0.4
# 2025-04-13 14:21:45,279 - INFO - Extracted subjectivity_objectivity: 0.6
# 2025-04-13 14:21:45,279 - INFO - Extracted gemini_overall_sentiment: 0.3
# 2025-04-13 14:21:45,280 - INFO - Extracted gemini_emotional_sentiment: 0.2
# 2025-04-13 14:21:45,280 - INFO - Extracted gemini_contextual_sentiment: 0.3
# 2025-04-13 14:21:45,281 - INFO - Extracted fine_grained_sentiment_avg: 0.25
# 2025-04-13 14:21:45,281 - INFO - Extracted aspect_based_sentiment_avg: 0.33
# 2025-04-13 14:21:45,282 - INFO - Extracted topic_sentiment_analysis_avg: 0.25
# 2025-04-13 14:21:45,283 - INFO - Extracted contextual_sentiment_avg: 0.3
# 2025-04-13 14:21:45,283 - INFO - Extracted aspect_financial_performance_revenue_growth: 0.5
# 2025-04-13 14:21:45,284 - INFO - Extracted aspect_financial_performance_earnings: 0.6
# 2025-04-13 14:21:45,284 - INFO - Extracted aspect_financial_performance_profit_margins: 0.5
# 2025-04-13 14:21:45,284 - INFO - Extracted aspect_financial_performance_debt_levels: 0.2
# 2025-04-13 14:21:45,285 - INFO - Extracted aspect_financial_performance_cash_flow: 0.4
# 2025-04-13 14:21:45,285 - INFO - Extracted aspect_management_and_leadership: 0.3
# 2025-04-13 14:21:45,286 - INFO - Extracted aspect_product_service_performance: 0.4
# 2025-04-13 14:21:45,286 - INFO - Extracted aspect_future_outlook: 0.3
# 2025-04-13 14:21:45,287 - INFO - Extracted aspect_legal_and_risk: -0.2
# 2025-04-13 14:21:45,287 - INFO - Extracted topic_financial_performance: 0.5
# 2025-04-13 14:21:45,288 - INFO - Extracted topic_management_and_leadership: 0.3
# 2025-04-13 14:21:45,288 - INFO - Extracted topic_product_service_performance: 0.4
# 2025-04-13 14:21:45,288 - INFO - Extracted topic_industry_and_market_factors: 0.2
# 2025-04-13 14:21:45,289 - INFO - Extracted topic_future_outlook: 0.3
# 2025-04-13 14:21:45,289 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 14:21:45,291 - INFO - Flattened JSON into 27 key-value pairs
# 2025-04-13 14:21:45,292 - INFO - Successfully analyzed sentiment for row 203
# Reprocessing rows with NaN scores:  10%|█         | 203/1958 [10:59<1:24:14,  2.88s/it]2025-04-13 14:21:45,293 - INFO - Looking for match: Ticker=AVB, CIK=915912, FormType=10-Q, FiledAt=2024-11-12
# 2025-04-13 14:21:45,297 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 14:21:45,298 - INFO - Found matching MDA text for row 204 (length: 76262 chars)
# 2025-04-13 14:21:45,298 - WARNING - Text too long (76262 chars), truncating to 60000 chars
# 2025-04-13 14:21:45,799 - INFO - Sending request to Gemini API...
# 2025-04-13 14:21:45,800 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 14:21:48,122 - INFO - AFC remote call 1 is done.
# 2025-04-13 14:21:48,123 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.4,
#   "emotion_detection": 0.2,
#   "intent_analysis": 0.3,
#   "subj...
# 2025-04-13 14:21:48,124 - INFO - Flattening JSON with keys: ['polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 14:21:48,125 - INFO - Extracted polarity_detection: 0.4
# 2025-04-13 14:21:48,125 - INFO - Extracted emotion_detection: 0.2
# 2025-04-13 14:21:48,126 - INFO - Extracted intent_analysis: 0.3
# 2025-04-13 14:21:48,126 - INFO - Extracted subjectivity_objectivity: 0.6
# 2025-04-13 14:21:48,127 - INFO - Extracted gemini_overall_sentiment: 0.3
# 2025-04-13 14:21:48,127 - INFO - Extracted gemini_emotional_sentiment: 0.1
# 2025-04-13 14:21:48,128 - INFO - Extracted gemini_contextual_sentiment: 0.3
# 2025-04-13 14:21:48,129 - INFO - Extracted fine_grained_sentiment_avg: 0.25
# 2025-04-13 14:21:48,129 - INFO - Extracted aspect_based_sentiment_avg: 0.3
# 2025-04-13 14:21:48,130 - INFO - Extracted topic_sentiment_analysis_avg: 0.25
# 2025-04-13 14:21:48,130 - INFO - Extracted contextual_sentiment_avg: 0.3
# 2025-04-13 14:21:48,131 - INFO - Extracted aspect_financial_performance_revenue_growth: 0.4
# 2025-04-13 14:21:48,131 - INFO - Extracted aspect_financial_performance_earnings: 0.6
# 2025-04-13 14:21:48,132 - INFO - Extracted aspect_financial_performance_profit_margins: 0.3
# 2025-04-13 14:21:48,132 - INFO - Extracted aspect_financial_performance_debt_levels: 0.1
# 2025-04-13 14:21:48,132 - INFO - Extracted aspect_financial_performance_cash_flow: 0.4
# 2025-04-13 14:21:48,133 - INFO - Extracted aspect_management_and_leadership: 0.2
# 2025-04-13 14:21:48,134 - INFO - Extracted aspect_product_service_performance: 0.3
# 2025-04-13 14:21:48,135 - INFO - Extracted aspect_future_outlook: 0.3
# 2025-04-13 14:21:48,135 - INFO - Extracted aspect_legal_and_risk: 0.1
# 2025-04-13 14:21:48,135 - INFO - Extracted topic_financial_performance: 0.4
# 2025-04-13 14:21:48,136 - INFO - Extracted topic_management_and_leadership: 0.2
# 2025-04-13 14:21:48,136 - INFO - Extracted topic_product_service_performance: 0.3
# 2025-04-13 14:21:48,137 - INFO - Extracted topic_industry_and_market_factors: 0.2
# 2025-04-13 14:21:48,137 - INFO - Extracted topic_future_outlook: 0.3
# 2025-04-13 14:21:48,137 - INFO - Extracted topic_legal_and_risk: 0.1
# 2025-04-13 14:21:48,138 - INFO - Flattened JSON into 27 key-value pairs
# 2025-04-13 14:21:48,138 - INFO - Successfully analyzed sentiment for row 204
# Reprocessing rows with NaN scores:  10%|█         | 204/1958 [11:02<1:23:54,  2.87s/it]2025-04-13 14:21:48,140 - INFO - Looking for match: Ticker=AVB, CIK=915912, FormType=10-Q, FiledAt=2024-08-06
# 2025-04-13 14:21:48,143 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 14:21:48,144 - INFO - Found matching MDA text for row 205 (length: 73690 chars)
# 2025-04-13 14:21:48,144 - WARNING - Text too long (73690 chars), truncating to 60000 chars
# 2025-04-13 14:21:48,645 - INFO - Sending request to Gemini API...
# 2025-04-13 14:21:48,646 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 14:21:51,258 - INFO - AFC remote call 1 is done.
# 2025-04-13 14:21:51,259 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.2,
#   "emotion_detection": 0.1,
#   "intent_analysis": 0.3,
#   "subj...
# 2025-04-13 14:21:51,259 - INFO - Flattening JSON with keys: ['polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 14:21:51,260 - INFO - Extracted polarity_detection: 0.2
# 2025-04-13 14:21:51,261 - INFO - Extracted emotion_detection: 0.1
# 2025-04-13 14:21:51,261 - INFO - Extracted intent_analysis: 0.3
# 2025-04-13 14:21:51,261 - INFO - Extracted subjectivity_objectivity: 0.4
# 2025-04-13 14:21:51,262 - INFO - Extracted gemini_overall_sentiment: 0.2
# 2025-04-13 14:21:51,262 - INFO - Extracted gemini_emotional_sentiment: 0.1
# 2025-04-13 14:21:51,263 - INFO - Extracted gemini_contextual_sentiment: 0.2
# 2025-04-13 14:21:51,263 - INFO - Extracted fine_grained_sentiment_avg: 0.15
# 2025-04-13 14:21:51,264 - INFO - Extracted aspect_based_sentiment_avg: 0.22
# 2025-04-13 14:21:51,265 - INFO - Extracted topic_sentiment_analysis_avg: 0.21
# 2025-04-13 14:21:51,265 - INFO - Extracted contextual_sentiment_avg: 0.2
# 2025-04-13 14:21:51,266 - INFO - Extracted aspect_financial_performance_revenue_growth: 0.4
# 2025-04-13 14:21:51,266 - INFO - Extracted aspect_financial_performance_earnings: -0.2
# 2025-04-13 14:21:51,267 - INFO - Extracted aspect_financial_performance_profit_margins: 0.1
# 2025-04-13 14:21:51,268 - INFO - Extracted aspect_financial_performance_debt_levels: 0.2
# 2025-04-13 14:21:51,268 - INFO - Extracted aspect_financial_performance_cash_flow: 0.4
# 2025-04-13 14:21:51,269 - INFO - Extracted aspect_management_and_leadership: 0.3
# 2025-04-13 14:21:51,269 - INFO - Extracted aspect_product_service_performance: 0.4
# 2025-04-13 14:21:51,269 - INFO - Extracted aspect_future_outlook: 0.5
# 2025-04-13 14:21:51,270 - INFO - Extracted aspect_legal_and_risk: -0.1
# 2025-04-13 14:21:51,270 - INFO - Extracted topic_financial_performance: 0.18
# 2025-04-13 14:21:51,271 - INFO - Extracted topic_management_and_leadership: 0.3
# 2025-04-13 14:21:51,272 - INFO - Extracted topic_product_service_performance: 0.4
# 2025-04-13 14:21:51,272 - INFO - Extracted topic_industry_and_market_factors: 0.0
# 2025-04-13 14:21:51,272 - INFO - Extracted topic_future_outlook: 0.5
# 2025-04-13 14:21:51,273 - INFO - Extracted topic_legal_and_risk: -0.1
# 2025-04-13 14:21:51,273 - INFO - Flattened JSON into 27 key-value pairs
# 2025-04-13 14:21:51,274 - INFO - Successfully analyzed sentiment for row 205
# 2025-04-13 14:21:51,275 - INFO - Processed 205 rows with NaN scores so far
# Reprocessing rows with NaN scores:  10%|█         | 205/1958 [11:05<1:26:10,  2.95s/it]2025-04-13 14:21:51,276 - INFO - Looking for match: Ticker=AVB, CIK=915912, FormType=10-Q, FiledAt=2024-05-03
# 2025-04-13 14:21:51,278 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 14:21:51,279 - INFO - Found matching MDA text for row 206 (length: 67179 chars)
# 2025-04-13 14:21:51,279 - WARNING - Text too long (67179 chars), truncating to 60000 chars
# 2025-04-13 14:21:51,780 - INFO - Sending request to Gemini API...
# 2025-04-13 14:21:51,781 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-13 14:21:54,405 - INFO - AFC remote call 1 is done.
# 2025-04-13 14:21:54,406 - INFO - Received response from Gemini API: ```json
# {
#   "polarity_detection": 0.3,
#   "emotion_detection": 0.1,
#   "intent_analysis": 0.2,
#   "subj...
# 2025-04-13 14:21:54,407 - INFO - Flattening JSON with keys: ['polarity_detection', 'emotion_detection', 'intent_analysis', 'subjectivity_objectivity', 'fine_grained_sentiment', 'aspect_based_sentiment', 'topic_sentiment_analysis', 'contextual_sentiment', 'gemini_analysis']
# 2025-04-13 14:21:54,408 - INFO - Extracted polarity_detection: 0.3
# 2025-04-13 14:21:54,408 - INFO - Extracted emotion_detection: 0.1
# 2025-04-13 14:21:54,409 - INFO - Extracted intent_analysis: 0.2
# 2025-04-13 14:21:54,410 - INFO - Extracted subjectivity_objectivity: 0.1
# 2025-04-13 14:21:54,410 - INFO - Extracted gemini_overall_sentiment: 0.3
# 2025-04-13 14:21:54,411 - INFO - Extracted gemini_emotional_sentiment: 0.1
# 2025-04-13 14:21:54,412 - INFO - Extracted gemini_contextual_sentiment: 0.2
# 2025-04-13 14:21:54,412 - INFO - Extracted fine_grained_sentiment_avg: 0.2
# 2025-04-13 14:21:54,413 - INFO - Extracted aspect_based_sentiment_avg: 0.3
# 2025-04-13 14:21:54,413 - INFO - Extracted topic_sentiment_analysis_avg: 0.2
# 2025-04-13 14:21:54,414 - INFO - Extracted contextual_sentiment_avg: 0.2
# 2025-04-13 14:21:54,414 - INFO - Extracted aspect_financial_performance_revenue_growth: 0.5
# 2025-04-13 14:21:54,415 - INFO - Extracted aspect_financial_performance_earnings: 0.6
# 2025-04-13 14:21:54,416 - INFO - Extracted aspect_financial_performance_profit_margins: 0.4
# 2025-04-13 14:21:54,416 - INFO - Extracted aspect_financial_performance_debt_levels: 0.1
# 2025-04-13 14:21:54,417 - INFO - Extracted aspect_financial_performance_cash_flow: 0.4
# 2025-04-13 14:21:54,417 - INFO - Extracted aspect_management_and_leadership: 0.3
# 2025-04-13 14:21:54,417 - INFO - Extracted aspect_product_service_performance: 0.3
# 2025-04-13 14:21:54,418 - INFO - Extracted aspect_future_outlook: 0.2
# 2025-04-13 14:21:54,418 - INFO - Extracted aspect_legal_and_risk: -0.2
# 2025-04-13 14:21:54,419 - INFO - Extracted topic_financial_performance: 0.4
# 2025-04-13 14:21:54,419 - INFO - Extracted topic_management_and_leadership: 0.3
# 2025-04-13 14:21:54,420 - INFO - Extracted topic_product_service_performance: 0.3
# 2025-04-13 14:21:54,420 - INFO - Extracted topic_industry_and_market_factors: 0.2
# 2025-04-13 14:21:54,421 - INFO - Extracted topic_future_outlook: 0.2
# 2025-04-13 14:21:54,421 - INFO - Extracted topic_legal_and_risk: -0.2
# 2025-04-13 14:21:54,421 - INFO - Flattened JSON into 27 key-value pairs
# 2025-04-13 14:21:54,422 - INFO - Successfully analyzed sentiment for row 206
# Reprocessing rows with NaN scores:  11%|█         | 206/1958 [11:08<1:27:51,  3.01s/it]2025-04-13 14:21:54,423 - INFO - Looking for match: Ticker=AVB, CIK=915912, FormType=10-K, FiledAt=2024-02-23
# 2025-04-13 14:21:54,428 - INFO - Strategy 1 (all fields): Found 1 matches
# 2025-04-13 14:21:54,428 - INFO - Found matching MDA text for row 207 (length: 72120 chars)
# 2025-04-13 14:21:54,429 - WARNING - Text too long (72120 chars), truncating to 60000 chars
# 2025-04-13 14:21:54,930 - INFO - Sending request to Gemini API...
# 2025-04-13 14:21:54,931 - INFO - AFC is enabled with max remote calls: 10.
